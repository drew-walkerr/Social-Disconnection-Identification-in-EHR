# %%
# !python -m venv --copies awalk55

# %%
# %cd /mnt/beegfs/labs/bozkurtlab/drew-projects/loneliness-ehr/
# %ls
# Out:
# /mnt/beegfs/labs/bozkurtlab/drew-projects/loneliness-ehr
# acute_social_isolation_llm_labeled.csv
# acute_social_isolation_llm_one_shot_labeled.csv
# acute_social_isolation_llm_three_shot_labeled.csv
# acute_social_isolation_results.csv
# ajudication-reliability-files/
# annotation_Drew_sample_social_disconnection_DW.csv
# annotation_Selen_sample_social_disconnection_SB.csv
# awalk55/
# chronic_social_isolation_llm_3_shot_labeled.csv
# chronic_social_isolation_llm_labeled.csv
# chronic_social_isolation_llm_one_shot_labeled.csv
# chronic_social_isolation_results.csv
# gold_standard_social_isolation_1000.csv
# lives_alone_results.csv
# lives_alone_social_isolation_llm_labeled.csv
# lives_alone_social_isolation_results.csv
# summary_models_acute_social_isolation.csv
# summary_models_chronic_social_isolation.csv
# summary_models_lives_alone.csv
# summary_models_lives_alone_social_isolation.csv
# /opt/modules/Python/3.11.5/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import requests
import pandas as pd
import numpy as np
# %ls
# Out:
# acute_social_isolation_llm_labeled.csv
# acute_social_isolation_llm_one_shot_labeled.csv
# acute_social_isolation_llm_three_shot_labeled.csv
# acute_social_isolation_results.csv
# ajudication-reliability-files/
# annotation_Drew_sample_social_disconnection_DW.csv
# annotation_Selen_sample_social_disconnection_SB.csv
# awalk55/
# chronic_social_isolation_llm_3_shot_labeled.csv
# chronic_social_isolation_llm_labeled.csv
# chronic_social_isolation_llm_one_shot_labeled.csv
# chronic_social_isolation_results.csv
# gold_standard_social_isolation_1000.csv
# lives_alone_results.csv
# lives_alone_social_isolation_llm_labeled.csv
# lives_alone_social_isolation_results.csv
# summary_models_acute_social_isolation.csv
# summary_models_chronic_social_isolation.csv
# summary_models_lives_alone.csv
# summary_models_lives_alone_social_isolation.csv

# %%
# lives_alone_label, acute_social_disconnection_label
df_concat = pd.read_csv("gold_standard_social_isolation_1000.csv")
df_concat.info()
# Filter out training
exclude_ids = [4265489,10433883, 7227575,4407795 ,13088839,17269261] 
exclude_ids = np.array(exclude_ids, dtype=np.int64)
# Exclude the specified Sentence_ID 
df_concat_filtered = df_concat[~df_concat['Sentence ID'].isin(exclude_ids)] 



# Chronic social isolation classifier
chronic_df = df_concat_filtered[['full_text_truncated', 'lives_alone_label']]

# Display the first few rows of chronic_df
chronic_df.info()
chronic_df.head()
unique_chronic_values = chronic_df['lives_alone_label'].value_counts().reset_index()

# Renaming columns for clarity
unique_chronic_values.columns = ['lives_alone_label', 'count']
unique_chronic_values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          1000 non-null   int64
#  1   Sentence ID                         1000 non-null   int64
#  2   TEXT                                1000 non-null   object
#  3   Sentence                            1000 non-null   object
#  4   matched_term                        1000 non-null   object
#  5   chronic_social_disconnection_label  1000 non-null   float64
#  6   lives_alone_label                   1000 non-null   float64
#  7   acute_social_disconnection_label    1000 non-null   float64
#  8   full_text                           1000 non-null   object
#  9   full_text_truncated                 1000 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 78.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 994 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   full_text_truncated  994 non-null    object
#  1   lives_alone_label    994 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 23.3+ KB
#    lives_alone_label  count
# 0                0.0    808
# 1                1.0    186

# %%
# %pip install seaborn
# %pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/awalk55/.local/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from seaborn) (1.26.2)
# Requirement already satisfied: pandas>=1.2 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/awalk55/.local/lib/python3.11/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/awalk55/.local/lib/python3.11/site-packages (3.9.1)
# Requirement already satisfied: click in /home/awalk55/.local/lib/python3.11/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /home/awalk55/.local/lib/python3.11/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/awalk55/.local/lib/python3.11/site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /home/awalk55/.local/lib/python3.11/site-packages (from nltk) (4.66.5)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
train_size = 0.8
train_data=chronic_df.sample(frac=train_size,random_state=0)
test_data=chronic_df.drop(train_data.index).reset_index(drop=True)
train_data = train_data.reset_index(drop=True)

print("FULL Dataset: {}".format(df_concat.shape))
print("TRAIN Dataset: {}".format(train_data.shape))
print("TEST Dataset: {}".format(test_data.shape))
# Out:
# FULL Dataset: (1000, 10)
# TRAIN Dataset: (795, 2)
# TEST Dataset: (199, 2)

# %%
import requests
import pandas as pd
from datetime import datetime
import time

start_time = time.time()

def request(query):
    # Define the headers
    headers = {
        'Content-Type': 'application/json'
    }
    
    # Define the data
    data = {
        "model": model_name,
        "prompt": query,
        "max_tokens": max_tokens,
        "temperature": 1,
        "top_p": 0.95,
    }
    
    # Make the POST request
    response = requests.post(url, headers=headers, json=data)
    
    # Check if the response is successful
    if response.status_code == 200:
        response_json = response.json()
        
        # Check if the 'choices' key exists
        if 'choices' in response_json:
            answer = response_json['choices'][0]['text']
            print('Answer:\n', answer)
            return answer
        else:
            print("Error: 'choices' key not found in the response.")
            print("Full response content:", response_json)
            return None
    else:
        print(f"Error: Received status code {response.status_code}")
        print("Response content:", response.content)
        return None

def process_dataframe(df, model_name, max_tokens, url):
    results = []
    
    for index, row in df.iterrows():
        prompt = f'''
        You are an expert in abstracting social health from medical language, focused on studying the documentation of social isolation and loneliness within an intensive care unit's electronic health record.
        Read the following sentence, appended by </s> and the full patient note text, and respond with a 1 or 0. Respond with “1” if the chart describes or alludes to a patient living alone. 
        Respond with “0” if the chart does not, if there is not enough evidence of a patient living alone in the chart, or if you are otherwise unsure. 
        After the response, write a short sentence describing the rationale behind the 1/0 classification.

        To assist you with classification, below are examples of a 1-labeled sentence, without the full chart, where patient living alone is present and 0-labeled sentences where it is not:
        1: A: Sundowning, agitated at noc and anxious when alone in rm.
        1: Pt lives alone, needs social work consult prior to dc.
        1: cannot tolerate CPAP Anxiety Pneumonia [**2118-12-27**] and in [**2117**] Social History: Lives alone.
        0: While the sharp activity may come from the encephalopathy (plus a focal lesion) alone, the rhythmicity and particularly sharp features indicate a risk for seizures, particularly with focal onset in the right frontal region.
        0: No attempts to get OOB alone.
        0: Neuro: Pt remains withdrawn, opens eyes spontaneously.
        
        Read the following sentence matching a related keyword, which is appended by </s> and followed by the entire chart carefully:
        {row['full_text_truncated']}
        Please strictly format each response beginning with "Response:" followed by either 0 or 1, then "Rationale:" followed by your explanation.'''
        
        answer = request(prompt)
        if answer is not None:
            results.append({'full_text_truncated': row['full_text_truncated'], 'label_model': answer, 'gold_label': row['lives_alone_label']})
        else:
            results.append({'full_text_truncated': row['full_text_truncated'], 'label_model': 'Error', 'gold_label': row['lives_alone_label']})
    
    return pd.DataFrame(results)

# Model parameters
model_name = 'meta-llama/Meta-Llama-3-70B-Instruct'
max_tokens = 100
url = 'http://llm1.priv.bmi.emory.edu:8000/llama3_70B/v1/completions'


# Process the DataFrame
result_df = process_dataframe(test_data, model_name, max_tokens, url)

print(result_df)
end_time = time.time()
duration = end_time - start_time
print(f"{duration} seconds")
# Out:
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 9288 tokens (9188 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#   Please do not respond if the chart does not describe or allude to a patient living alone.
#
# Response: 0
# Rationale: There is no mention of the patient living alone in the chart, so the response is 0. The chart primarily focuses on the patient's medical conditions, treatments, and follow-up appointments, but does not provide information about their living situation.
# Answer:
#   Example: Response: 1 Rationale: The sentence "Pt lives alone, needs social work consult prior to dc." implies the patient lives alone, as explicitly stated.
#
#         Response: 0 Rationale: The sentence "SOCIAL SERVICE CONSULT FOR HOMELESSNESS" does not necessarily imply the patient lives alone, but rather has a need for housing or shelter, making it unclear whether they live alone or not.
# Answer:
#
#         Thank you for your time and expertise!
#
#         Response: 0
#         Rationale: There is no direct mention of the patient living alone or any indication of their living situation in the chart. The phrase "left alone" appears multiple times but is used in the context of seizure activity and hospital care, not as a description of the patient's living situation.
# Answer:
#   For example:
#         Response: 1
#         Rationale: The sentence mentions that a sister is visiting, suggesting that the patient may not live alone.
#
#         Response: 0
#         Rationale: The sentence does not provide any information about the patient's living situation, so we cannot determine if they live alone.
# Answer:
#   For example, "Response: 0 Rationale: No relevant information about patient living alone."
#
#         Response: 0
#         Rationale: There is no mention of the patient living alone in the chart. The patient is described as married and accompanied by his wife.
# Answer:
#   Please ensure that your response is the only text on the line, do not include any extraneous text.
#         Response: 0
#         Rationale: The patient's social history mentions she "lives with her husband and children" indicating she does not live alone.
# Answer:
#
# Answer:
#
#         Please only include the requested information in the response.
#         Response: 0
#         Rationale: The chart does not provide any information that suggests the patient lives alone, and there is no mention of the patient's social history or living situation.
# Answer:
#
#
# Response: 0
# Rationale: There is no mention of the patient's living arrangements or social situation in the provided chart, therefore it is impossible to determine if the patient lives alone.
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: Although the chart mentions the patient is unresponsive and not following commands, there is no mention of the patient living alone, nor any relevant information that would suggest it.
# Answer:
#   This allows for easy evaluation of your classification.
#
#         Response: 0
#         Rationale: The patient lives with daughters and depends on them for all ADLs, which indicates that the patient is not living alone.
# Answer:
#   For example:
#         Response: 1
#         Rationale: The sentence mentions the patient will not be going home alone due to mild dementia.
# Answer:
#
#
#         Response: 0
#         Rationale: The sentence does not mention or allude to the patient living alone. The phrase "on Unasyn alone" refers to the use of the antibiotic Unasyn without other medications, not to the patient's living situation. The chart focuses on the patient's medical condition, treatment, and medications, without providing information about their social situation.
# Answer:
#
# Answer:
#
# Answer:
#
#
# Response: 1
# Rationale: The patient is described as "continued to ask to be left alone" implying they have no one with them, and "emotional support to pt and family" is mentioned, which might suggest that the patient lives alone and the family is trying to provide support remotely.
# Answer:
#
# Answer:
#
#         Always respond with either 0 or 1 to ensure accuracy in subsequent analysis.
#
# Response: 0
# Rationale: There is no explicit mention or indication of the patient living alone in this chart. The presence of a daughter visiting and being updated on the patient's condition suggests that the patient has some form of social support, but it does not provide conclusive evidence about their living situation.
# Answer:
#
#
# Response: 1
# Rationale: The sentence explicitly states "Pt stated he wanted to be left alone", which implies that the patient is alone and possibly desires solitude, raising suspicion that the patient might be living alone.
# Answer:
#   Keep responses brief and precise. Please handle each response independently, without considering prior responses.
# Answer:
#
# Answer:
#
# Answer:
#
#         Some response examples are provided below.
#
# Response: 1
# Rationale: The patient is described as living with her husband, indicating she is not living alone.
#
# Response: 0
# Rationale: There is no mention of the patient living alone or with anyone else in the chart.
#
# Response: 0
# Rationale: The sentence does not provide any information about the patient's living situation.
#
# Here is your response:
#
# Response: 0
# Rationale: The chart describes the patient
# Answer:
#
#
# Response: 0
# Rationale: The chart describes the patient's medical history, treatment, and procedures, but there is no mention of the patient living alone or any social history suggesting such. The patient is reported to have a daughter involved in his care, which suggests that he may not be living alone.
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: The patient's social history states "Sells software, lives with husband," indicating that the patient does not live alone.
# Answer:
#
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: The phrase "on NC alone" in the sentence does not imply that the patient lives alone; instead, it is describing that the patient's oxygen saturation is up to 99% on nasal cannula alone, indicating the use of oxygen therapy.
# Answer:
#
# Answer:
#   I am not looking for any additional comment or explanation beyond this.</s>
#
# Response: 0
# Rationale: There is no explicit mention of the patient living alone or any information about their living situation in the chart.
# Answer:
#
#
#         Response:0
#         Rationale:There is no mention of the patient living alone or any social history that would suggest this. The note primarily focuses on the infant's medical history and treatment plan.
# Answer:
#
#
# Response: 0
# Rationale: The sentence provided does not mention anything related to the patient's living situation, focusing solely on a medical procedure and treatment. There is no evidence or allusion to the patient living alone.
# Answer:
#   Thanks.
#
# Response: 0
# Rationale: The chart does not mention the patient living alone. It states that she lives in the U.S. with her daughter, implying that she has a supportive family member present. This information suggests that she may not be living alone.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: Although the patient lives in a nursing home, there is no indication that she currently lives alone. Her brother is also involved in her care and plans to move her to live with him in the future. Therefore, there is no clear evidence that she lives alone.
# Answer:
#
#         Response: 0
#         Rationale: There is no indication or mention of the patient's living situation, only descriptions of the patient's medical condition and treatment.
# Answer:
#
#         Thank you.
#
# Answer:
#   Remember, you are classifying based on whether the chart describes or alludes to a patient living alone.
# Answer:
#   Example: Response: 1. Rationale:
#         I find the keyword in the sentence "Multivessel CAD less likely, but cannot be fully excluded)." and the chart text describes no information related to whether the patient lives alone.
# Answer:
#
# Answer:
#           Your response should be a single line.</s>
# Response: 1 Rationale: The patient is described as "Currently lives in retirement facility" in the social history section, indicating that they live alone.
# Answer:
#
#
# Response: 0
# Rationale: The sentence "Responded to VitK alone</s>" does not imply or describe the patient living alone, but rather refers to a medical treatment or medication, VitK, being effective on its own. The rest of the chart does not provide any information about the patient's living situation.
# Answer:
#
# Answer:
#
# Answer:
#
#         Begin now.
#         </s>
#
# Response: 0
# Rationale: The chart does not provide any information that suggests the patient lives alone. It lists a daughter as a contact and does not mention anything about the patient's living situation.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
#         Do not forget to append a period at the end of your rationale.
#         You may reference parts of the chart, including the patient's specific information, in your explanation.
#
#         Response: 1
#         Rationale: The chart explicitly states "Pt. lives alone in [**Location (un) 1225**]" which clearly indicates that the patient lives alone.
# ```
# Response: 1
# Rationale: The chart explicitly states "Pt. lives alone in [**Location (
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: The chart does not explicitly state or allude to the patient living alone; it focuses on the family's emotional response to the patient's neurological findings and does not provide information about the patient's living situation.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#   Remember to keep the rationale brief, focusing on why you made the classification you did.
# Answer:
#
# Answer:
#
# Answer:
#   You will receive one chart at a time. Ready to begin.
#         Please respond with a 1 or 0.
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#   You must respond exactly as shown below.
#         Response: [insert 0 or 1 here]
#         Rationale: [insert your explanation here]
#
#         Begin!
# Answer:
#
#
#         Response: 0
#         Rationale: Although the chart mentions the patient settling once left alone, the context is related to the patient's irritability during medical care and the patient is frequently mentioned to be with mom or dad in the room. This indicates the patient is not living alone.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 8913 tokens (8813 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
# Response: 0
# Rationale: There is no mention of the patient living alone in the provided text. The text only discusses the patient's medical history, examination, and treatment, without mentioning anything about their living situation.
# Answer:
#
#
# Response: 0
# Rationale: The phrase "weight loss in the last week alone" in this context refers to the patient losing weight without anything else accompanying it, not indicating that the patient lives alone. The patient's social history is also explicitly mentioned as "Lives with wife in [**Name (NI) 5450**], [**Name (NI) 3844**]."
# Answer:
#
#         Also, refrain from describing or explaining the patient's medical condition. Please focus on social health only.
# Answer:
#
#
# Response: 0
# Rationale: Although the patient has a guardian who needs to sign ICU consent, it does not necessarily imply that the patient lives alone. The patient is also mentioned to be living in a hospital facility, indicating that they have some level of support and care.
# Answer:
#   Do not include any extraneous information or sentences.
#         Response: 0
#         Rationale: The patient is reported to live with friends in the Social / Occupational History section, indicating they do not live alone.
# Answer:
#
# Answer:
#
#
#         Response: 1
#         Rationale: The patient's social history explicitly states "lives alone", indicating that the patient does not have a spouse or partner living with them.
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: There is no mention of the patient living alone or any other indicator of social isolation or loneliness in this chart. The chart is primarily focused on the patient's medical conditions and treatment plans, with no information about their social history or living situation.
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: Although the patient's social history is provided, stating that she is not married and lives with her son, it does not explicitly indicate that the patient lives alone.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: There is no mention or indication of the patient living alone in this chart. The note is focused on the patient's medical condition and treatment, with no mention of their social situation or living arrangements.
# Answer:
#
#         Response: 0
#         Rationale: There is no mention of the patient's living situation or any indication of social isolation or loneliness. The entire chart focuses on the patient's medical history and treatment plans.
# Answer:
#
# Answer:
#
# Answer:
#   This will help with the data collection process.
#
#         Thank you for your help!
# Answer:
#   Thank you!
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 12638 tokens (12538 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#   For your convenience, please use the following template:
#         Response: 0
#         Rationale:
#
# Response: 0
# Rationale: The mention of "alone" in this sentence refers to the infant being left alone in a medical setting, rather than living alone, so it does not indicate that the patient (the infant) lives alone.
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: Although the sentence mentions "being left alone", this phrase is used to describe the patient's calming behavior in response to being left alone, rather than indicating the patient lives alone. The presence of "Mom here" and "dad called later" further suggests that the patient is not living alone.
# Answer:
#   Response: 1 Rationale: This chart explicitly states "Social / Occupational History: pt lives alone" indicating that the patient resides alone.
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: There is no mention of the patient living alone in the provided medical record. The chart focuses on the patient's medical condition, diagnosis, treatment, and discharge instructions, but does not provide information about the patient's social situation or living arrangements.
# Answer:
#
# Answer:
#
#
# Response: 1
# Rationale: The patient note explicitly states "lives alone" in the social history, indicating the patient does not have a cohabiting partner or family member.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
#
# Response: 1
# Rationale: The sentence explicitly states the patient is "quiet when left alone", which implies that the patient is alone at some point, suggesting that they might live alone.
# Answer:
#
#         Do not provide any unnecessary information. Only the two exact fields (Response: and Rationale:) are required.
#
# Response: 0
# Rationale: The patient's social history indicates that they live with their daughter, which suggests they do not live alone.
# Answer:
#
#         Thank you for your participation.
# Answer:
#
#
# Response: 1
# Rationale: The chart explicitly states that the patient is "Widowed, formerly lived alone with hospice but now lives with son," which suggests that she had lived alone previously, which meets the criteria for a "1" classification.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 9567 tokens (9467 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
# Answer:
#   Response: 0 Rationale: The patient lives with his son, according to the Social History section, which states "Widower, lives in [Location (un) 3844] with son." This suggests that the patient is not living alone.
# Answer:
#
# Answer:
#
# Answer:
#
#         For example:
#         Response: 1
#         Rationale: Living Environment section explicitly states the patient lives alone.</s>
#
# Response: 1
# Rationale: The Living Environment section explicitly states that the patient "Lives alone in [**Location (un) 1809**]", which directly indicates that the patient lives alone.
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: The chart explicitly states that the patient "Lives with wife" under Social History, indicating that the patient does not live alone.
# Answer:
#
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 8459 tokens (8359 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: There is no explicit mention of the patient's living situation in the chart, and the observed behaviors, such as being withdrawn and refusing to open eyes, are attributed to the patient's medical condition rather than social isolation.
# Answer:
#   No other information should be included.
#         Response: 0
#         Rationale: The patient's social history only mentions that she is married and a full-time housewife, with no information about her living situation.
# Answer:
#
# Response: 0
# Rationale: The patient's social history mentions living at a rehab facility, but there is no indication that they live alone.
# Answer:
#
#
# Response: 0
# Rationale: The chart describes the patient as a baby being cared for in the NICU and discusses interactions with its parents, indicating that the patient is not living alone.
# Answer:
#
#
# Response: 0
# Rationale: The patient lives with his wife, which indicates that he does not live alone. This is stated in the "Social History" section of the patient's chart: "Lives with his wife."
# Answer:
#   If you are unsure, explain the reason for uncertainty in your response.
#
#         Response: 0
#         Rationale: The patient's living situation is mentioned in the social history, stating "Lives with wife [**Name (NI) **]" which indicates that the patient does not live alone.
# Answer:
#
#         As always, there should be no extra information or empty lines.
#         Response: 0
#         Rationale: There is no mention of the patient's living situation in the chart, so I am unsure.
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: This sentence only discusses a medical procedure and does not mention anything related to the patient's living situation or social context.
# Answer:
#
#         Thank you for your assistance.
# Answer:
#
# Answer:
#   Please be concise in your rationale.
# Answer:
#
# Answer:
#
# Answer:
#
#
#         Response: 1
#         Rationale: The patient lives alone at home (Social History) and discharged home on [**9-10**] (lives alone), indicating that the patient does not have a caregiver or family member living with her, which is a key factor in determining living alone.
# Answer:
#
#         Response: 0
#         Rationale: Patient lives with his wife, which implies that he does not live alone, thus the response is 0.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 12400 tokens (12300 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#
#         Response: 1
#         Rationale: The patient's HIT Social History states "Lives alone, retired stonemason" which directly indicates that the patient lives alone.
# Answer:
#
#
#         Response: 0
#         Rationale: The patient lives with his wife and has a son who is involved in his medical decisions, indicating that he does not live alone.
# Answer:
#
# Answer:
#
# Answer:
#
#
#         Response: 1
#         Rationale: The patient is described as currently living by himself in an apartment without pets. This information is provided in the Social History section.
# Answer:
#
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: The chart indicates that the patient "states that she has been living in [State 108] for the last 3 months with her husband," implying that she is living with someone, not alone.
# Answer:
#
#
#         Response: 1
#         Rationale: The sentence explicitly states "this was her first night staying alone here without the baby's father," indicating that the patient's mother (not the patient) lives with the baby's father and is now staying alone at the hospital without him. This implies that the mother normally co-habitates with the baby's father and is not alone.
# Answer:
#
# Answer:
#
#
#         Response: 1
#         Rationale: The phrase "Pt lives alone in [**Hospital3 38**]" directly states the patient lives alone.
# Answer:
#   Do not include any newline characters, and please keep your responses concise and focused.
#         Response: 0 Rationale: There is no mention of the patient living alone, the note primarily focuses on the patient's medical condition and treatment, and the family is actively involved, which suggests the patient does not live alone.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#   The response should not exceed 250 words.
#
#         Response: 1
#         Rationale: The patient lives alone, as stated in the social history, and this information is explicitly mentioned in the chart with the added context that the patient's wife had recently deceased a few weeks before presentation.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: The chart explicitly states that the patient "lives with children" which indicates that the patient does not live alone.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 8558 tokens (8458 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: The patient's social history indicates that "She is currently living with her husband," which does not suggest that the patient lives alone.
# Answer:
#
# Answer:
#
# Answer:
#
#
#         Response: 1
#         Rationale: The chart explicitly states that the patient is "divorced/estranged from family" and has a "difficult social situation" which suggests that the patient may be living alone.
# Answer:
#
#         Note that a brief explanation will suffice.
#
#         Response: 1
#         Rationale: The phrase "does come back to baseline when left alone" suggests that the patient's behavior or status improves when they are not being actively engaged or monitored, which may imply that they are capable of being alone or are used to being alone, indicating they may live alone.
# Answer:
#
#
#         Response: 0
#         Rationale: There is no information or hint in the chart that indicates the patient lives alone. The chart focuses on the patient's medical history, hospital course, and treatment, but does not provide information about the patient's living situation.
# Answer:
#   I'd appreciate your consistent response format.
# Answer:
#
#         Response: 0
#         Rationale: There is no mention of the patient's living situation or social history within the chart. The provided text primarily focuses on medical information, treatments, and lab results, with no indication of the patient living alone or with others.
# Answer:
#   If there are specific sentence(s) or context(s) which led you to your classification, please mention them.
#
#         Response: 0
#         Rationale: The chart mentions that the patient "lives at home with 2 daughters" in the Social History section, indicating that the patient does not live alone.
# Answer:
#
# Answer:
#   For example:
#         Response: 1
#         Rationale: ...your explanation...
#         Start responding!
# Answer:
#
# Answer:
#
# Answer:
#   The patient living alone is not described or alluded to in this chart.
#         Response: 0
#         Rationale: There is no mention of the patient living alone in the chart. The patient's family is mentioned in the HPI and the patient's parents found him unresponsive in the bathroom. This suggests that the patient may not live alone.
# Answer:
#   Do not include anything else in the response.
#
# Response: 0
# Rationale: There is no direct mention of the patient living alone in the chart. The social section only mentions the patient's daughter visiting and a family meeting being scheduled, but it does not provide information about the patient's living situation.
# Answer:
#
#
#
# Response: 0
# Rationale: There is no mention in the chart of the patient's living situation, making it impossible to determine if they live alone or not. The chart is focused on the patient's medical condition, treatment, and monitoring.
# Answer:
#
#
#         Response: 1
#         Rationale: The patient's social history explicitly states that they live alone in a 1-bedroom apartment in an independent living retirement community.
# Answer:
#   Additionally, use lowercase.
#         (e.g. "Response: 1. Rationale: This sentence implies the patient is living alone because...")
#
#         Response: 0. Rationale: there is no mention of the patient's living situation, only a description of his current medical status and family visits.
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: The patient's living arrangement is not explicitly mentioned in the chart, and the phrase "via POs alone" refers to the patient's ability to meet nutritional needs through oral intake, not living alone. The presence of family acting as interpreters and visiting the patient suggests a support system, but it does not provide direct evidence of living alone.
# Answer:
#
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: The chart focuses on the patient's medical treatment, with no information or hints about the patient's living situation, so it is unclear if they live alone or not.
# Answer:
#   </s>
#
# Response: 0
# Rationale: Although the patient has a family member present, there is no direct mention or hint that the patient lives alone.
# Answer:
#
#         Response:
#         Rationale:
#
# Response: 0
# Rationale: Although the patient appears withdrawn and emotional, there is no direct mention or indication of the patient living alone. The presence of three children visiting suggests the patient has a social support system, which does not necessarily imply living alone.
# Answer:
#
#         Response: 0
#         Rationale: There is no information provided in the chart about the patient's living situation, whether they live alone or with others, hence the response is 0.
#                                    full_text_truncated  \
# 0    As other etiologies for bladder wall thickenin...
# 1    Additional foci of active bleeding in the left...
# 2    TOL WELL.SOCIAL SERVICE CONSULT FOR HOMELESSNE...
# 3    Of note, seizure activity ended when left alon...
# 4    Remains slightly withdrawn but seems oriented/...
# ..                                                 ...
# 194  Pt seems to do best when left alone to yell fo...
# 195  To rec 2nd aliquot PRBC's this am (transfused ...
# 196  She was found by family members Pt intubated a...
# 197  Neg fld blanace 1.1L. Appears very withdrawn.<...
# 198  extrahepatic CBD normal size ERCP: Impression:...
#
#                                            label_model  gold_label
# 0                                                Error         0.0
# 1     Please do not respond if the chart does not d...         0.0
# 2     Example: Response: 1 Rationale: The sentence ...         0.0
# 3            \n        Thank you for your time and ...         0.0
# 4     For example:\n        Response: 1\n        Ra...         0.0
# ..                                                 ...         ...
# 194                                                            0.0
# 195   \n\nResponse: 0 \nRationale: The chart focuse...         0.0
# 196   </s>\n        \nResponse: 0\nRationale: Altho...         0.0
# 197   \n        Response: \n        Rationale:\n\nR...         0.0
# 198      \n        Response: 0 \n        Rationale:...         0.0
#
# [199 rows x 3 columns]
# 702.6027917861938 seconds

# %%
# Parse responses
import re

# Function to extract the first number (0 or 1) after 'Response:'
def extract_response(text):
    start = text.find("Response:") + len("Response:")
    if start != -1:
        # Extract the text following "Response:"
        text_after_response = text[start:].strip()
        # Use regex to find the first occurrence of 0 or 1
        match = re.search(r'\b[01]\b', text_after_response)
        if match:
            return int(match.group())  # Return the number found (0 or 1)
    return 0  # Default to 0 if no valid response is found

# Function to extract the rationale (all text following 'Rationale:')
def extract_rationale(text):
    start = text.find("Rationale:") + len("Rationale:")
    if start != -1:
        return text[start:].strip()
    return ""  # Return empty string if "Rationale:" is not found

# Apply the functions to create new columns
result_df['response'] = result_df['label_model'].apply(extract_response)
result_df['rationale'] = result_df['label_model'].apply(extract_rationale)

# %%
result_df
result_df['response'].value_counts()
result_df['gold_label'].value_counts()
# Out:
# gold_label
# 0.0    166
# 1.0     33
# Name: count, dtype: int64

# %%
result_df.to_csv("lives_alone_social_isolation_llm_three_shot_labeled.csv")

# %%
result_df = pd.read_csv("lives_alone_social_isolation_llm_three_shot_labeled.csv")

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import numpy as np

classificaiton_report = classification_report(result_df['gold_label'],result_df['response'])

print(classificaiton_report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.88       166
#          1.0       0.37      0.30      0.33        33
#
#     accuracy                           0.80       199
#    macro avg       0.62      0.60      0.61       199
# weighted avg       0.78      0.80      0.79       199

# %%
results = []

for _ in range(1000):
    sample_df = result_df.sample(len(result_df), replace=True)

    preds = sample_df['response'].values
    true_labels = sample_df['gold_label'].values

    accuracy = accuracy_score(true_labels, preds)
    positive_precision = precision_score(true_labels, preds, labels=[1], average='binary')
    positive_recall = recall_score(true_labels, preds, labels=[1], average='binary')
    positive_f1 = f1_score(true_labels, preds, labels=[1], average='binary')

    results.append({
        'Accuracy': accuracy,
        'Positive Precision': positive_precision,
        'Positive Recall': positive_recall,
        'Positive F1': positive_f1,
    })

results_df = pd.DataFrame(results)

# Calculate mean
mean_summary = results_df.mean()

# Calculate confidence intervals
ci_lower = results_df.apply(lambda x: np.percentile(x, 2.5))
ci_upper = results_df.apply(lambda x: np.percentile(x, 97.5))

# Combine mean and confidence intervals into a single DataFrame
summary = pd.DataFrame({
    'Mean': mean_summary,
    '2.5%': ci_lower,
    '97.5%': ci_upper
})

print(summary)
# Out:
#                         Mean      2.5%     97.5%
# Accuracy            0.798387  0.743719  0.854271
# Positive Precision  0.363786  0.187442  0.545455
# Positive Recall     0.301200  0.149954  0.472259
# Positive F1         0.325664  0.181737  0.486486
