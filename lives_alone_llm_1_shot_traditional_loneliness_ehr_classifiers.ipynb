# %%
# !python -m venv --copies awalk55

# %%
# %cd /mnt/beegfs/labs/bozkurtlab/drew-projects/loneliness-ehr/
# %ls
# Out:
# /mnt/beegfs/labs/bozkurtlab/drew-projects/loneliness-ehr
# acute_social_isolation_llm_labeled.csv
# acute_social_isolation_results.csv
# ajudication-reliability-files/
# annotation_Drew_sample_social_disconnection_DW.csv
# annotation_Selen_sample_social_disconnection_SB.csv
# awalk55/
# chronic_social_isolation_llm_3_shot_labeled.csv
# chronic_social_isolation_llm_labeled.csv
# chronic_social_isolation_llm_one_shot_labeled.csv
# chronic_social_isolation_results.csv
# gold_standard_social_isolation_1000.csv
# lives_alone_results.csv
# lives_alone_social_isolation_llm_labeled.csv
# lives_alone_social_isolation_results.csv
# summary_models_acute_social_isolation.csv
# summary_models_chronic_social_isolation.csv
# summary_models_lives_alone.csv
# summary_models_lives_alone_social_isolation.csv
# /opt/modules/Python/3.11.5/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import requests
import pandas as pd
import numpy as np
# %ls
# Out:
# acute_social_isolation_llm_labeled.csv
# acute_social_isolation_results.csv
# ajudication-reliability-files/
# annotation_Drew_sample_social_disconnection_DW.csv
# annotation_Selen_sample_social_disconnection_SB.csv
# awalk55/
# chronic_social_isolation_llm_3_shot_labeled.csv
# chronic_social_isolation_llm_labeled.csv
# chronic_social_isolation_llm_one_shot_labeled.csv
# chronic_social_isolation_results.csv
# gold_standard_social_isolation_1000.csv
# lives_alone_results.csv
# lives_alone_social_isolation_llm_labeled.csv
# lives_alone_social_isolation_results.csv
# summary_models_acute_social_isolation.csv
# summary_models_chronic_social_isolation.csv
# summary_models_lives_alone.csv
# summary_models_lives_alone_social_isolation.csv

# %%
# lives_alone_label, acute_social_disconnection_label
df_concat = pd.read_csv("gold_standard_social_isolation_1000.csv")
df_concat.info()
# Filter out training
exclude_ids = [4265489,1056798] 
exclude_ids = np.array(exclude_ids, dtype=np.int64)
# Exclude the specified Sentence_ID 
df_concat_filtered = df_concat[~df_concat['Sentence ID'].isin(exclude_ids)] 



# Chronic social isolation classifier
chronic_df = df_concat_filtered[['full_text_truncated', 'lives_alone_label']]

# Display the first few rows of chronic_df
chronic_df.info()
chronic_df.head()
unique_chronic_values = chronic_df['lives_alone_label'].value_counts().reset_index()

# Renaming columns for clarity
unique_chronic_values.columns = ['lives_alone_label', 'count']
unique_chronic_values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          1000 non-null   int64
#  1   Sentence ID                         1000 non-null   int64
#  2   TEXT                                1000 non-null   object
#  3   Sentence                            1000 non-null   object
#  4   matched_term                        1000 non-null   object
#  5   chronic_social_disconnection_label  1000 non-null   float64
#  6   lives_alone_label                   1000 non-null   float64
#  7   acute_social_disconnection_label    1000 non-null   float64
#  8   full_text                           1000 non-null   object
#  9   full_text_truncated                 1000 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 78.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 998 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   full_text_truncated  998 non-null    object
#  1   lives_alone_label    998 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 23.4+ KB
#    lives_alone_label  count
# 0                0.0    811
# 1                1.0    187

# %%
# %pip install seaborn
# %pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/awalk55/.local/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from seaborn) (1.26.2)
# Requirement already satisfied: pandas>=1.2 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/awalk55/.local/lib/python3.11/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/awalk55/.local/lib/python3.11/site-packages (3.9.1)
# Requirement already satisfied: click in /home/awalk55/.local/lib/python3.11/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /home/awalk55/.local/lib/python3.11/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/awalk55/.local/lib/python3.11/site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /home/awalk55/.local/lib/python3.11/site-packages (from nltk) (4.66.5)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
train_size = 0.8
train_data=chronic_df.sample(frac=train_size,random_state=0)
test_data=chronic_df.drop(train_data.index).reset_index(drop=True)
train_data = train_data.reset_index(drop=True)

print("FULL Dataset: {}".format(df_concat.shape))
print("TRAIN Dataset: {}".format(train_data.shape))
print("TEST Dataset: {}".format(test_data.shape))
# Out:
# FULL Dataset: (1000, 10)
# TRAIN Dataset: (798, 2)
# TEST Dataset: (200, 2)

# %%
import requests
import pandas as pd
from datetime import datetime
import time

start_time = time.time()

def request(query):
    # Define the headers
    headers = {
        'Content-Type': 'application/json'
    }
    
    # Define the data
    data = {
        "model": model_name,
        "prompt": query,
        "max_tokens": max_tokens,
        "temperature": 1,
        "top_p": 0.95,
    }
    
    # Make the POST request
    response = requests.post(url, headers=headers, json=data)
    
    # Check if the response is successful
    if response.status_code == 200:
        response_json = response.json()
        
        # Check if the 'choices' key exists
        if 'choices' in response_json:
            answer = response_json['choices'][0]['text']
            print('Answer:\n', answer)
            return answer
        else:
            print("Error: 'choices' key not found in the response.")
            print("Full response content:", response_json)
            return None
    else:
        print(f"Error: Received status code {response.status_code}")
        print("Response content:", response.content)
        return None

def process_dataframe(df, model_name, max_tokens, url):
    results = []
    
    for index, row in df.iterrows():
        prompt = f'''
        You are an expert in abstracting social health from medical language, focused on studying the documentation of social isolation and loneliness within an intensive care unit's electronic health record.
        Read the following sentence, appended by </s> and the full patient note text, and respond with a 1 or 0. Respond with “1” if the chart describes or alludes to a patient living alone. 
        Respond with “0” if the chart does not, if there is not enough evidence of a patient living alone in the chart, or if you are otherwise unsure. 
        After the response, write a short sentence describing the rationale behind the 1/0 classification.

        To assist you with classification, below are one example of a 1-labeled sentence, without the full chart, where patient living alone is present and a 0-labeled sentence where it is not:
        1: Social History: Not married, lives alone.
        0: While the sharp activity may come from the encephalopathy (plus a focal lesion) alone, the rhythmicity and particularly sharp features indicate a risk for seizures, particularly with focal onset in the right frontal region.

        
        Read the following sentence matching a related keyword, which is appended by </s> and followed by the entire chart carefully:
        {row['full_text_truncated']}
        Please strictly format each response beginning with "Response:" followed by either 0 or 1, then "Rationale:" followed by your explanation.'''
        
        answer = request(prompt)
        if answer is not None:
            results.append({'full_text_truncated': row['full_text_truncated'], 'label_model': answer, 'gold_label': row['lives_alone_label']})
        else:
            results.append({'full_text_truncated': row['full_text_truncated'], 'label_model': 'Error', 'gold_label': row['lives_alone_label']})
    
    return pd.DataFrame(results)

# Model parameters
model_name = 'meta-llama/Meta-Llama-3-70B-Instruct'
max_tokens = 100
url = 'http://llm1.priv.bmi.emory.edu:8000/llama3_70B/v1/completions'


# Process the DataFrame
result_df = process_dataframe(test_data, model_name, max_tokens, url)

print(result_df)
end_time = time.time()
duration = end_time - start_time
print(f"{duration} seconds")
# Out:
# Answer:
#   Be cautious not to make assumptions about patient living situation. Only use the chart information to determine your classification.
#         Ready when you are!
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 9204 tokens (9104 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
# Answer:
#   In this case, the sentence mentions "Social: Found down in apartment alone," indicating the patient lives alone, hence the 1 classification.
# Answer:
#
#
# Response: 1
# Rationale: The social history section of the chart mentions that the patient "lived alone at home - retired", which indicates that the patient resides alone.
# Answer:
#   Do not provide unnecessary text.
#         Response: 1
#         Rationale: The patient states he lives alone.
# Answer:
#
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: The chart text does not contain any information about the patient's living situation. The mention of the daughter calling to check on the mother suggests that the patient is not alone, but it does not directly imply that they do not live alone.
# Answer:
#
# Answer:
#
#         There should be no other information in your response other than the classified response and its rationale.
#
# Response: 0
# Rationale: The sentence does not provide any information about the patient's living situation, and the rest of the chart does not mention the patient living alone or with someone else.
# Answer:
#
# Answer:
#
#
#         Response: 1
#         Rationale: The sentence "Lives alone in [**Location (un) **]." explicitly indicates that the patient lives alone.
# Answer:
#   Use only the provided information from the chart.
#
#         Response: 0
#         Rationale: There is no mention or indication of the patient living alone in the provided chart. The chart focuses on the patient's medical history, surgical procedures, and post-operative care instructions, with no social history or information about the patient's living arrangements.
# Answer:
#
#         Please respond to the sentence appended with </s>.
#
#         Response: 0
#         Rationale: The chart does not mention anything about the patient's living situation, and there is no information provided about the patient living alone.
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: There is no information in the chart that explicitly states the patient lives alone. The patient has a wife, which suggests they may not live alone.
# Answer:
#
#
#         Response: 0
#         Rationale: The patient lives with her husband in [**Name (NI) 13011**], which indicates that she does not live alone.
# Answer:
#
#
# Response: 1
# Rationale: The patient "continued to ask to be left alone", indicating that they do not have someone to provide emotional support or companionship, implying that they might be living alone.
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: The chart is focused on a medical procedure and contains no information or hints about the patient's living situation.
# Answer:
#
#         Strictly adhere to this format.
# Answer:
#
#
# Response: 0
# Rationale: The sentence "Pt depressed withdrawn, minimlally interactive with family members" may suggest the patient is having trouble interacting with others, but the presence of a husband and sister-in-law visiting briefly indicates they are not living alone.
# Answer:
#
#
#         Response: 1
#         Rationale: The phrase "anxious when alone in rm" implies that the patient is alone in their room, which in turn implies that they are living alone as no other individuals are mentioned in the social history section.
# Answer:
#
#
#         Response: 0
#         Rationale: This patient lives with her daughter, as stated in the Social History section of the chart, which indicates that she is not living alone.
# Answer:
#
# Answer:
#   Examples are provided.
#
#         Response: 0
#         Rationale: The sentence does not mention whether the patient lives alone or with someone.
#
#         Please respond to the sentence given.
# Answer:
#
# Response: 0
# Rationale: There is no language indicating the patient's living situation or social history in the provided chart note. The entire note focuses on the patient's medical treatment and current condition.
# Answer:
#
# Answer:
#
#         Response: 0
#         Rationale: This chart does not explicitly mention the patient living alone, and there is no evidence or hint of it throughout the entire patient note.
# Answer:
#
# Answer:
#
#
#         Response: 1
#         Rationale: The chart explicitly states "Social History: - lives alone", indicating that the patient lives alone.
# Answer:
#
#         I'm looking forward to your thoughtful response.
# Answer:
#
#
# Response: 0
# Rationale: The patient lives with his wife, who is his primary caretaker, indicating that he does not live alone.
# Answer:
#
# Answer:
#   For example: Response: 1 Rationale: The chart directly states that the patient took a few steps to the commode "alone".
#         Response: 0 Rationale: There is no mention of the patient's living situation in this chart.
#
#         Go ahead and respond.
#
#         Response: 1
#         Rationale: The chart directly states that the patient took a few steps to the commode "alone", which implies the patient is capable of doing certain activities without assistance, suggesting
# Answer:
#
#
#
#         Response: 0
#         Rationale: The patient lives with her daughter, as stated in the Social History section, indicating she does not live alone.
# Answer:
#
# Answer:
#
#         Response:
#         Rationale:
# Answer:
#   Example:
#         Response: 0
#         Rationale: There is no mention of the patient's living situation in this chart.
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: The chart focuses on medical status and treatment with no mention of the patient's living arrangements or social situation, indicating no evidence of living alone.
# Answer:
#
#
#
#
# Response: 0
# Rationale: The chart does not explicitly mention the patient living alone. It does mention the patient is divorced and has a son, but it does not provide information about his current living situation.
# Answer:
#
#         Response: 1
#         Rationale: The phrase "pt is unsafe to be left alone" in the "Activity" section indicates that the patient requires constant supervision and is at risk of harm if left alone, implying they live alone.
# Answer:
#
# Answer:
#   Also, please make sure to elaborate on your reasoning, and not just say "it has/does not mention".
#
#
#         Response: 0
#         Rationale: Although the chart discusses the patient's living situation, it mentions that "The patient lives with his son who is the only caretaker; is completely dependent on him for ADLs, IADLs," indicating that the patient does not live alone. This suggests that the patient has some level of support and assistance in their daily
# Answer:
#
#         Response: 0
#         Rationale: The chart does not mention anything about the patient living alone, it only mentions that the patient is "married to a nurse, with 3 sons" in the Social History section, indicating that the patient has a family and is not living alone.
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: This sentence does not mention the patient's living arrangement, it only mentions the daughter visiting and there is no evidence of the patient living alone.
# Answer:
#
# Answer:
#
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 9339 tokens (9239 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#   Response: 0 Rationale: The chart does not mention the patient's living situation or provide any relevant information about social isolation or loneliness.
# Answer:
#
#
#
#         Response: 0
#         Rationale: There is no mention of the patient's living situation or marital status in the chart, and no information about the patient living alone can be inferred from the description of their behavior or interactions with their daughters. The presence of daughters at the bedside and their supportive behavior suggests a possible support system for the patient, but does not provide conclusive evidence about the patient's living arrangements.
# Answer:
#
#
#
# Response: 0
# Rationale: The sentence does not explicitly state that the patient lives alone. The patient's wife is mentioned several times in the chart, indicating that the patient is married and has a wife who is involved in his care. There is no mention of the patient living alone or having no family support.
# Answer:
#
#
#
#
# Response: 1
# Rationale: The chart explicitly states "lives alone" under the Social / Occupational History section, indicating the patient's living situation.
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: There is no mention of the patient's living situation or social status in this chart, so we cannot determine if the patient lives alone. The chart primarily focuses on the patient's medical conditions and treatment.
# Answer:
#   Do not include any other information.</s>Response: 1 Rationale: The patient's social history explicitly states "Lives alone, wife died in [**2168**]", indicating that the patient is a widower living alone.
# Answer:
#
#         Keep your responses as concise as possible and make sure to mention the relevant keywords or phrases that led you to your classification.
#
#         I look forward to your classification!
# Answer:
#
#
#         Response: 0
#         Rationale: There is no mention of the patient's living situation or personal life that would suggest they live alone.
# Answer:
#
#
#
#         Response: 1
#         Rationale: The occupation section mentions that "The patient currently lives in [**Location (un) 3425**] alone" which explicitly indicates that the patient lives alone.
# Answer:
#
# Answer:
#
#
# Response: 1
# Rationale: The sentence "He has been widowed for 8 years and lives alone in [**Location (un) 341**]" explicitly states that the patient lives alone.
# Answer:
#
# Answer:
#
# Answer:
#   Do not include any extra lines or characters.
#         Response: 0
#         Rationale: The patient's social history mentions her occupation as a hairdresser, but there is no mention of her living arrangements or social connections that would indicate she lives alone.
# Answer:
#
#
#         Response: 0
#         Rationale: There is no mention of the patient living alone in the entire chart. The social history mentions that he "Lives in [Location 5583] MA. Currently on disability, previous employed as welder", but there is no indication of living arrangement.
# Answer:
#          Response: 0 Rationale: The chart primarily discusses the patient's medical condition, treatment, and wife's concerns, but does not explicitly mention or imply that the patient lives alone.
# Answer:
#   Also, use the entire space provided. If you need more space, let me know.
#
#         Response: 1
#         Rationale: The chart explicitly states, "She currently lives alone with 2 cats" in the social history section, indicating that the patient lives alone.
# Answer:
#
# Answer:
#
#         Do not include any additional information or commentary beyond the prescribed format.
# Answer:
#
#
# Response: 1
# Rationale: The patient's social history indicates that they "Lives alone in an apartment", which suggests that they live alone.
# Answer:
#
#
# Response: 0
# Rationale: There is no explicit mention of the patient living alone in the given chart, and the keywords that stand out are related to the patient's medical condition and treatment, but not their living situation.
# Answer:
#
#         Please keep your responses brief and to the point.
#
#
#         Response: 0
#         Rationale: The patient does not live alone, as per the chart, they live with friends.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
#         Remember to consider the entire chart while making your classification.
#         Please pay attention to the task of determining whether or not the chart describes or alludes to a patient living alone.
# Answer:
#
#
# Response: 1
# Rationale: The chart explicitly states that the infant "settles when left alone," which implies that the infant is being cared for without a permanent caregiver present, suggesting that the infant's primary caregiver may be living alone.
# Answer:
#
# Answer:
#   Please do not add any extra text or commentary in your responses.
#         Response: 0
#         Rationale: There is no mention of the patient's living arrangements or social history indicating they live alone.
# Answer:
#
#
#         Response:0
#         Rationale: The sentence mentions someone leaving the infant's room for alone time, but this does not indicate the person's living situation. It is likely they were taking time away from the infant's room for personal reflection or to clear their mind.
# Answer:
#   For this chart, you would respond as follows:
#         Response: 0
#         Rationale: There is no mention of the patient living alone or any allusion to this fact. The patient had a wife who was involved in the care decisions.
# Answer:
#   So, for example:
#         Response: 0
#         Rationale: There is no indication in the chart that the patient lives alone.
#
#         Response:
#         Rationale:
# Answer:
#
#
#         Response: 0
#         Rationale: There is no mention of the patient living alone in the provided chart note, and the chart primarily focuses on the patient's medical condition, treatment, and test results. Therefore, it is not possible to determine whether the patient lives alone or not from the given information.
# Answer:
#
# Answer:
#   Please use only this format.
# Answer:
#
# Answer:
#
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 8816 tokens (8716 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#   </s>
#
#         Response: 0
#         Rationale: There is no explicit mention of the patient living alone in the chart. The chart primarily focuses on the patient's medical history, diagnosis, and treatment, with no information about their living arrangements.
# Answer:
#
#
#         Response: 0
#         Rationale: There is no specific mention or indication that the patient lives alone in the chart. The communication with Son [**Name (NI) **] and the mention of the Resident suggest that there may be family support or contacts available, but there is no explicit information about the patient's living arrangement.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 12316 tokens (12216 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 12554 tokens (12454 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#         You will respond similarly to each subsequent sentence.
# Answer:
#   For example:
#         Response: 1
#         Rationale: This chart explicitly states the patient "lives alone" in the state.
# Answer:
#   Each response should be on a new line for readability.
#
# Response: 0
# Rationale: The chart describes the patient as "Married" under the Social History section, indicating that the patient does not live alone.
# Answer:
#
#
#         Response:0
#         Rationale: There is no mention or evidence suggesting that the patient lives alone, as the presence of "pt s two sons" indicates family support, implying that the patient may have some level of social connection and support system.
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: The patient's husband is mentioned in the chart, indicating that the patient does not live alone.
# Answer:
#
# Answer:
#   Response: 0 Rationale: The chart does not mention the patient's living situation, including whether they live alone or with others. The focus of the chart is on the patient's medical history, hospital course, and treatment, with no information provided about their social situation.
# Answer:
#
# Answer:
#
#
# Response: 1
# Rationale: The sentence "Early in shift she would sleep when left alone" directly indicates that the patient spends time alone, implying that she lives alone or is often left unattended.
# Answer:
#   Do not include extra lines.        Response: 0 Rationale: No mention of patient living alone or any relevant context related to patient living situation is present in the entire chart note.
# Answer:
#
#
#         Response: 0
#         Rationale: There is no mention of the patient's living situation or family dynamics in the chart that would indicate whether the patient lives alone or not. The mention of "Family visited last night" only suggests that the patient has a family, but it does not provide any information about their living arrangement.
# Answer:
#
# Answer:
#
# Answer:
#
#
#         Response: 1
#         Rationale: The phrase "Lives alone" directly indicates the patient lives alone.
# Answer:
#
#
# Response: 1
# Rationale: The chart states "Widowed, formerly lived alone with hospice but now lives with son", indicating that the patient previously lived alone but currently lives with their son.
# Answer:
#
#
#         Response: 0
#         Rationale: There is no mention of the patient living alone or any information that would suggest they live alone. The focus is primarily on the patient's medical history and treatment. The patient's father is mentioned, but there is no indication of their living arrangement.
# Answer:
#   Remember that you are looking for instances of social isolation/loneliness in the documentation, specifically if the patient lives alone. In this case, the response is:
#
#         Response: 0
#         Rationale: There is no mention of the patient's living arrangements or social support in this chart note, hence we cannot determine if the patient lives alone or not.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 9258 tokens (9158 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#   There should be no further text.
#
# Response: 0
# Rationale: The chart does not explicitly mention or suggest the patient lives alone; the concern is about the patient's ability to meet nutrition needs with oral intake alone given their respiratory status, which does not imply living alone.
# Answer:
#
#         Response:
#         Rationale:
# Answer:
#
# Answer:
#
#         You should answer based on your understanding of the patient living alone or not.
#         Please do not add any additional text or explanations beyond your answer and rationale.
#
# Response: 0
# Rationale: The patient lives at home with her husband in [**Name2 (NI) **].
# Answer:
#   Ensure that your responses are precise, clear, and limited to this format.
#
# Response: 1
# Rationale: The chart explicitly states "SOCIAL Hx: The patient lives alone," indicating that the patient resides alone.
# Answer:
#   Do not use any other text or formatting.
#         Response: 0
#         Rationale: The chart explicitly states that the patient lives with his wife and son, indicating that he does not live alone.
# Answer:
#
# Answer:
#   Each response should be on a new line.
#
# Response: 0
# Rationale: There is no mention of the patient's living situation, family, or social support in this chart, therefore it cannot be determined if the patient lives alone or not.
# Answer:
#
# Answer:
#
# Answer:
#
#         Here is a response example:
#         Response: 0
#         Rationale: The chart does not describe or allude to the patient living alone.
# Answer:
#
# Response:0
# Rationale: There is no evidence in the chart suggesting the patient lives alone, and it only mentions her daughter helping with dressing changes. The focus is on her medical history and treatment.
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: The chart is focused on a medical procedure and does not mention the patient's living situation.
# Answer:
#
# Answer:
#
#         Go!
#
# Response: 1
# Rationale: The patient's social history explicitly states "Lives alone at home" which indicates that the patient lives alone.
# Answer:
#   For instance:
#         Response: 1
#         Rationale: The sentence clearly indicates patient living alone.
# Answer:
#   Thank you.
#
#         Response: 0
#         Rationale: The chart does not mention or allude to the patient living alone, but rather mentions that he "Lives with wife" which implies that he has a partner and does not live alone.
# Answer:
#
#
# Response:1
# Rationale: The sentence explicitly states "Lives alone, has pets" in the Social History section of the chart, indicating that the patient lives alone.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 8767 tokens (8667 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#
# Response: 0
# Rationale: There is no mention or allusion to the patient living alone in this chart. The quote "leave me alone" is a figure of speech and not related to the patient's living situation. The focus is on the patient's medical condition, treatment, and interaction with the healthcare team.
# Answer:
#
#
# Response: 1
# Rationale: The patient admits to feeling anxious and lonely, suggesting they might not have a support system or someone to care for them at home, which could imply they live alone.
# Answer:
#
#
# Response: 1
# Rationale: The patient's social history explicitly states "Lives at home alone" indicating that he does not have a spouse or roommate.
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: There is no mention of the patient living alone or any information that would indicate social isolation in the provided chart. The chart focuses on the patient's medical history and current condition, with no mention of their social situation or living arrangements.
# Answer:
#
# Answer:
#
#
#         Response: 1
#         Rationale: The sentence "Patient was born in Poland, Now lives alone in [**Location (un) 583**] with daily care taker visits and [**1-23**] times/week VNA" and another instance "Lives alone" under Social History both explicitly state that the patient lives alone, suggesting that she does not have anyone to provide daily support or companionship.
# Answer:
#
# Answer:
#
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 12711 tokens (12611 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#   </s>
#         Response: 1
#         Rationale: The patient's social history mentions "Lives alone, retired stonemason" indicating the patient is not living with a partner or family members, thus suggesting they live alone.
# Answer:
#   Do not include any additional information.
#
#         Response: 0
#         Rationale: There is no mention of the patient living alone in this chart.
# Answer:
#   This will allow for easy evaluation and feedback on your responses.
#
#         Response: 0
#         Rationale: The chart does not mention the patient living alone, and explicitly mentions that the patient lives with his mother and father who help with his medical care, indicating that he does not live alone.
# Answer:
#
#
#         Response: 1
#         Rationale: The chart describes the patient as currently living by himself in an apartment without pets.
# Answer:
#
#
# Response: 0
# Rationale: There is no mention or allusion to the patient living alone in the provided chart, so I classified it as 0. The phrase "LEFT ALONE" in the sentence is referring to the patient's oxygen saturation levels resolving when they are not disturbed, rather than indicating that the patient lives alone.
# Answer:
#
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 9241 tokens (9141 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#   For example: "Response: 0 Rationale: The chart does not mention or imply a patient living alone."
# Answer:
#
#
# Response: 1
# Rationale: The patient's social history explicitly states "Reports living alone." This suggests that the patient resides alone, supporting a response of 1.
# Answer:
#   For example: Response: 1 Rationale: The chart explicitly mentions the patient lives alone.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 11000 tokens (10900 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: The chart primarily details medical procedures for an infant, with no information provided about the patient's living situation or family dynamics.
# Answer:
#   Be sure to justify your responses with the patient information given in the chart, which does not suggest or indicate that the patient lives alone.
#
#         Response: 0
#         Rationale: The patient note does not mention the patient's living arrangements, marital status, or any information that would suggest the patient lives alone. The chart focuses on the patient's medical history, diagnosis, and treatment plans, but does not provide any information about their social circumstances.
# Answer:
#
#
# Response: 0
# Rationale: There is no indication that the patient lives alone in this chart, only that he was found down in his living [**Apartment Address(1) **] days prior to admission. This suggests he may have some support or that someone else may have been living with him.
# Answer:
#
# Answer:
#
#         Response: 1
#         Rationale: The sentence "Social History: The patient is single/lives alone in [**Location (un) 1411**], never married, no children" explicitly states that the patient lives alone.
# Answer:
#
#
#
#
# Response: 0
# Rationale: The chart does not mention the patient's (infant's) living arrangements, only their behavior when left alone, which could refer to a medical context rather than a living situation.
# Answer:
#
# Answer:
#
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 8261 tokens (8161 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#
# Response: 0
# Rationale: There is no information in the chart indicating whether the patient lives alone or not. While the patient's marital status is mentioned as "not married," this does not necessarily mean they live alone, as they may have other household members. Additionally, there is no other information in the chart that suggests the patient's living situation.
# Answer:
#
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: There is no information present in the chart suggesting that the patient (the infant) or the mother lives alone. The presence of a father and mother visiting and participating in the infant's care indicates a multigenerational household.
# Answer:
#
# Answer:
#
#         Response: 1
#         Rationale: The phrase "Pt divorced/estranged from family" directly suggests that the patient is not living with family members, and their history of occasionally being homeless and living in motels/shelters further implies that they are likely living alone.
# Answer:
#
#
# Response: 1
# Rationale: The chart describes the patient's mother as deemed unsafe by the daughter to live alone at this time, indicating that the mother would normally be living alone but is currently in the hospital due to dementia and increased level of care needed. This implies that the mother, the patient's family member, lives alone.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: The provided chart does not contain explicit information about the patient's living situation or mention of living alone. The text focuses on the patient's medical history, diagnoses, and treatment plans.
# Answer:
#
# Answer:
#   There should be a blank line before and after each response.
#
#
#         Response: 0
# Rationale: There is no indication of the patient living alone in the social history section, which mentions a daughter and a son, indicating a support system, and the patient's residence at a rehab facility.
# Answer:
#
# Answer:
#
#         Please note that only one response per prompt is allowed.
#
# Response: 1
# Rationale: The patient's social history explicitly states that they "Lives alone", indicating that they do not have a roommate or family member living with them.
# Answer:
#
# Answer:
#
#         Response: 0
#         Rationale: The patient is described as having a wife who is present at bedside, and the statement "Pt stated that he felt anxious when left alone" indicates anxiety when the wife stepped out, but not that the patient lives alone. The presence of a wife suggests that the patient does not live alone.
# Answer:
#
#
# Response: 0
# Rationale: This chart focuses primarily on the patient's medical condition, treatment, and vital signs in the ICU, with no mention of their living situation or social history. Therefore, there is no evidence to suggest the patient lives alone.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: The sentence does not describe the patient's living situation outside of the hospital; it only describes the patient's behavior and response to being left alone in the hospital setting.
# Answer:
#
#         Each response must be on a new line.
# Answer:
#
#
# Response: 0
# Rationale: There is no explicit mention of the patient living alone, and the presence of three children visiting at different times suggests that the patient may have a support system.
# Answer:
#
#
#         Response: 0
#         Rationale: The patient is married, has one child, and is going to be discharged to a skilled nursing facility near his home where he will be close to his wife and son. This indicates that he does not live alone.
#                                    full_text_truncated  \
# 0    Ischemic disease was excluded (no EKG changes,...
# 1    As other etiologies for bladder wall thickenin...
# 2    MAE, patient is cooparative with but seems to ...
# 3    Social: Found down in apartment alone.</s>T/SI...
# 4    It may represent extension / recurrence of a t...
# ..                                                 ...
# 195  Action: Sedated while left alone on 200mcg/hr ...
# 196  Pt seems to do best when left alone to yell fo...
# 197  She was found by family members Pt intubated a...
# 198  Neg fld blanace 1.1L. Appears very withdrawn.<...
# 199  extrahepatic CBD normal size ERCP: Impression:...
#
#                                            label_model  gold_label
# 0     Be cautious not to make assumptions about pat...         0.0
# 1                                                Error         0.0
# 2                                                              0.0
# 3     In this case, the sentence mentions "Social: ...         0.0
# 4     \n\nResponse: 1\nRationale: The social histor...         0.0
# ..                                                 ...         ...
# 195                                                            0.0
# 196   \n\n        Response: 0\n        Rationale: T...         0.0
# 197     \n        Each response must be on a new line.         0.0
# 198   \n\nResponse: 0\nRationale: There is no expli...         0.0
# 199   \n\n        Response: 0\n        Rationale: T...         0.0
#
# [200 rows x 3 columns]
# 987.3057780265808 seconds

# %%
# Parse responses
import re

# Function to extract the first number (0 or 1) after 'Response:'
def extract_response(text):
    start = text.find("Response:") + len("Response:")
    if start != -1:
        # Extract the text following "Response:"
        text_after_response = text[start:].strip()
        # Use regex to find the first occurrence of 0 or 1
        match = re.search(r'\b[01]\b', text_after_response)
        if match:
            return int(match.group())  # Return the number found (0 or 1)
    return 0  # Default to 0 if no valid response is found

# Function to extract the rationale (all text following 'Rationale:')
def extract_rationale(text):
    start = text.find("Rationale:") + len("Rationale:")
    if start != -1:
        return text[start:].strip()
    return ""  # Return empty string if "Rationale:" is not found

# Apply the functions to create new columns
result_df['response'] = result_df['label_model'].apply(extract_response)
result_df['rationale'] = result_df['label_model'].apply(extract_rationale)

# %%
result_df
result_df['response'].value_counts()
result_df['gold_label'].value_counts()
# Out:
# gold_label
# 0.0    154
# 1.0     46
# Name: count, dtype: int64

# %%
result_df.to_csv("lives_alone_social_isolation_llm_one_shot_labeled.csv")

# %%
result_df = pd.read_csv("lives_alone_social_isolation_llm_one_shot_labeled.csv")

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import numpy as np

classificaiton_report = classification_report(result_df['gold_label'],result_df['response'])

print(classificaiton_report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.90      0.87       154
#          1.0       0.57      0.43      0.49        46
#
#     accuracy                           0.80       200
#    macro avg       0.71      0.67      0.68       200
# weighted avg       0.78      0.80      0.78       200

# %%
results = []

for _ in range(1000):
    sample_df = result_df.sample(len(result_df), replace=True)

    preds = sample_df['response'].values
    true_labels = sample_df['gold_label'].values

    accuracy = accuracy_score(true_labels, preds)
    positive_precision = precision_score(true_labels, preds, labels=[1], average='binary')
    positive_recall = recall_score(true_labels, preds, labels=[1], average='binary')
    positive_f1 = f1_score(true_labels, preds, labels=[1], average='binary')

    results.append({
        'Accuracy': accuracy,
        'Positive Precision': positive_precision,
        'Positive Recall': positive_recall,
        'Positive F1': positive_f1,
    })

results_df = pd.DataFrame(results)

# Calculate mean
mean_summary = results_df.mean()

# Calculate confidence intervals
ci_lower = results_df.apply(lambda x: np.percentile(x, 2.5))
ci_upper = results_df.apply(lambda x: np.percentile(x, 97.5))

# Combine mean and confidence intervals into a single DataFrame
summary = pd.DataFrame({
    'Mean': mean_summary,
    '2.5%': ci_lower,
    '97.5%': ci_upper
})

print(summary)
# Out:
#                         Mean      2.5%     97.5%
# Accuracy            0.795765  0.740000  0.850000
# Positive Precision  0.573047  0.407378  0.750000
# Positive Recall     0.436536  0.289448  0.577778
# Positive F1         0.492102  0.350877  0.623690
