# %%
# !python -m venv --copies awalk55

# %%
# %cd /mnt/beegfs/labs/bozkurtlab/drew-projects/loneliness-ehr/
# %ls
# Out:
# /mnt/beegfs/labs/bozkurtlab/drew-projects/loneliness-ehr
# acute_social_isolation_llm_labeled.csv
# acute_social_isolation_llm_one_shot_labeled.csv
# acute_social_isolation_llm_three_shot_labeled.csv
# acute_social_isolation_results.csv
# ajudication-reliability-files/
# annotation_Drew_sample_social_disconnection_DW.csv
# annotation_Selen_sample_social_disconnection_SB.csv
# awalk55/
# chronic_social_isolation_llm_3_shot_labeled.csv
# chronic_social_isolation_llm_labeled.csv
# chronic_social_isolation_llm_one_shot_labeled.csv
# chronic_social_isolation_results.csv
# gold_standard_social_isolation_1000.csv
# lives_alone_results.csv
# lives_alone_social_isolation_llm_labeled.csv
# lives_alone_social_isolation_llm_one_shot_labeled.csv
# lives_alone_social_isolation_llm_three_shot_labeled.csv
# lives_alone_social_isolation_results.csv
# summary_models_acute_social_isolation.csv
# summary_models_chronic_social_isolation.csv
# summary_models_lives_alone.csv
# summary_models_lives_alone_social_isolation.csv
# /opt/modules/Python/3.11.5/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import requests
import pandas as pd
import numpy as np
# %ls
# Out:
# acute_social_isolation_llm_labeled.csv
# acute_social_isolation_llm_one_shot_labeled.csv
# acute_social_isolation_llm_three_shot_labeled.csv
# acute_social_isolation_results.csv
# ajudication-reliability-files/
# annotation_Drew_sample_social_disconnection_DW.csv
# annotation_Selen_sample_social_disconnection_SB.csv
# awalk55/
# chronic_social_isolation_llm_3_shot_labeled.csv
# chronic_social_isolation_llm_labeled.csv
# chronic_social_isolation_llm_one_shot_labeled.csv
# chronic_social_isolation_results.csv
# gold_standard_social_isolation_1000.csv
# lives_alone_results.csv
# lives_alone_social_isolation_llm_labeled.csv
# lives_alone_social_isolation_llm_one_shot_labeled.csv
# lives_alone_social_isolation_llm_three_shot_labeled.csv
# lives_alone_social_isolation_results.csv
# summary_models_acute_social_isolation.csv
# summary_models_chronic_social_isolation.csv
# summary_models_lives_alone.csv
# summary_models_lives_alone_social_isolation.csv

# %%
# Read the Annie Sample csv file
df1 = pd.read_csv("annotation_Selen_sample_social_disconnection_SB.csv") #Selen Sample

# Read the Drew Sample csv file
df2 = pd.read_csv("annotation_Drew_sample_social_disconnection_DW.csv") #Drew Sample
# Bind the rows of the two dataframes

# %%
## Read in reliability and ajudications
# reliability for 100
df_reliability = pd.read_csv("ajudication-reliability-files/ajudications_reliability_social_disconnection_agree.csv",encoding="latin1")

# ajudication dfs for disagreements 
acute_aju = pd.read_csv("ajudication-reliability-files/ajudications_acute_disagreements_dw.csv",encoding="latin1")
chronic_aju = pd.read_csv("ajudication-reliability-files/ajudications_chronic_disagreements_dw.csv",encoding="latin1")
live_alone_aju = pd.read_csv("ajudication-reliability-files/ajudications_lives_alone_disagreements_dw.csv",encoding="latin1")

df_reliability.info()

#ajudication dataframes
acute_aju.info()
chronic_aju.info()
live_alone_aju.info()

# keep only sentence_id and ajudication columns in ajudication dataframes
keep = ['sentence_id', 'adjudication']

# Keep only 'sentence_id' and 'adjudication' columns
acute_aju_trimmed = acute_aju[keep]
chronic_aju_trimmed = chronic_aju[keep]
live_alone_aju_trimmed = live_alone_aju[keep]

# Merge acute_aju, chronic_aju, live_alone_aju with df_reliability based on 'sentence_id'
df_merged = df_reliability.merge(acute_aju_trimmed, on='sentence_id', how='left', suffixes=('', '_acute_aju')) \
                          .merge(chronic_aju_trimmed, on='sentence_id', how='left', suffixes=('', '_chronic_aju')) \
                          .merge(live_alone_aju_trimmed, on='sentence_id', how='left', suffixes=('', '_live_alone_aju'))


# Merge in ajudications for nonagreement 
# for any row =0 for chronic_label_agree, make chronic_social_disconnection_label = adjudication. For any row =0 for lives_alone_agree, make lives_alone_label = adjudication . For any row = 0 for acute_label_agree, make acute_social_disconnection_label = adjudication.

# For rows where chronic_label_agree == 0, replace chronic_social_disconnection_label with adjudication from chronic_aju
df_merged['chronic_social_disconnection_label'] = df_merged.apply(
    lambda row: row['adjudication_chronic_aju'] if row['chronic_label_agree'] == 0 else row['chronic_social_disconnection_label'], axis=1
)

# For rows where lives_alone_agree == 0, replace lives_alone_label with adjudication from live_alone_aju
df_merged['lives_alone_label'] = df_merged.apply(
    lambda row: row['adjudication_live_alone_aju'] if row['lives_alone_agree'] == 0 else row['lives_alone_label'], axis=1
)

# For rows where acute_label_agree == 0, replace acute_social_disconnection_label with adjudication from acute_aju
df_merged['acute_social_disconnection_label'] = df_merged.apply(
    lambda row: row['adjudication_acute_aju'] if row['acute_label_agree'] == 0 else row['acute_social_disconnection_label'], axis=1
)

df_merged.info()  # Check the structure of the merged DataFrame
df_merged[df_merged['lives_alone_agree'] == 0].head(100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   sentence_id                           100 non-null    int64
#  1   text                                  100 non-null    object
#  2   sentence                              100 non-null    object
#  3   matched_term                          100 non-null    object
#  4   chronic_social_disconnection_label    100 non-null    int64
#  5   lives_alone_label                     100 non-null    int64
#  6   acute_social_disconnection_label      100 non-null    int64
#  7   annotator_comments                    5 non-null      object
#  8   manuscript_example                    1 non-null      object
#  9   chronic_social_disconnection_label_2  100 non-null    int64
#  10  lives_alone_label_2                   100 non-null    int64
#  11  acute_social_disconnection_label_2    100 non-null    int64
#  12  annotator_comments_2                  3 non-null      object
#  13  manuscript_example_2                  1 non-null      object
#  14  chronic_label_agree                   100 non-null    int64
#  15  lives_alone_agree                     100 non-null    int64
#  16  acute_label_agree                     100 non-null    int64
#  17  adjudication                          0 non-null      float64
#  18  adjudication_rationale                0 non-null      float64
#  19  adjudication_2                        0 non-null      float64
#  20  adjudication_rationale_2              0 non-null      float64
# dtypes: float64(4), int64(10), object(7)
# memory usage: 16.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 12 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   sentence_id                         6 non-null      int64
#  1   text                                6 non-null      object
#  2   sentence                            6 non-null      object
#  3   matched_term                        6 non-null      object
#  4   acute_social_disconnection_label    6 non-null      int64
#  5   acute_social_disconnection_label_2  6 non-null      int64
#  6   annotator_comments                  2 non-null      object
#  7   annotator_comments_2                0 non-null      float64
#  8   adjudication                        6 non-null      int64
#  9   adjudication_rationale              6 non-null      object
#  10  adjudication_2                      0 non-null      float64
#  11  adjudication_rationale_2            0 non-null      float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 708.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   sentence_id                           4 non-null      int64
#  1   text                                  4 non-null      object
#  2   sentence                              4 non-null      object
#  3   matched_term                          4 non-null      object
#  4   chronic_social_disconnection_label    4 non-null      int64
#  5   chronic_social_disconnection_label_2  4 non-null      int64
#  6   annotator_comments                    2 non-null      object
#  7   annotator_comments_2                  1 non-null      object
#  8   adjudication                          4 non-null      int64
#  9   adjudication_rationale                4 non-null      object
#  10  adjudication_2                        0 non-null      float64
#  11  adjudication_rationale_2              0 non-null      float64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 516.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   sentence_id               3 non-null      int64
#  1   text                      3 non-null      object
#  2   sentence                  3 non-null      object
#  3   matched_term              3 non-null      object
#  4   lives_alone_label         3 non-null      int64
#  5   lives_alone_label_2       3 non-null      int64
#  6   annotator_comments        1 non-null      object
#  7   annotator_comments_2      1 non-null      object
#  8   adjudication              3 non-null      int64
#  9   adjudication_rationale    3 non-null      object
#  10  adjudication_2            0 non-null      float64
#  11  adjudication_rationale_2  0 non-null      float64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 420.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   sentence_id                           100 non-null    int64
#  1   text                                  100 non-null    object
#  2   sentence                              100 non-null    object
#  3   matched_term                          100 non-null    object
#  4   chronic_social_disconnection_label    100 non-null    float64
#  5   lives_alone_label                     100 non-null    float64
#  6   acute_social_disconnection_label      100 non-null    float64
#  7   annotator_comments                    5 non-null      object
#  8   manuscript_example                    1 non-null      object
#  9   chronic_social_disconnection_label_2  100 non-null    int64
#  10  lives_alone_label_2                   100 non-null    int64
#  11  acute_social_disconnection_label_2    100 non-null    int64
#  12  annotator_comments_2                  3 non-null      object
#  13  manuscript_example_2                  1 non-null      object
#  14  chronic_label_agree                   100 non-null    int64
#  15  lives_alone_agree                     100 non-null    int64
#  16  acute_label_agree                     100 non-null    int64
#  17  adjudication                          0 non-null      float64
#  18  adjudication_rationale                0 non-null      float64
#  19  adjudication_2                        0 non-null      float64
#  20  adjudication_rationale_2              0 non-null      float64
#  21  adjudication_acute_aju                6 non-null      float64
#  22  adjudication_chronic_aju              4 non-null      float64
#  23  adjudication_live_alone_aju           3 non-null      float64
# dtypes: float64(10), int64(7), object(7)
# memory usage: 18.9+ KB
#     sentence_id                                               text  \
# 21      5555625  Pt is a 62yof  w/ hx of Schizophrenia who pres...
# 23      9739007  T/SICU RN Admit/Progress Note\nPt. 66y/o femal...
# 36      4954645  PMH: Atrial flutter w/ failed ablation now in ...
#
#                                              sentence matched_term  \
# 21  TOL WELL.SOCIAL SERVICE CONSULT FOR HOMELESSNE...    estranged
# 23             Social: Found down in apartment alone.        alone
# 36  PT ALERT,OX3 ,COOPERATIVE .NOW IN SR NO ECTOPY...  lives alone
#
#     chronic_social_disconnection_label  lives_alone_label  \
# 21                                 1.0                0.0
# 23                                 0.0                0.0
# 36                                 0.0                1.0
#
#     acute_social_disconnection_label                annotator_comments  \
# 21                               0.0                               NaN
# 23                               0.0  maybe 0 for lives alone actually
# 36                               0.0                               NaN
#
#    manuscript_example  chronic_social_disconnection_label_2  ...  \
# 21                NaN                                     1  ...
# 23                NaN                                     0  ...
# 36                NaN                                     0  ...
#
#     chronic_label_agree  lives_alone_agree acute_label_agree adjudication  \
# 21                    1                  0                 1          NaN
# 23                    1                  0                 1          NaN
# 36                    1                  0                 1          NaN
#
#     adjudication_rationale  adjudication_2  adjudication_rationale_2  \
# 21                     NaN             NaN                       NaN
# 23                     NaN             NaN                       NaN
# 36                     NaN             NaN                       NaN
#
#     adjudication_acute_aju  adjudication_chronic_aju  \
# 21                     NaN                       NaN
# 23                     NaN                       NaN
# 36                     NaN                       NaN
#
#     adjudication_live_alone_aju
# 21                          0.0
# 23                          0.0
# 36                          1.0
#
# [3 rows x 24 columns]

# %%
# Filter rows where annotator_comments or annotator_comments_2 are not NA or blank
df_merged_filtered_comments = df_merged[
    (df_merged['annotator_comments'].notna()) & (df_merged['annotator_comments'] != '') |
    (df_merged['annotator_comments_2'].notna()) & (df_merged['annotator_comments_2'] != '')
]

# Filter rows where manuscript_example or manuscript_example_2 are not NA or blank
df_merged_filtered_manuscripts = df_merged[
    (df_merged['manuscript_example'].notna()) & (df_merged['manuscript_example'] != '') |
    (df_merged['manuscript_example_2'].notna()) & (df_merged['manuscript_example_2'] != '')
]
df_merged_filtered_comments
df_merged_filtered_manuscripts
# Out:
#     sentence_id                                               text  \
# 43      6756039  1900-0700 NPN\nNEURO:  Awake and alert, states...
# 83     18016293  SW referred by RN to provide support to this 7...
#
#                                              sentence matched_term  \
# 43  1900-0700 NPN NEURO: Awake and alert, states h...       lonely
# 83  Pt reports feeling depressed lately, he notes ...   loneliness
#
#     chronic_social_disconnection_label  lives_alone_label  \
# 43                                 1.0                0.0
# 83                                 1.0                0.0
#
#     acute_social_disconnection_label  \
# 43                               1.0
# 83                               1.0
#
#                                    annotator_comments manuscript_example  \
# 43              may be more acute, unclear if chronic                NaN
# 83  Full text is extremely descriptive of social s...                yes
#
#     chronic_social_disconnection_label_2  ...  chronic_label_agree  \
# 43                                     1  ...                    0
# 83                                     1  ...                    1
#
#     lives_alone_agree acute_label_agree adjudication  adjudication_rationale  \
# 43                  1                 0          NaN                     NaN
# 83                  1                 0          NaN                     NaN
#
#     adjudication_2  adjudication_rationale_2  adjudication_acute_aju  \
# 43             NaN                       NaN                     1.0
# 83             NaN                       NaN                     1.0
#
#     adjudication_chronic_aju  adjudication_live_alone_aju
# 43                       1.0                          NaN
# 83                       NaN                          NaN
#
# [2 rows x 24 columns]

# %%
df = pd.concat([df1, df2], ignore_index=True)
# clean up more
df


# Add in the ajudicated reliability df 

# Step 1: Rename the columns in df_merged based on your mapping
merged_df = df_merged.rename(columns={
    'sentence_id': 'Sentence ID',
    'text': 'TEXT',
    'sentence': 'Sentence',
})

# Step 2: Select the specific columns from merged_df and df
merged_df_cols = ['Sentence ID', 'TEXT', 'Sentence', 'matched_term', 
                  'chronic_social_disconnection_label', 'lives_alone_label', 'acute_social_disconnection_label']

# Select the columns for both datasets
df_merged_selected = merged_df[merged_df_cols]
df_selected = df[merged_df_cols]

# Step 3: Concatenate the two DataFrames
df_concat = pd.concat([df_merged_selected, df_selected], axis=0, ignore_index=True)

# Replacing blank or NA values with 0 in the specified columns
df_concat[['chronic_social_disconnection_label', 'acute_social_disconnection_label', 'lives_alone_label']] = df_concat[
    ['chronic_social_disconnection_label', 'acute_social_disconnection_label', 'lives_alone_label']
].fillna(0).replace('', 0)

# Displaying the updated DataFrame
df_concat.head()



cols = ['Sentence', 'TEXT']
df_concat['full_text'] = df_concat[cols].apply(lambda row: '</s>'.join(row.values.astype(str)), axis=1)

# Function to truncate full_text to a maximum number of words (tokens approximation)
def truncate_to_8000_words(text, max_words=6000):
    # Split the text into words (tokens are often split similarly)
    words = text.split()

    # Truncate to the first max_words if necessary
    if len(words) > max_words:
        words = words[:max_words]

    # Join back into a string
    truncated_text = ' '.join(words)
    
    return truncated_text

# Apply the truncation function to each row in the dataframe
df_concat['full_text_truncated'] = df_concat['full_text'].apply(lambda x: truncate_to_8000_words(x))



df_concat.info()
df_concat.head()
df_concat.to_csv("gold_standard_social_isolation_1000.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Sentence ID                         1000 non-null   int64
#  1   TEXT                                1000 non-null   object
#  2   Sentence                            1000 non-null   object
#  3   matched_term                        1000 non-null   object
#  4   chronic_social_disconnection_label  1000 non-null   float64
#  5   lives_alone_label                   1000 non-null   float64
#  6   acute_social_disconnection_label    1000 non-null   float64
#  7   full_text                           1000 non-null   object
#  8   full_text_truncated                 1000 non-null   object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 70.4+ KB

# %%
# lives_alone_label, acute_social_disconnection_label
# Chronic social isolation classifier
chronic_df = df_concat[['full_text_truncated', 'lives_alone_label']]

# Display the first few rows of chronic_df
chronic_df.info()
chronic_df.head()
unique_chronic_values = chronic_df['lives_alone_label'].value_counts().reset_index()

# Renaming columns for clarity
unique_chronic_values.columns = ['lives_alone_label', 'count']
unique_chronic_values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   full_text_truncated  1000 non-null   object
#  1   lives_alone_label    1000 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 15.8+ KB
#    lives_alone_label  count
# 0                0.0    812
# 1                1.0    188

# %%
# %pip install seaborn
# %pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/awalk55/.local/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from seaborn) (1.26.2)
# Requirement already satisfied: pandas>=1.2 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/awalk55/.local/lib/python3.11/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/awalk55/.local/lib/python3.11/site-packages (3.9.1)
# Requirement already satisfied: click in /home/awalk55/.local/lib/python3.11/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /home/awalk55/.local/lib/python3.11/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/awalk55/.local/lib/python3.11/site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /home/awalk55/.local/lib/python3.11/site-packages (from nltk) (4.66.5)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
train_size = 0.8
train_data=chronic_df.sample(frac=train_size,random_state=0)
test_data=chronic_df.drop(train_data.index).reset_index(drop=True)
train_data = train_data.reset_index(drop=True)

print("FULL Dataset: {}".format(df_concat.shape))
print("TRAIN Dataset: {}".format(train_data.shape))
print("TEST Dataset: {}".format(test_data.shape))
# Out:
# FULL Dataset: (1000, 9)
# TRAIN Dataset: (800, 2)
# TEST Dataset: (200, 2)

# %%
import requests
import pandas as pd
from datetime import datetime
import time

start_time = time.time()

def request(query):
    # Define the headers
    headers = {
        'Content-Type': 'application/json'
    }
    
    # Define the data
    data = {
        "model": model_name,
        "prompt": query,
        "max_tokens": max_tokens,
        "temperature": 1,
        "top_p": 0.95,
    }
    
    # Make the POST request
    response = requests.post(url, headers=headers, json=data)
    
    # Check if the response is successful
    if response.status_code == 200:
        response_json = response.json()
        
        # Check if the 'choices' key exists
        if 'choices' in response_json:
            answer = response_json['choices'][0]['text']
            print('Answer:\n', answer)
            return answer
        else:
            print("Error: 'choices' key not found in the response.")
            print("Full response content:", response_json)
            return None
    else:
        print(f"Error: Received status code {response.status_code}")
        print("Response content:", response.content)
        return None

def process_dataframe(df, model_name, max_tokens, url):
    results = []
    
    for index, row in df.iterrows():
        prompt = f'''
        You are an expert in abstracting social health from medical language, focused on studying the documentation of social isolation and loneliness within an intensive care unit's electronic health record.
        Read the following sentence, appended by </s> and the full patient note text, and respond with a 1 or 0. Respond with “1” if the chart describes or alludes to a patient living alone. 
        Respond with “0” if the chart does not, if there is not enough evidence of a patient living alone in the chart, or if you are otherwise unsure. 
        After the response, write a short sentence describing the rationale behind the 1/0 classification.
        
        Read the following sentence matching a related keyword, which is appended by </s> and followed by the entire chart carefully:
        {row['full_text_truncated']}
        Please strictly format each response beginning with "Response:" followed by either 0 or 1, then "Rationale:" followed by your explanation.'''
        
        answer = request(prompt)
        if answer is not None:
            results.append({'full_text_truncated': row['full_text_truncated'], 'label_model': answer, 'gold_label': row['lives_alone_label']})
        else:
            results.append({'full_text_truncated': row['full_text_truncated'], 'label_model': 'Error', 'gold_label': row['lives_alone_label']})
    
    return pd.DataFrame(results)

# Model parameters
model_name = 'meta-llama/Meta-Llama-3-70B-Instruct'
max_tokens = 100
url = 'http://llm1.priv.bmi.emory.edu:8000/llama3_70B/v1/completions'


# Process the DataFrame
result_df = process_dataframe(test_data, model_name, max_tokens, url)

print(result_df)
end_time = time.time()
duration = end_time - start_time
print(f"{duration} seconds")
# Out:
# Answer:
#
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 9101 tokens (9001 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#
# Response: 0
# Rationale: The chart mentions "Partner and family members at bed side and very supportive" which indicates the patient is not living alone.
# Answer:
#
# Answer:
#
#
#         Please respond with the following format:
#
#         Response: [insert 0 or 1]
#         Rationale: [insert rationale]
#
#         I will wait for your response.
# Answer:
#   Response: 1 Rationale: The patient's statement "he lives alone" explicitly indicates that the patient lives alone.
# Answer:
#
# Answer:
#
# Answer:
#   Please provide your response based on the chart below.
# Answer:
#
#         Go ahead!
#
#         Response: 1
#         Rationale: The patient explicitly states he is "lonely", and there is no mention of family or a roommate accompanying him, suggesting he may be living alone.
# Answer:
#
#         Response: 0
#         Rationale: There is no indication in the chart that the patient lives alone. The presence of a wife who is involved in the patient's care and discharge teaching suggests that the patient has a support system at home.
# Answer:
#
# Response: 0
# Rationale: The chart does not mention the patient living alone. It describes the care of an infant patient in the ICU, with no mention of living arrangements or social circumstances.
# Answer:
#
# Response: 1
# Rationale: The chart explicitly states "Lives alone in [**Location (un) **]." which indicates that the patient lives alone.
# Answer:
#
#
# Response: 0
# Rationale: There is no mention of the patient's living situation or any indication that the patient lives alone. The social history is described as "non-contributory," implying that there is no relevant information regarding the patient's social situation.
# Answer:
#
#
#
#
#         Response: 0
#         Rationale: There is no indication in the chart that the patient lives alone. The focus is on the patient's medical condition, treatment, and hospital course, with no mention of living arrangements.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#    Do not provide any other comments.
#         Response: 0
#         Rationale: The chart states that the patient lives with his wife and children, which indicates that he is not living alone.
# Answer:
#
#         For example: Response: 0. Rationale: This sentence does not mention the patient living alone or any information that would suggest they are living alone.
#
#         Response: 0. Rationale: This sentence does not mention the patient living alone or any information that would suggest they are living alone.
# Answer:
#
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: There is no direct or indirect mention of the patient living alone, and the note only mentions lack of family contact but does not imply living arrangement.
# Answer:
#
#         Please note that the full patient note is included below the sentence to be analyzed.
#
# Response: 1
# Rationale: The chart indicates that the patient "lives with her daughter" which suggests that she is not living alone.
# Answer:
#
#
# Response: 0
# Rationale: There is no indication in the chart that the patient lives alone, and there is no mention of social isolation or loneliness. While the patient has many significant medical issues, there is no information about their living situation or social support.
# Answer:
#
#
# Response: 1
# Rationale: The patient lives with her daughter, which indicates that she is not living alone.
# Answer:
#
#
# Response: 0
# Rationale: There is no mention of the patient's living arrangements in this chart, so we cannot determine if the patient lives alone. The chart primarily focuses on the patient's medical condition, treatment, and procedure.
# Answer:
#
# Answer:
#
# Answer:
#
#
#         Response: 1
#         Rationale: The patient's social history states "Lives alone."
# Answer:
#   Do not include the sentence or the chart in your response.
# Answer:
#
#         Response: 0
#         Rationale: The patient note does not mention the patient's living situation or whether they live alone. The note focuses on the patient's medical condition, treatment, and psychological status, without providing any information about their living arrangements.
# Answer:
#
# Response: 0
# Rationale: While it is mentioned that the patient normally is able to be alone at home without problems, it is also stated that he lives with his wife, who is his primary caretaker. This indicates that he is not living alone.
# Answer:
#   This will make your responses more readable and easier to score.
#
#         Response: 0
#         Rationale: The patient's social history is mentioned as "non-contributory", indicating that there is no relevant information about the patient's social situation, including whether they live alone or not.
# Answer:
#
#
# Response: 1
# Rationale: The sentence 'took few steps to commode today on hi-flow mask alone' implies the patient is able to walk to the bathroom by themselves, suggesting that they do not have a caregiver or roommate to assist them, and thus may be living alone.
# Answer:
#
#
#         Response: 0
#         Rationale: Although the patient's social history mentions that she lives in the U.S. with her daughter, there is no indication that she lives alone. In fact, it is mentioned that she has 7 children and that her children will provide 24-hour supervision for her after discharge, implying that she will not be living alone.
# Answer:
#
#
# Response: 0
# Rationale: The patient's social history explicitly states "She lives with her husband," indicating she does not live alone.
# Answer:
#
# Answer:
#
#         Any questions or exceptions, please raise.
#
# Response: 0
# Rationale: There is no information in the chart that suggests the patient lives alone. The patient's husband is mentioned, and it is stated that "She lives at home with her husband." This indicates that the patient does not live alone.
# Answer:
#
#         Response: 0
#         Rationale: The text does not explicitly state the patient lives alone, and the focus is primarily on their medical treatment, rather than their living situation. The mention of a patient not being able to return to a nursing home and having a bed available at another facility does not provide conclusive evidence of them living alone.
# Answer:
#
# Answer:
#
#
# Response: 1
# Rationale: The patient has a visitor, specifically their daughter, indicating they have some social connections and potential support outside of the hospital, but they do not live with this person, implying they likely live alone.
# Answer:
#   Do not include any other extraneous information.
#         Response: 0
#         Rationale: There is no mention of the patient living alone in the chart. The patient is mentioned to be divorced with a son, indicating they have family members.
# Answer:
#
#
# Response: 1
# Rationale: The sentence "pt is unsafe to be left alone" implies that the patient would require assistance at home, indicating they likely live alone.
# Answer:
#
# Answer:
#   The entire response should be a single line.
#         Response: 1 Rationale: The patient was found alone in a situation where they needed medical assistance, suggesting they live alone.
# Answer:
#
# Answer:
#
#         Response: 0
#         Rationale: There is no mention or hint of the patient living alone in this chart.
# Answer:
#
#
# Response: 0
# Rationale: There is no mention of the patient living alone in the chart. The patient is described as homeless and has a history of going to Pine street Inn, but there is no information provided about their current living situation.
# Answer:
#
#         Begin your response now.
#         Response: 1
#         Rationale: The patient states "I sit in my room alone all weekend" and explains their daily routine, including being left alone on weekends by their daughter and grandchildren, indicating they live with family members but are often left alone for extended periods.
# Answer:
#
#         Remember, a 1 means the patient is living alone, a 0 means the patient is not living alone or there is not enough information.
# Answer:
#
#
# Response: 1
# Rationale: The phrase "Usually closes eys when left alone" implies that the patient is left alone, suggesting they do not have anyone present with them, which could indicate that they live alone.
# Answer:
#
#         Response: 1
#         Rationale: The patient's social history mentions that "He lives at home with his wife." Although this does not directly state he lives alone, it does indicate that he lives with someone, specifically his wife, which implies he does not live alone.
# Answer:
#   For example, "Response: 0 Rationale: This sentence does not describe a patient living alone."
#         Please answer the prompt question as follows:
#         Response: 0
#         Rationale: This chart does not describe or allude to the patient living alone. The patient is mentioned to be married with two grown children in the area, indicating she is not living alone.  The patient's husband is also mentioned to be present at the bedside, further indicating she is not living alone.
# Answer:
#   The response should be formatted as shown below.
#
#         Response: 1
#         Rationale: The chart explicitly states "Pt lives alone" which confirms the patient's living situation.
# Answer:
#
# Response: 1
# Rationale: The patient is explicitly stated to live alone in the chart, and further information about not having living relatives is provided.
# Answer:
#
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: There is no indication in the chart that the patient lives alone, and multiple references are made to the patient's wife, indicating that the patient has a spouse or partner who is involved in their care.
# Answer:
#
#         Response: 0
#         Rationale: There is no mention of a patient living alone in the chart. Although there are details about the patient's wishes and family, there is no direct evidence of the patient living alone.
# Answer:
#
# Answer:
#
# Answer:
#
#
# Response: 1
# Rationale: The patient lives alone, according to the Social History section of the chart, which states "She lives alone and has a cat. She works out of her home as an organizational consultant."
# Answer:
#
# Answer:
#
# Response: 0
# Rationale: There is no evidence in the chart to suggest that the patient lives alone. There is no mention of social isolation or loneliness, and the patient's social history is primarily focused on his occupation and habits.
# Answer:
#
# Answer:
#
#         Do not include any other information.
#
#         Response: 0
#         Rationale: The chart describes the patient as "lives with wife and sons 10 and 14 yo," indicating that the patient does not live alone.
# Answer:
#
# Answer:
#
# Answer:
#   I can easily track this way.
#         Response:
#         Rationale:
#
#         Response: 0
#         Rationale: There is no direct mention of the patient living alone or any family members providing care, so it is not possible to determine whether the patient lives alone or not. The mention of "UPDATE FAMILY ON PT. CONDITION" does not necessarily imply that the patient lives with family, only that family members are involved in the patient's care.
# Answer:
#
#         Response:
#         Rationale:
# Answer:
#
# Answer:
#
# Answer:
#   Response: 0
#         Rationale: There is no indication in the chart that the patient lives alone. The patient's social history mentions that he lives with his wife, daughter, and son in New Hampshire.
# Answer:
#
#
#         Response: 0
#         Rationale: There is no direct mention of the patient living alone. The only information about family is that they called EMS and were not present on arrival. This does not provide sufficient evidence to conclude that the patient lives alone.
# Answer:
#
#         Always end the response with the period.
#
#         Response: 1
#         Rationale: The phrase "She is very fatigued and sleeps when left alone" implies that the patient is often alone, which suggests that they may live alone, although it is not directly stated. .
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
#
# Response: 1
# Rationale: The sentence "Infant active and alert with cares, but settles when left alone" suggests that the infant is comfortable when alone, implying that the infant may be without adult supervision or care at times, indicating that the parent or caregiver might be living alone.
# Answer:
#
# Answer:
#
# Answer:
#   Response and Rationale should be on separate lines.
#
#         Response: 1
#         Rationale: The chart explicitly states "Pt lives alone" in the social history section, indicating that the patient resides alone.
# Answer:
#
#         Go ahead and respond!
# Answer:
#
# Answer:
#
#         Thank you!
# Answer:
#
# Answer:
#
#         Response: 0
#         Rationale: The chart does not provide any direct information or clues about the patient's living situation or whether they live alone or not.
# Answer:
#   Here is your response:
# Response: 0
# Rationale: The chart explicitly states that the patient "lives w/ friends," indicating that the patient does not live alone.
# Answer:
#
#
# Response: 1
# Rationale: The patient lives in a duplex with her daughter living upstairs and her son living next door. This suggests that she lives with her daughter, making it likely that she does not live alone.
# Answer:
#
#         Response: 0
#         Rationale: There is no mention of the patient living alone in the provided chart. The chart focuses on the patient's medical condition, treatment, and test results, with no information about their living situation.
# Answer:
#
# Answer:
#
#         The response should look like this:
#         Response: 0
#         Rationale: No language in the chart implies the patient lives alone.
#
#         Begin your response here.
#
#         Response: 0
#         Rationale: No language in the chart implies the patient lives alone.
# Answer:
#   Do not include any extra text or spaces.
#         Response: 1
#         Rationale: The chart explicitly states "Social: lives at home alone" under Family/Social history.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 12451 tokens (12351 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#         Thanks!
#
#         Response: 0
#         Rationale: The patient lives with her husband, indicating that she does not live alone.
# Answer:
#   Always keep your responses to these 3 lines.
#
# Response: 1
# Rationale: The patient is explicitly described as living alone in the state.
# Answer:
#   I appreciate your cooperation.
#         Response: 1
#         Rationale: The patient lives in [**Hospital1 487**] alone, indicating that she lives alone.
# Answer:
#
#
# Response: 1
# Rationale: The sentence "lives alone, functionally independent, no cane or walker" explicitly states that the patient lives alone, which justifies the classification as 1.
# Answer:
#
#         Go ahead and respond.
#
#         Response: 1
#         Rationale: The note explicitly states "social:lives alone" which directly indicates the patient lives alone.
# Answer:
#
# Answer:
#
#
# Response: 1
# Rationale: The chart explicitly states that the patient was living at home alone prior to hospitalization.
# Answer:
#
# Answer:
#
#         Response: 0
#         Rationale: There is no direct indication that the patient lives alone, as there is mention of a husband who will visit the patient tomorrow.
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: The patient note only mentions that the patient is quiet when left alone, but there is no explicit or implicit evidence that the patient lives alone. The mention of "Mom" who will visit later in the note further suggests that the patient may not live alone.
# Answer:
#
# Answer:
#   I'll also keep track of the scoring so don't worry about that.
# Answer:
#   Do not include any extra text. Response: 1 Rationale: The chart describes the patient living with his wife, indicating that he is not living alone.
# Answer:
#          Thank you!
#
#         Response: 0
#         Rationale: The chart explicitly states that "He currently lives with his parents," indicating that the patient does not live alone.
# Answer:
#   Thank you.
#
#         Response: 0
#         Rationale: There is no direct mention of the patient living alone or any information regarding their social or living situation, so I am unsure.
# Answer:
#   For example: Response: 1 Rationale: The chart mentions "lives alone" explicitly.
#
#         Response: 0
#         Rationale: There is no information in the chart that suggests the patient lives alone. The patient has a history of being a locksmith and is described as having a social history of drinking 6-8 shots per day, but there is no mention of his living situation.
# Answer:
#
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 9155 tokens (9055 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#         Thank you!
#
# Response: 0
# Rationale: The chart does not mention anything about the patient living alone, but it does mention the daughter calling to check on the mother, suggesting that the patient has family support and may not be living alone.
# Answer:
#
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 10179 tokens (10079 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#
# Response: 1
# Rationale: The patient note explicitly states "Social History: Lives at home alone in [**Location (un) 5110**]" which indicates the patient lives alone.
# Answer:
#
# Answer:
#
#         Thank you for your help!
# Answer:
#   Be concise.
# Answer:
#
#
#         Response: 0
#         Rationale: The sentence "She sleeps when left alone" does not necessarily imply that the patient lives alone; it could simply mean that she tends to fall asleep when she is not actively being monitored or engaged. The presence of her husband, who "spends most of the day with her and is very involved in her care," suggests that she may have social support at home.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 8272 tokens (8172 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#         Finally, provide your answer.
# Answer:
#
#         Do not include any additional information, etc. in your response. Only the specified format.
#
# Response: 0
# Rationale: There is no mention of the patient's living situation in the chart, so it is unclear whether they live alone.
# Answer:
#
#
#         Response: 1
#         Rationale: The patient has no visitors or phone calls, indicating that they may not have a support system or someone to check in on them, suggesting they may be living alone.
# Answer:
#
#         Response: 0
#         Rationale: There is no mention of the patient living alone in the provided chart. The patient is married and was transferred to the hospital from another hospital, indicating that there may be a support system in place.
# Answer:
#          </s>
#         Response: 1
#         Rationale: The patient's social history explicitly states "She lives alone but her son is involved in her care," indicating that she is not cohabiting with anyone and is living alone.
# Answer:
#   Response and Rationale must be on the same line separated by a space.
#         Please answer with the chart description details without any grammar or spelling correction.
#
#         Response: 1 Rationale: The chart explicitly states "lives alone" in the Social / Occupational History section.
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: There is no mention of the patient living alone, and the presence of a wife and two daughters visiting the patient suggests that they may have a supportive network at home.
# Answer:
#
# Answer:
#
# Answer:
#
#         Response: 1
#         Rationale: The chart explicitly states the patient lives alone in an apartment, which is a clear indication of social isolation.
# Answer:
#   Here is the response format you should use:
#         Response: [0 or 1]
#         Rationale: [Your explanation here]
#
#         Here is your response:
#         Response: 1
#         Rationale: The patient's social history mentions that "The patient currently lives in [**Location 10059**], MA by herself." This indicates that she lives alone.
# Answer:
#   If you are unsure, respond with a 0 and explain why you are unsure.
#         Response: 1
#         Rationale: The sentence "SHe admitted that she was feeling anxious and lonely" implies that the patient feels lonely, which could suggest that she does not have someone at home to care for her. Additionally, the note mentions that her sister is planning to visit once the patient is out of ICU, but there is no mention of a spouse or other immediate family members, further supporting
# Answer:
#
#         Response: 0
#         Rationale: The patient is documented as living with a male partner of 20+ years, who is wheelchair-bound, and is his primary caregiver. Therefore, the patient does not live alone.
# Answer:
#
#         Ensure the response and rationale are separate and not combined. Also, make sure to include spaces between the response and rationale.
#
#         Thank you for your cooperation.
# Answer:
#
# Answer:
#
#         I will append multiple sentences to facilitate easier comprehension.</s>
#         Response: 0
#         Rationale: The patient is mentioned as "Married" under the social history section, indicating the presence of a spouse and ruling out the possibility of living alone.
# Answer:
#   For example: Response: 0 Rationale: [Insert explanation here].
#
#         Response: 1
#         Rationale: The chart mentions the patient living alone with daily caretaker visits and 1-23 times a week VNA, indicating that the patient lives alone.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 12213 tokens (12113 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#         Ensure each response and rationale is on the same line as the label.
# Response: 1
# Rationale: The patient lives with her husband and son in [**Name (NI) **], indicating she is not living alone.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 12608 tokens (12508 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#
# Response: 1
# Rationale: The patient lives in a room in a monastery, indicating that they live alone.
# Answer:
#
#         I am ready when you are.
#         Go ahead and respond.
#         Response: 1
#         Rationale: The patient's social history explicitly states "Lives alone in an apt in a senior living community," indicating that they live alone.
# Answer:
#
# Answer:
#
#
#         Response: 1
#         Rationale: The patient lives alone, as stated in the sentence "Lives at home alone, reported A0 x3 at baseline" and also in the social history section where it says "Lives alone, daughter and son live down the street."
# Answer:
#
#
# Response: 0
# Rationale: There is no direct or indirect mention of the patient living alone.
# Answer:
#
#         Response: 0
#         Rationale: There is no mention or hint in the chart that the patient lives alone, and the patient expresses worry about her children seeing her sick, suggesting that she has a family or social support system.
# Answer:
#
# Answer:
#
#
# Response: 1
# Rationale: The sentence "this was her first night staying alone here without the baby's father" explicitly states that the mother is alone in the hospital without the father, suggesting that she may live alone with her infant.
# Answer:
#
# Answer:
#   For this chart note, the response is:
# Response: 1
# Rationale: The patient's belongings are given to the patient's son, which suggests that the patient may have been living alone and the son is taking responsibility for the belongings. Additionally, there is no mention of a spouse or other family members being involved in the patient's care.
# Answer:
#
# Answer:
#   This will help ensure the accuracy of the responses.
# Answer:
#
# Answer:
#   Here is an example:
#         Response: 0
#         Rationale: The text does not contain information that suggests the patient lives alone.
#         Kindly respond to the provided chart note.
# Answer:
#
#
#         Response: 0
#         Rationale: The presence of parents, mother-in-law, children, priest, and social worker indicates a strong support network, making it unlikely that the patient lives alone.
# Answer:
#
# Answer:
#   Response and Rationale must be on separate lines. Thanks!
#
#         Response: 0
#         Rationale: The patient is described as living with her parents and three younger brothers, indicating that she does not live alone.
# Answer:
#
# Answer:
#
# Answer:
#
#
#         Response: 1
#         Rationale: The patient is described as "homeless" and "lives under a bridge", indicating that they do not have a permanent residence or a family support system, which can imply they are living alone.
# Answer:
#
#         Thank you for your contributions to the research project.
#
#         Response: 0
#         Rationale: There is no mention of the patient's living situation or household composition in this chart, which is focused on medical procedures.
# Answer:
#
#
# Response: 0
# Rationale: The sentence mentions that the patient is estranged from family in another country, but there is no explicit mention of the patient living alone.
# Answer:
#
#
# Response: 0
# Rationale: The phrase "left alone" in this context refers to the patient being in a certain position, rather than living alone. There is no evidence in the chart to suggest the patient's living situation.
# Answer:
#
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: There is no mention of the patient living alone in the chart. The patient's daughter is mentioned as a source of information and visited the patient at the rehab facility, suggesting that the patient may have a support system, but there is no explicit mention of the patient's living situation.
# Answer:
#
# Answer:
#
#         Go ahead and respond.</s>
#
# Response: 1
# Rationale: The patient is described as "widowed, lives alone independently" in the Social History section, indicating that he lives alone.
# Answer:
#
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 8371 tokens (8271 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#         Response: 1
#         Rationale: The chart explicitly mentions that "She lives by herself" in the social history section. This is a clear indication that the patient lives alone.
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: There is no mention in the chart that suggests the patient lives alone, and the presence of family members who are involved in decision-making and informed of the patient's status suggests that the patient likely has social support.
# Answer:
#
#
# Response: 1
# Rationale: The chart explicitly mentions the patient being "divorced/estranged from family" and "no contact" with their children, indicating a lack of social support and potential loneliness, thus suggesting that they live alone.
# Answer:
#   Remember to answer based on the chart's description of the patient's living situation, not the mother's.
#
#         Response: 0
#         Rationale: The chart explicitly discusses the patient's mother living with the patient and being deemed unsafe to live alone, but does not mention the patient's living situation beyond being divorced with custody of two children.
# Answer:
#
#         Response: 0
#         Rationale: There is no mention of the patient's living situation or social support within this chart, and it primarily focuses on their medical treatment and physical status.
# Answer:
#   Ensure that each response is confined to a single line.
#
# Response: 0 Rationale: There is no mention of the patient living alone in this chart.
# Answer:
#
#         Thank you for your time and expertise.
# Answer:
#
#
# Response: 1
# Rationale: The chart states that the patient lives in an apartment and her son lives upstairs, suggesting that she lives alone in the apartment.
# Answer:
#
# Answer:
#
#
# Response: 1
# Rationale: The patient is described as falling asleep easily when left alone, implying that they are often or typically alone, which could suggest that they live alone.
# Answer:
#
#
#         Response: 0
#         Rationale: There is no indication in the chart that the patient lives alone, as the text only focuses on the patient's medical history and treatment during their stay in the MICU. The chart does not contain any information about the patient's living situation.
# Answer:
#
#
#         Response:1
#         Rationale: The chart explicitly states "Patient lives alone, but his son stays with him frequently" under Social History. This implies the patient resides alone, but has occasional company from his son.
# Answer:
#
#
#         Response: 1
#         Rationale: The chart explicitly states "UNMARRIED LIVES ALONE" in the social section, indicating the patient lives alone.
# Answer:
#   Do not add any additional comments.  Please respond to each example directly.
#
#         Response: 0
#         Rationale: There is no information in the chart suggesting the patient lives alone.
# Answer:
#   Response: 1 Rationale: The chart explicitly states "Social History: Lives alone in 1 bdrm apartment at [**Location (un) 74908**] in [**Location (un) 1456**], independent living retirement community." indicating that the patient lives alone.
# Answer:
#
#
# Response: 0
# Rationale: There is no mention of the patient living alone in this note. The mention of a wife and daughters visiting implies that the patient has a social support system and does not live alone.
# Answer:
#
#         I look forward to your carefully considered and correctly formatted response.
#
#         Response: 0
#         Rationale: Although the chart notes the patient's attempts to leave the bed (OOB) were alone, it does not provide any information about their living situation outside of the hospital.
# Answer:
#
#
#         Response: 0
#         Rationale: There is no indication in the chart that the patient lives alone, as the family is present and acting as interpreters for the medical team. The focus of the chart is on the patient's medical condition, specifically her swallowing abilities, and there is no mention of living arrangements.
# Answer:
#
#         Response:
#         Rationale:
#
#
#
#         Response: 0
#         Rationale: There is no explicit mention of the patient's living arrangements in the chart, and the phrase "being left alone" in the chart is describing the patient's behavior in response to care, rather than indicating they live alone.
# Answer:
#
#
#         Response: 0
#         Rationale: The chart does not explicitly state or imply that the patient lives alone. The context is focused on the patient's medical treatment and hospital stay, with no mention of living arrangements.
# Answer:
#
#
# Response: 0
# Rationale: There is no explicit mention of the patient living alone in the chart; the chart primarily focuses on medical events and treatment, with only brief mention of the patient's social situation in relation to their need for a new care facility due to the closing of their previous residence.
# Answer:
#
#
#
# Response: 1
# Rationale: The patient was "found by family members" which implies that they do not live alone and have a support system.
# Answer:
#
# Answer:
#
#                                    full_text_truncated  \
# 0    Ischemic disease was excluded (no EKG changes,...
# 1    As other etiologies for bladder wall thickenin...
# 2    MAE, patient is cooparative with but seems to ...
# 3    Social: Found down in apartment alone.</s>T/SI...
# 4    It may represent extension / recurrence of a t...
# ..                                                 ...
# 195  Action: Sedated while left alone on 200mcg/hr ...
# 196  Pt seems to do best when left alone to yell fo...
# 197  She was found by family members Pt intubated a...
# 198  Neg fld blanace 1.1L. Appears very withdrawn.<...
# 199  extrahepatic CBD normal size ERCP: Impression:...
#
#                                            label_model  gold_label
# 0                                                              0.0
# 1                                                Error         0.0
# 2     \n\nResponse: 0 \nRationale: The chart mentio...         0.0
# 3                                                              0.0
# 4     \n\n        Please respond with the following...         0.0
# ..                                                 ...         ...
# 195   \n\n        Response: 0\n        Rationale: T...         0.0
# 196   \n\nResponse: 0 \nRationale: There is no expl...         0.0
# 197          \n\n\nResponse: 1\nRationale: The pati...         0.0
# 198                                                            0.0
# 199                                                            0.0
#
# [200 rows x 3 columns]
# 1786.9128601551056 seconds

# %%
# Parse responses
import re

# Function to extract the first number (0 or 1) after 'Response:'
def extract_response(text):
    start = text.find("Response:") + len("Response:")
    if start != -1:
        # Extract the text following "Response:"
        text_after_response = text[start:].strip()
        # Use regex to find the first occurrence of 0 or 1
        match = re.search(r'\b[01]\b', text_after_response)
        if match:
            return int(match.group())  # Return the number found (0 or 1)
    return 0  # Default to 0 if no valid response is found

# Function to extract the rationale (all text following 'Rationale:')
def extract_rationale(text):
    start = text.find("Rationale:") + len("Rationale:")
    if start != -1:
        return text[start:].strip()
    return ""  # Return empty string if "Rationale:" is not found

# Apply the functions to create new columns
result_df['response'] = result_df['label_model'].apply(extract_response)
result_df['rationale'] = result_df['label_model'].apply(extract_rationale)

# %%
result_df
result_df['response'].value_counts()
result_df['gold_label'].value_counts()
# Out:
# gold_label
# 0.0    164
# 1.0     36
# Name: count, dtype: int64

# %%
result_df.to_csv("lives_alone_social_isolation_llm_labeled.csv")

# %%
result_df = pd.read_csv("lives_alone_social_isolation_llm_labeled.csv")

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import numpy as np

classificaiton_report = classification_report(result_df['gold_label'],result_df['response'])

print(classificaiton_report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.82      0.86       164
#          1.0       0.41      0.58      0.48        36
#
#     accuracy                           0.78       200
#    macro avg       0.66      0.70      0.67       200
# weighted avg       0.81      0.78      0.79       200

# %%
results = []

for _ in range(1000):
    sample_df = result_df.sample(len(result_df), replace=True)

    preds = sample_df['response'].values
    true_labels = sample_df['gold_label'].values

    accuracy = accuracy_score(true_labels, preds)
    positive_precision = precision_score(true_labels, preds, labels=[1], average='binary')
    positive_recall = recall_score(true_labels, preds, labels=[1], average='binary')
    positive_f1 = f1_score(true_labels, preds, labels=[1], average='binary')

    results.append({
        'Accuracy': accuracy,
        'Positive Precision': positive_precision,
        'Positive Recall': positive_recall,
        'Positive F1': positive_f1,
    })

results_df = pd.DataFrame(results)

# Calculate mean
mean_summary = results_df.mean()

# Calculate confidence intervals
ci_lower = results_df.apply(lambda x: np.percentile(x, 2.5))
ci_upper = results_df.apply(lambda x: np.percentile(x, 97.5))

# Combine mean and confidence intervals into a single DataFrame
summary = pd.DataFrame({
    'Mean': mean_summary,
    '2.5%': ci_lower,
    '97.5%': ci_upper
})

print(summary)
# Out:
#                         Mean      2.5%     97.5%
# Accuracy            0.774490  0.715000  0.830000
# Positive Precision  0.410435  0.276596  0.553621
# Positive Recall     0.585012  0.419237  0.750000
# Positive F1         0.479332  0.343709  0.609775

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV, train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score, roc_curve, auc, f1_score, precision_score, recall_score, make_scorer
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import seaborn as sn
import os
import nltk
from datetime import datetime
import time


skf = StratifiedKFold(n_splits=5)
X = chronic_df['full_text_truncated'].values
y = chronic_df['lives_alone_label'].values

metrics = []

skf = StratifiedKFold(n_splits=5)

for train_index, test_index in skf.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    vect = CountVectorizer(ngram_range=(1, 2), max_features=10000, stop_words="english")
    X_train_dtm = vect.fit_transform(X_train)
    X_test_dtm = vect.transform(X_test)


# Define the parameter grids for Naive Bayes, Random Forest, and Logistic Regression
nb_param_grid = {
    'alpha': [0.1, 0.5, 1.0],  # Different alpha values for MultinomialNB
}

rf_param_grid = {
    'n_estimators': [100, 200, 300],  # Number of trees in the forest
    'max_depth': [None, 10, 20],  # Maximum depth of the trees
    'min_samples_split': [2, 5, 10],  # Minimum samples required to split an internal node
}

lr_param_grid = {
    'C': [0.01, 0.1, 1.0],  # Regularization parameter for Logistic Regression
}

# Create a list to store the results
results = []

# Define a custom scoring function to prioritize precision for the positive class
positive_precision_scorer = make_scorer(precision_score, labels=[1], average='binary',  zero_division = 0)
positive_recall_scorer = make_scorer(recall_score, labels=[1], average='binary',  zero_division = 0)
positive_f1_scorer = make_scorer(f1_score, labels=[1], average='binary',  zero_division = 0)


# Perform grid search for Naive Bayes
nb_grid_search = GridSearchCV(MultinomialNB(), nb_param_grid, cv=5, scoring='accuracy', verbose=1)
start_time = time.time()
nb_grid_search.fit(X_train_dtm, y_train)
end_time = time.time()
duration = end_time - start_time

# Get the best hyperparameters and the corresponding model
best_nb_model = nb_grid_search.best_estimator_
best_nb_params = nb_grid_search.best_params_

# Evaluate the Naive Bayes model on the test set
nb_test_predictions = best_nb_model.predict(X_test_dtm)
nb_accuracy = accuracy_score(y_test, nb_test_predictions)
nb_positive_precision = precision_score(y_test, nb_test_predictions, labels=[1], average='binary',  zero_division = 0)
nb_positive_recall = recall_score(y_test, nb_test_predictions, labels=[1], average='binary',  zero_division = 0)
nb_positive_f1 = f1_score(y_test, nb_test_predictions, labels=[1], average='binary',  zero_division = 0)


# Store the results for Naive Bayes
results.append({
    'Model': 'Multinomial Naive Bayes',
    'Hyperparameters': best_nb_params,
    'Accuracy': nb_accuracy,
    'Positive Precision': nb_positive_precision,
    'Positive Recall': nb_positive_recall,
    'Positive F1': nb_positive_f1,
    'Timestamp': datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
    'Duration (s)': duration
})

# Perform grid search for Random Forest
rf_grid_search = GridSearchCV(RandomForestClassifier(random_state=1), rf_param_grid, cv=5, scoring='accuracy', verbose=1)
start_time = time.time()
rf_grid_search.fit(X_train_dtm, y_train)
end_time = time.time()
duration = end_time - start_time

# Get the best hyperparameters and the corresponding model
best_rf_model = rf_grid_search.best_estimator_
best_rf_params = rf_grid_search.best_params_

# Evaluate the Random Forest model on the test set
rf_test_predictions = best_rf_model.predict(X_test_dtm)
rf_accuracy = accuracy_score(y_test, rf_test_predictions)
rf_positive_precision = precision_score(y_test, rf_test_predictions, labels=[1], average='binary',zero_division = 0)
rf_positive_recall = recall_score(y_test, rf_test_predictions, labels=[1], average='binary', zero_division = 0)
rf_positive_f1 = f1_score(y_test, rf_test_predictions, labels=[1], average='binary',  zero_division = 0)


# Store the results for Random Forest
results.append({
    'Model': 'Random Forest',
    'Hyperparameters': best_rf_params,
    'Accuracy': rf_accuracy,
    'Precision': rf_positive_precision,
    'Recall': rf_positive_recall,
    'F1': rf_positive_f1,
    'Timestamp': datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
    'Duration (s)': duration
})

# Perform grid search for Logistic Regression
lr_grid_search = GridSearchCV(LogisticRegression(max_iter=1000), lr_param_grid, cv=5, scoring='accuracy', verbose=1)
start_time = time.time()
lr_grid_search.fit(X_train_dtm, y_train)
end_time = time.time()
duration = end_time - start_time

# Get the best hyperparameters and the corresponding model
best_lr_model = lr_grid_search.best_estimator_
best_lr_params = lr_grid_search.best_params_

# Evaluate the Logistic Regression model on the test set
lr_test_predictions = best_lr_model.predict(X_test_dtm)
lr_accuracy = accuracy_score(y_test, lr_test_predictions)
lr_positive_precision = precision_score(y_test, lr_test_predictions, labels=[1], average='binary',  zero_division = 0)
lr_positive_recall = recall_score(y_test, lr_test_predictions, labels=[1], average='binary',  zero_division = 0)
lr_positive_f1 = f1_score(y_test, lr_test_predictions, labels=[1], average='binary',  zero_division = 0)


# Store the results for Logistic Regression
results.append({
    'Model': 'Logistic Regression',
    'Hyperparameters': best_lr_params,
    'Accuracy': lr_accuracy,
    'Positive Precision': lr_positive_precision,
    'Positive Recall': lr_positive_recall,
    'Positive F1': lr_positive_f1,
    'Timestamp': datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
    'Duration (s)': duration
})

# Create a DataFrame from the results
results_df = pd.DataFrame(results)

# Print the results
print(results_df)

# Save the results to a CSV file
results_df.to_csv('lives_alone_social_isolation_results.csv', index=False)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
#                      Model                                    Hyperparameters  \
# 0  Multinomial Naive Bayes                                     {'alpha': 0.1}
# 1            Random Forest  {'max_depth': None, 'min_samples_split': 2, 'n...
# 2      Logistic Regression                                         {'C': 0.1}
#
#    Accuracy  Positive Precision  Positive Recall  Positive F1  \
# 0     0.840            0.578947         0.578947     0.578947
# 1     0.870                 NaN              NaN          NaN
# 2     0.895            0.814815         0.578947     0.676923
#
#              Timestamp  Duration (s)  Precision    Recall   F1
# 0  2024-10-06 21:33:41      0.069689        NaN       NaN  NaN
# 1  2024-10-06 21:35:16     95.216332   0.928571  0.342105  0.5
# 2  2024-10-06 21:35:19      2.834397        NaN       NaN  NaN

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Placeholder for best hyperparameters (you can modify these values)
best_nb_params = {'alpha': .1}
best_rf_params = {'n_estimators': 300, 'max_depth': None, 'min_samples_split': 2}
best_lr_params = {'C': .1}

X = chronic_df['full_text_truncated'].values
y = chronic_df['lives_alone_label'].values


skf = StratifiedKFold(n_splits=5)

for train_index, test_index in skf.split(X, y):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    vect = CountVectorizer(ngram_range=(1, 2), max_features=10000, stop_words="english")
    X_train_dtm = vect.fit_transform(X_train)
    X_test_dtm = vect.transform(X_test)

    # Train and predict using the models
    models = {
        "Multinomial Naive Bayes": MultinomialNB(**best_nb_params),
        "Random Forest": RandomForestClassifier(random_state=1, **best_rf_params),
        "Logistic Regression": LogisticRegression(max_iter=1000, **best_lr_params)
    }

    predictions = {}

    for model_name, model in models.items():
        model.fit(X_train_dtm, y_train)
        preds = model.predict(X_test_dtm)
        predictions[model_name] = preds

    # Convert predictions to DataFrame
    predicted_df = pd.DataFrame(predictions)
    predicted_df['True Label'] = y_test

    results = []

    # Bootstrap by randomly sampling from predicted_df
    for _ in range(1000):
        sample_df = predicted_df.sample(len(predicted_df), replace=True)

        for model_name in models.keys():
            preds = sample_df[model_name].values
            true_labels = sample_df['True Label'].values

            accuracy = accuracy_score(true_labels, preds)
            positive_precision = precision_score(true_labels, preds, labels=[1], average='binary',  zero_division = 0)
            positive_recall = recall_score(true_labels, preds, labels=[1], average='binary',  zero_division = 0)
            positive_f1 = f1_score(true_labels, preds, labels=[1], average='binary',  zero_division = 0)

            results.append({
                'Model': model_name,
                'Accuracy': accuracy,
                'Positive Precision': positive_precision,
                'Positive Recall': positive_recall,
                'Positive F1': positive_f1,
            })

    results_df = pd.DataFrame(results)

    # Calculate mean and confidence intervals
    summary = results_df.groupby('Model').agg({
        metric: ['mean', lambda x: np.percentile(x, 2.5), lambda x: np.percentile(x, 97.5)]
        for metric in ['Accuracy', 'Positive Precision', 'Positive Recall', 'Positive F1']
    })

    print(summary)

summary

summary.to_csv("summary_models_lives_alone_social_isolation.csv")
# Out:
#                          Accuracy                       Positive Precision  \
#                              mean <lambda_0> <lambda_1>               mean
# Model
# Logistic Regression      0.840170      0.790      0.890           0.637871
# Multinomial Naive Bayes  0.819685      0.765      0.870           0.525162
# Random Forest            0.874045      0.825      0.915           1.000000
#
#                                               Positive Recall             \
#                         <lambda_0> <lambda_1>            mean <lambda_0>
# Model
# Logistic Regression       0.400000   0.857143        0.326970   0.183627
# Multinomial Naive Bayes   0.304348   0.733421        0.326071   0.179464
# Random Forest             1.000000   1.000000        0.323588   0.181818
#
#                                    Positive F1
#                         <lambda_1>        mean <lambda_0> <lambda_1>
# Model
# Logistic Regression       0.484848    0.427696   0.260870   0.586207
# Multinomial Naive Bayes   0.484848    0.398107   0.233333   0.553846
# Random Forest             0.470629    0.484175   0.307692   0.640038
#                          Accuracy                       Positive Precision  \
#                              mean <lambda_0> <lambda_1>               mean
# Model
# Logistic Regression      0.870395   0.824875   0.915000           0.667304
# Multinomial Naive Bayes  0.816865   0.765000   0.865125           0.503643
# Random Forest            0.890055   0.845000   0.930000           0.855537
#
#                                               Positive Recall             \
#                         <lambda_0> <lambda_1>            mean <lambda_0>
# Model
# Logistic Regression       0.500000   0.833333        0.595480   0.432336
# Multinomial Naive Bayes   0.346136   0.645864        0.594899   0.441176
# Random Forest             0.687500   1.000000        0.486857   0.324324
#
#                                    Positive F1
#                         <lambda_1>        mean <lambda_0> <lambda_1>
# Model
# Logistic Regression       0.741959    0.625997   0.485714   0.747063
# Multinomial Naive Bayes   0.750000    0.542543   0.410959   0.666667
# Random Forest             0.648649    0.616457   0.461475   0.757576
#                          Accuracy                       Positive Precision  \
#                              mean <lambda_0> <lambda_1>               mean
# Model
# Logistic Regression      0.823905      0.770      0.870           0.552497
# Multinomial Naive Bayes  0.800540      0.745      0.855           0.473741
# Random Forest            0.844015      0.795      0.890           0.815387
#
#                                               Positive Recall             \
#                         <lambda_0> <lambda_1>            mean <lambda_0>
# Model
# Logistic Regression       0.347784   0.740741        0.391049   0.230714
# Multinomial Naive Bayes   0.314241   0.633409        0.418825   0.266618
# Random Forest             0.555303   1.000000        0.232968   0.102500
#
#                                    Positive F1
#                         <lambda_1>        mean <lambda_0> <lambda_1>
# Model
# Logistic Regression       0.547679    0.454109   0.294978   0.602740
# Multinomial Naive Bayes   0.571429    0.441237   0.296266   0.571526
# Random Forest             0.368470    0.357401   0.176471   0.518556
#                          Accuracy                       Positive Precision  \
#                              mean <lambda_0> <lambda_1>               mean
# Model
# Logistic Regression      0.869070      0.820      0.910           0.696885
# Multinomial Naive Bayes  0.838905      0.785      0.885           0.589680
# Random Forest            0.899525      0.855      0.940           0.948194
#
#                                               Positive Recall             \
#                         <lambda_0> <lambda_1>            mean <lambda_0>
# Model
# Logistic Regression       0.533333   0.857453        0.550170   0.393912
# Multinomial Naive Bayes   0.428571   0.750000        0.497838   0.349971
# Random Forest             0.821429   1.000000        0.497972   0.333152
#
#                                    Positive F1
#                         <lambda_1>        mean <lambda_0> <lambda_1>
# Model
# Logistic Regression       0.704545    0.611516   0.470526   0.742857
# Multinomial Naive Bayes   0.652249    0.536441   0.393443   0.666848
# Random Forest             0.666667    0.648804   0.489773   0.789548
#                          Accuracy                       Positive Precision  \
#                              mean <lambda_0> <lambda_1>               mean
# Model
# Logistic Regression      0.895580      0.850      0.935           0.813933
# Multinomial Naive Bayes  0.838425      0.785      0.890           0.573253
# Random Forest            0.870470      0.820      0.915           0.926020
#
#                                               Positive Recall             \
#                         <lambda_0> <lambda_1>            mean <lambda_0>
# Model
# Logistic Regression       0.649879   0.952435        0.580900   0.416667
# Multinomial Naive Bayes   0.416616   0.734709        0.573689   0.414594
# Random Forest             0.769231   1.000000        0.343004   0.181760
#
#                                    Positive F1
#                         <lambda_1>        mean <lambda_0> <lambda_1>
# Model
# Logistic Regression       0.750000    0.674369   0.528252   0.807738
# Multinomial Naive Bayes   0.729779    0.570259   0.430759   0.704303
# Random Forest             0.515152    0.495339   0.297872   0.666667

# %%
# Sample size x Performance 

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt

# Placeholder for best hyperparameters (you can modify these values)
best_nb_params = {'alpha': .1}
best_rf_params = {'n_estimators': 300, 'max_depth': None, 'min_samples_split': 2}
best_lr_params = {'C': .1}

# Assuming chronic_df is already loaded and available
X = chronic_df['full_text_truncated'].values
y = chronic_df['lives_alone_label'].values

skf = StratifiedKFold(n_splits=5)

# Empty lists to store sample sizes and F1 scores for the best model
sample_sizes = []
f1_scores = []

# Loop through different sample sizes
for sample_size in range(100, 1001, 100):
    f1_scores_sample = []

    for train_index, test_index in skf.split(X, y):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        # Use only the first `sample_size` samples for training
        X_train_sampled = X_train[:sample_size]
        y_train_sampled = y_train[:sample_size]

        vect = CountVectorizer(ngram_range=(1, 2), max_features=10000, stop_words="english")
        X_train_dtm = vect.fit_transform(X_train_sampled)
        X_test_dtm = vect.transform(X_test)

        # Train and predict using the model with the best F1 score
        best_model = LogisticRegression(max_iter=1000, **best_lr_params)
        best_model.fit(X_train_dtm, y_train_sampled)
        preds = best_model.predict(X_test_dtm)

        # Calculate F1 score
        positive_f1 = f1_score(y_test, preds, labels=[1], average='binary', zero_division=0)
        f1_scores_sample.append(positive_f1)

    # Store the mean F1 score for this sample size
    sample_sizes.append(sample_size)
    f1_scores.append(np.mean(f1_scores_sample))

# Create a DataFrame for the results
results_df = pd.DataFrame({'Sample Size': sample_sizes, 'F1 Score': f1_scores})

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(results_df['Sample Size'], results_df['F1 Score'], marker='o', linestyle='-', color='b')
plt.title('Lives Alone Classification Sample Size vs F1 Score for Logistic Regression Model')
plt.xlabel('Sample Size')
plt.ylabel('F1 Score')
plt.grid(True)
# Save the figure as a PNG file
file_path = 'lives_alone_sample_size_vs_f1_score.png'
plt.savefig(file_path)

# Save results to CSV
results_df.to_csv("lives_alone_sample_size_vs_f1_score.csv", index=False)

# %%
# Regex 
df_concat['regex_label'] = 1.0
df_concat.head()
# REGEX values 

results = []

for _ in range(1000):
    sample_df = df_concat.sample(len(df_concat), replace=True)

    preds = df_concat['regex_label'].values
    true_labels = df_concat['lives_alone_label'].values

    accuracy = accuracy_score(true_labels, preds)
    positive_precision = precision_score(true_labels, preds, labels=[1], average='binary')
    positive_recall = recall_score(true_labels, preds, labels=[1], average='binary')
    positive_f1 = f1_score(true_labels, preds, labels=[1], average='binary')
    results.append({
        'Accuracy': accuracy,
        'Positive Precision': positive_precision,
        'Positive Recall': positive_recall,
        'Positive F1': positive_f1,
    })

df_concat_df = pd.DataFrame(results)

# Calculate mean
mean_summary = df_concat_df.mean()

# Calculate confidence intervals
ci_lower = df_concat_df.apply(lambda x: np.percentile(x, 2.5))
ci_upper = df_concat_df.apply(lambda x: np.percentile(x, 97.5))

# Combine mean and confidence intervals into a single DataFrame
summary = pd.DataFrame({
    'Mean': mean_summary,
    '2.5%': ci_lower,
    '97.5%': ci_upper
})

print(summary)
# Out:
#                         Mean      2.5%     97.5%
# Accuracy            0.188000  0.188000  0.188000
# Positive Precision  0.188000  0.188000  0.188000
# Positive Recall     1.000000  1.000000  1.000000
# Positive F1         0.316498  0.316498  0.316498
