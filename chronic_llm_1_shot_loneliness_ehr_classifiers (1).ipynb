# %%
# !python -m venv --copies awalk55

# %%
# %cd /mnt/beegfs/labs/bozkurtlab/drew-projects/loneliness-ehr/
# %ls
# Out:
# /mnt/beegfs/labs/bozkurtlab/drew-projects/loneliness-ehr
# acute_social_isolation_llm_labeled.csv
# acute_social_isolation_results.csv
# ajudication-reliability-files/
# annotation_Drew_sample_social_disconnection_DW.csv
# annotation_Selen_sample_social_disconnection_SB.csv
# awalk55/
# chronic_social_isolation_llm_labeled.csv
# chronic_social_isolation_results.csv
# gold_standard_social_isolation_1000.csv
# lives_alone_results.csv
# lives_alone_social_isolation_llm_labeled.csv
# lives_alone_social_isolation_results.csv
# summary_models_acute_social_isolation.csv
# summary_models_chronic_social_isolation.csv
# summary_models_lives_alone.csv
# summary_models_lives_alone_social_isolation.csv

# %%
import requests
import pandas as pd
import numpy as np
import sentencepiece
# %ls
# Out:
# acute_social_isolation_llm_labeled.csv
# acute_social_isolation_results.csv
# ajudication-reliability-files/
# annotation_Drew_sample_social_disconnection_DW.csv
# annotation_Selen_sample_social_disconnection_SB.csv
# awalk55/
# chronic_social_isolation_llm_labeled.csv
# chronic_social_isolation_results.csv
# gold_standard_social_isolation_1000.csv
# lives_alone_results.csv
# lives_alone_social_isolation_llm_labeled.csv
# lives_alone_social_isolation_results.csv
# summary_models_acute_social_isolation.csv
# summary_models_chronic_social_isolation.csv
# summary_models_lives_alone.csv
# summary_models_lives_alone_social_isolation.csv

# %%
# lives_alone_label, acute_social_disconnection_label
df_concat = pd.read_csv("gold_standard_social_isolation_1000.csv")
df_concat.info()
# Filter out training
exclude_ids = [18016293,10433883] 
exclude_ids = np.array(exclude_ids, dtype=np.int64)
# Exclude the specified Sentence_ID 
df_concat_filtered = df_concat[~df_concat['Sentence ID'].isin(exclude_ids)] 



# Chronic social isolation classifier
chronic_df = df_concat_filtered[['full_text_truncated', 'chronic_social_disconnection_label']]

# Display the first few rows of chronic_df
chronic_df.info()
chronic_df.head()
unique_chronic_values = chronic_df['chronic_social_disconnection_label'].value_counts().reset_index()

# Renaming columns for clarity
unique_chronic_values.columns = ['chronic_social_disconnection_label', 'count']
unique_chronic_values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          1000 non-null   int64
#  1   Sentence ID                         1000 non-null   int64
#  2   TEXT                                1000 non-null   object
#  3   Sentence                            1000 non-null   object
#  4   matched_term                        1000 non-null   object
#  5   chronic_social_disconnection_label  1000 non-null   float64
#  6   lives_alone_label                   1000 non-null   float64
#  7   acute_social_disconnection_label    1000 non-null   float64
#  8   full_text                           1000 non-null   object
#  9   full_text_truncated                 1000 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 78.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 998 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   full_text_truncated                 998 non-null    object
#  1   chronic_social_disconnection_label  998 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 23.4+ KB
#    chronic_social_disconnection_label  count
# 0                                 0.0    967
# 1                                 1.0     31

# %%
# %pip install seaborn
# %pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/awalk55/.local/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from seaborn) (1.26.2)
# Requirement already satisfied: pandas>=1.2 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/awalk55/.local/lib/python3.11/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/awalk55/.local/lib/python3.11/site-packages (3.9.1)
# Requirement already satisfied: click in /home/awalk55/.local/lib/python3.11/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /home/awalk55/.local/lib/python3.11/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/awalk55/.local/lib/python3.11/site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /home/awalk55/.local/lib/python3.11/site-packages (from nltk) (4.66.5)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Remove any of the one-shot examples
train_size = 0.8
train_data=chronic_df.sample(frac=train_size,random_state=0)
test_data=chronic_df.drop(train_data.index).reset_index(drop=True)
train_data = chronic_df.reset_index(drop=True)

print("Filtered Dataset: {}".format(chronic_df.shape))
print("TRAIN Dataset: {}".format(train_data.shape))
print("TEST Dataset: {}".format(test_data.shape))
# Out:
# Filtered Dataset: (998, 2)
# TRAIN Dataset: (998, 2)
# TEST Dataset: (200, 2)

# %%
import requests
import pandas as pd
from datetime import datetime
import time

start_time = time.time()

def request(query):
    # Define the headers
    headers = {
        'Content-Type': 'application/json'
    }
    
    # Define the data
    data = {
        "model": model_name,
        "prompt": query,
        "max_tokens": max_tokens,
        "temperature": 1,
        "top_p": 0.95,
    }
    
    # Make the POST request
    response = requests.post(url, headers=headers, json=data)
    
    # Check if the response is successful
    if response.status_code == 200:
        response_json = response.json()
        
        # Check if the 'choices' key exists
        if 'choices' in response_json:
            answer = response_json['choices'][0]['text']
            print('Answer:\n', answer)
            return answer
        else:
            print("Error: 'choices' key not found in the response.")
            print("Full response content:", response_json)
            return None
    else:
        print(f"Error: Received status code {response.status_code}")
        print("Response content:", response.content)
        return None

def process_dataframe(df, model_name, max_tokens, url):
    results = []
    
    for index, row in df.iterrows():
        prompt = f'''
        You are an expert in abstracting social health from medical language, focused on studying the documentation of social isolation and loneliness within an intensive care unit's electronic health record.
        Read the following sentence, appended by </s> and the full patient note text, and respond with a 1 or 0. Respond with “1” if the chart describes or alludes to a patient suffering from ongoing social isolation or loneliness. This would be any text relating to a patients' potential feelings of their social interaction/support needs not being met in general or over an extended period of time. 
        Respond with “0” if the chart does not, if there is not enough evidence of loneliness or social isolation in the chart, or if you are otherwise unsure. 
        After the response, write a short sentence describing the rationale behind the 1/0 classification.

        To assist you with classification, below are one example of a 1-labeled sentence, without the full chart, where patient chronic social isolation and loneliness is present and a 0-labeled sentence where it is not:
        1: Pt reports feeling depressed lately, he notes loneliness especially bothering him.
        0: No attempts to get OOB alone.

        
        Read the following sentence matching a related keyword, which is appended by </s> and followed by the entire chart carefully:
        {row['full_text_truncated']}
        Please strictly format each response beginning with "Response:" followed by either 0 or 1, then "Rationale:" followed by your explanation.'''
        
        answer = request(prompt)
        if answer is not None:
            results.append({'full_text_truncated': row['full_text_truncated'], 'label_model': answer, 'gold_label': row['chronic_social_disconnection_label']})
        else:
            results.append({'full_text_truncated': row['full_text_truncated'], 'label_model': 'Error', 'gold_label': row['chronic_social_disconnection_label']})
    
    return pd.DataFrame(results)

# Model parameters
model_name = 'meta-llama/Meta-Llama-3-70B-Instruct'
max_tokens = 100
url = 'http://llm1.priv.bmi.emory.edu:8000/llama3_70B/v1/completions'


# Process the DataFrame
result_df = process_dataframe(test_data, model_name, max_tokens, url)

print(result_df)
end_time = time.time()
duration = end_time - start_time
print(f"{duration} seconds")
# Out:
# Answer:
#
#         Thank you for your time and expertise!
# Answer:
#   Do not include the text of the chart in your response.
#         Response: 0
#         Rationale: The chart is primarily focused on the patient's medical diagnoses, including atrial fibrillation, respiratory failure, and chronic heart failure. There is no mention of social isolation or loneliness in the patient's medical history or in the clinician's assessment and plan.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#   Remember to respond based on whether the chart describes or alludes to a patient suffering from ongoing social isolation or loneliness.
#
# Response: 0
# Rationale: The mention of the daughter calling to check on the mother suggests that the patient has some social connection and support, and there is no explicit mention of loneliness or social isolation.
# Answer:
#
#
# Response: 1
# Rationale: The patient explicitly states they are "lonely" which indicates ongoing social isolation or loneliness, and the care team also acknowledges and tries to address this issue by suggesting alternatives such as providing music and changing the room to combat the loneliness.
# Answer:
#
#
# Response: 0
# Rationale: There is no indication of social isolation or loneliness in this patient note. The note primarily focuses on the patient's medical condition and treatment, with no mention of the patient's emotional or social state.
# Answer:
#
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: This chart does not mention anything related to social isolation or loneliness, focusing primarily on the patient's medical history, surgical procedures, and post-operative care.
# Answer:
#   For example:
#         Response: 0
#         Rationale: The chart does not mention any feelings of loneliness or social isolation.
#         Please do not include any sentences or phrases beyond the "Rationale:" sentence.
#
# Response: 0
# Rationale: Although the chart mentions the patient living with daughters and depending on them for ADLs, there is no indication of feelings of loneliness or social isolation.
# Answer:
#
#
# Response: 0
# Rationale: The sentence only mentions that the infant settles well when left alone, which could indicate that the infant is content in isolation, but it does not suggest or imply chronic social isolation or loneliness in the patient. The context of the sentence is within a NICU setting, where the infant is being cared for by medical staff and parents are present and involved.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 9266 tokens (9166 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
# Answer:
#
#
#         Response: 1
#         Rationale: The patient asked to be left alone, indicating potential feelings of social isolation or loneliness.
# Answer:
#
#         Example:
#         Response: 1
#         Rationale: The chart explicitly mentions the patient's feelings of loneliness, which indicates ongoing social isolation.
# Answer:
#
#         Begin!
#
# Response: 0
# Rationale: The chart does not contain any phrases or indications that suggest the patient is experiencing ongoing social isolation or loneliness. The social section of the chart notes the presence of the patient's daughter, who was updated on the patient's condition and plan of care, indicating some level of social support.
# Answer:
#
#
#         Response: 0
#         Rationale: The patient's request to be left alone is more likely related to their current emotional state of anger and frustration, rather than an expression of chronic social isolation or loneliness.
# Answer:
#
#
# Response: 0
# Rationale: The sentence does not imply ongoing social isolation or loneliness. The patient is receiving visits from family and friends, and social work is offering support, suggesting a level of social connection. The sentence "Not asking questions today, asking for time alone w/ pt, offered support as appropriate" suggests a temporary need for alone time, but it does not indicate chronic feelings of loneliness or social isolation.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 8667 tokens (8567 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#   Thank you for your time and expertise.
#         Response: 1
#         Rationale: The sentence "-pt has estranged husband; mother filing for emergency guardianship" suggests that the patient has a strained or non-existent relationship with her husband and that her mother is seeking guardianship, indicating potential ongoing social isolation or lack of support.
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: The patient's chart does not mention feelings of loneliness, isolation, or lack of social support. The patient's husband is involved in her care, and there is no indication of a lack of social interaction or support. The chart focuses on the patient's medical history, diagnoses, and treatment plans, with no mention of psychological or social concerns.
# Answer:
#   Here is the example format:
#         Response: 1
#         Rationale: The patient is described as feeling depressed lately, with loneliness being a specific concern.
#         Response:
#         Rationale:
# Answer:
#
#         Begin!
# Answer:
#
#
# Response: 1
# Rationale: The patient is noted to sleep when left alone, but is alert and cooperative when awake, which could suggest that the patient is experiencing social isolation or loneliness, as they are not actively seeking social interaction when given the opportunity.
# Answer:
#   </s>
#         Response: 1
#         Rationale: The patient is described as "Lives alone" in the social history section, indicating that the patient may be experiencing social isolation. This description, combined with the patient's history of heavy alcohol use and lack of other social connections mentioned in the chart, suggests that the patient may be at risk for ongoing social isolation and loneliness.
# Answer:
#   The classification should be determined by the presence of language that indicates ongoing or chronic feelings of social isolation or loneliness.
#
#         Response: 1
#         Rationale: Although not explicitly mentioning loneliness, the patient's social situation (living alone, never married, no children) and the tragic loss of his girlfriend in the accident, may have contributed to feelings of social isolation or loneliness that could be ongoing. Additionally, the family's concern about sharing the news of his girlfriend's death with him implies that they
# Answer:
#   Please keep your responses brief and to the point.
#
#         Go!
# Answer:
#
# Answer:
#   For example:
#         Response: 0
#         Rationale: There is no mention of social isolation or loneliness in the chart.
#
#         Response: 1
#         Rationale: The patient's living situation and lack of social interaction with others, despite having family nearby, suggest chronic social isolation and loneliness.
#
#         Please respond in this format. If you have any questions or concerns, please let me know!
#
#         Response:
#         Rationale:
# Answer:
#
#         Do not include the sentence or chart in the response.
#         There should be only two lines per response.
#         Response: 0
#         Rationale: There is no indication of social isolation or loneliness in the patient's history or hospital course, and the focus is on their medical treatment and family interactions.
# Answer:
#
#
#         Response: 0
#         Rationale: The patient note is exclusively focused on medical procedures, diagnoses, and treatment without any mention or allusion to the patient's social interaction or emotional well-being.
#
#         Please classify the next chart, the following sentence, which matches a related keyword, appended by </s> and followed by the entire chart:
#         Support system limited.</s>Discharge Summary/Record Abstract Discharge disposition: home. Patient experienced cardiac arrest in ER, subsequent to
# Answer:
#   Here is the format:
#
#         Response:
#         Rationale:
#
#         Please respond according to the instructions above.
#
# Response: 0
# Rationale: The sentence does not describe or allude to the patient's social interaction or support needs not being met, and only focuses on the patient's medical condition and treatment.
# Answer:
#
# Answer:
#
#         Do not provide any additional commentary or unrelated responses.
#
# Response: 1
# Rationale: The chart describes the patient living alone prior to the recent admission, indicating potential social isolation. While there is no explicit mention of loneliness, the patient's living situation suggests that they may not have adequate social support, which is a risk factor for loneliness.
# Answer:
#   Response and Rationale should be separated by a newline for clarity.
#
#         Response: 0
#         Rationale: There is no indication of social isolation or loneliness in the patient's medical history, social history, or hospital course. The patient is married and owns a gift store, suggesting a level of social engagement. Additionally, the patient has been in contact with doctors and is scheduled for follow-up appointments, indicating a level of social support.
# Answer:
#   For this particular case, you should respond with a 0 since there is no information about loneliness or social isolation.
#         You may then proceed with reading and classifying the following charts, one by one, following the same format.
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: There is no description or allusion to a patient suffering from ongoing social isolation or loneliness in this chart. Despite the mention of a sitter and the patient's unsafe state when left alone, this context is purely in regards to safety and physical support rather than emotional or social support needs.
#     """,
#
#
#
#
#
# The response is correct. The chart primarily focuses on the patient's physical condition and treatment plan, with no indication of social isolation or loneliness
# Answer:
#
# Answer:
#
#         Response: 1
#         Rationale: The patient settles to sleep when left alone, and the family/friends have to come to visit, implying the patient may be experiencing feelings of loneliness due to lack of social interaction and support.
# Answer:
#   For this particular patient note, please respond with a classification of 1, as there are mentions of the patient living alone, supporting the notion of ongoing social isolation.
#
# Response: 1
# Rationale: The patient note indicates that the patient "lives alone" which suggests a lack of social interaction and support, implying ongoing social isolation.
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: The chart does not describe or allude to a patient suffering from ongoing social isolation or loneliness. It mainly focuses on the patient's medical condition and treatment plans, and there is no mention of the patient's social interaction or feelings of loneliness.
# Answer:
#
# Answer:
#
# Answer:
#
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 9346 tokens (9246 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#
# Response: 0
# Rationale: There is no mention of social isolation, loneliness, or patient feelings in the chart; it is primarily focused on a medical procedure and the patient's physical state.
# Answer:
#
# Answer:
#
# Answer:
#
#         Go ahead.
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: There is no mention of social isolation or loneliness within the provided chart. The text primarily focuses on the patient's medical conditions, treatment, and observations, without any indication of the patient's emotional or social well-being.
# Answer:
#   Keep the responses brief and concise.
#
#         Response: 1
#         Rationale: The patient lives alone, and his wife died in 2016, indicating potential ongoing social isolation.
# Answer:
#
# Answer:
#
#
# Response:1
# Rationale: The patient is described as appearing withdrawn, and although the reason is not explicitly stated, it could indicate the patient is feeling isolated or lonely, especially given the restart of Elavil, which is an antidepressant.
# Answer:
#
#
#         Response: 1
#         Rationale: The patient is described as living alone, which may suggest a lack of social support and potential social isolation. Additionally, the patient is widowed with no children, which could further contribute to feelings of loneliness.
# Answer:
#
# Answer:
#
#
# Response: 1
# Rationale: The patient is described as being widowed for 8 years and living alone, which suggests a lack of emotional support and potential social isolation. Although it is mentioned that the patient has children in the area who are helpful, and an aid comes to clean the apartment and bathe him, this does not necessarily mitigate the potential feelings of loneliness and isolation.
# Answer:
#   Keep your responses brief and focused.
#         Response: 1
#         Rationale: The patient's social history explicitly mentions that they "Lives alone", suggesting chronic social isolation.
# Answer:
#
#
# Response: 0
# Rationale: There is no mention of the patient feeling lonely or isolated in this chart. The note primarily focuses on the patient's medical conditions and treatment plan, with a brief mention of the patient's interactions with their family members, indicating social support.
# Answer:
#   Keep in mind that you may abbreviate "Rationale:" to "R:" for brevity.
# Answer:
#
# Answer:
#   Don't forget to answer immediately after reading the full chart note.
#
# Response: 0
# Rationale: The note primarily focuses on the patient's medical condition and vital signs, while the wife's emotional state and concerns are mentioned briefly. The wife's feelings of distress and conflict are situational and related to her husband's hospitalization, rather than indicating a chronic state of social isolation or loneliness.
# Answer:
#   Example: Response: 0 Rationale: There is no mention of social isolation or loneliness.
# Answer:
#
# Answer:
#   Keep your responses brief.
#
#         Response: 0
#         Rationale: The chart primarily focuses on the patient's medical history, diagnosis, and treatment plans, with no indication of loneliness or social isolation. There is no mention of the patient's emotional state, relationships, or support system.
# Answer:
#
# Answer:
#   Do not provide any extraneous information.
# Answer:
#
#         Response: 1
#         Rationale: The patient lives with friends and is estranged from his parents, suggesting potential social isolation, though it's not explicitly stated. This, combined with his critical medical condition and limited social interaction, may contribute to feelings of loneliness.
# Answer:
#
# Answer:
#
#         In this response, please include in your rationale a mention of the related keyword(s) that led you to your classification.
# Answer:
#   The full chart is included to provide contextual information. </s>
#         Response: 1
#         Rationale: The patient's social history mentions that they live alone and are unemployed, suggesting potential social isolation.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#   The response should be no more than 4 lines in total.
#
#         Response: 0
#         Rationale: The text does not mention anything about social isolation or loneliness, it appears to be a medical history and hospital course of the patient. The patient's social history is mentioned but it does not indicate any feelings of loneliness or isolation.
# Answer:
#
#
# Response: 0
# Rationale: The note does not mention the patient's feelings or emotions, and the focus is on the patient's medical status, safety, and lab results, with no hint of social isolation or loneliness.
# Answer:
#
# Answer:
#
# Answer:
#   Do not leave any extra line breaks.
# Response: 0
# Rationale: The chart does not mention anything related to social isolation or loneliness. The patient's social history is provided, mentioning his living situation, occupation, and habits, but there is no indication that he is experiencing feelings of loneliness or social isolation.
# Answer:
#   Do not include any other information in your response.
#
#         Response: 0
#         Rationale: The sentence does not mention the patient feeling lonely or isolated, and rather focuses on the infant's medical condition and care in the NICU.
# Answer:
#   For the above passage, your response would be:
#
#
#         Response: 0
#         Rationale: The passage does not contain any information related to the patient's feelings of loneliness, social isolation, or lack of social interaction or support.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 8823 tokens (8723 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
# Response: 0
# Rationale: There is no explicit mention of the patient suffering from social isolation or loneliness in the provided chart. The focus is on the patient's medical history, diagnosis, and treatment, with no mention of their social support network or feelings of loneliness.
# Answer:
#
#         Make sure to not overlook the hidden keyword within the note and to thoroughly read the entire chart.
#
#         Go ahead with your classification:
#
#         Response: 0
#         Rationale: There is no explicit mention of social isolation or loneliness in the chart; the note primarily focuses on the patient's medical conditions and treatment.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 12323 tokens (12223 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 12561 tokens (12461 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
# Answer:
#   For example:
#         Response: 1
#         Rationale: The patient explicitly reports loneliness.
# Answer:
#
# Answer:
#
# Answer:
#   If the chart does not describe social isolation or loneliness, you can say "no evidence of social isolation/loneliness mentioned." If you are unsure, you can say "insufficient information to classify". Please begin:
# Response: 1
# Rationale: The patient "lives alone", which suggests that they may have limited social interaction and support, potentially contributing to feelings of loneliness.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: The presence of family visiting and waiting for a relative to arrive indicates strong family support, suggesting the patient is not socially isolated or lonely.
# Answer:
#
# Answer:
#
# Answer:
#   For example:
#         Response: 1
#         Rationale: The chart indicates social isolation or loneliness in this patient given the sentence mentioning family visited last night.
# Answer:
#   The Response should be a single digit. The Rationale should be a short sentence explaining why you chose that digit.
#         Response: 0
#         Rationale: Although the patient is described as withdrawn, there is no indication that this is due to ongoing social isolation or loneliness. The context suggests a more acute confusional state rather than an emotional state driven by lack of social interaction.
# Answer:
#
# Answer:
#
#
#         Response: 1
#         Rationale: The patient is described as living alone which alludes to potential chronic social isolation. The clinician has also indicated to provide emotional support, implying the patient may be in need of additional social interaction.
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: There is no indication of social isolation or loneliness in this patient's chart, and the focus is primarily on the patient's medical condition and treatment plan. The mention of the patient's father's death is a significant life event, but it is not described as having a direct impact on the patient's emotional state or social connections. The patient's social history mentions that the patient is a long-time smoker, but this is not related to social isolation or
# Answer:
#
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 9265 tokens (9165 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
# Answer:
#
#         Response:
#         Rationale:
# (After reading the full chart carefully)
#
# Response: 0
# Rationale: There is no direct indication that the patient is suffering from ongoing social isolation or loneliness. The focus of the note is on the communication and relationship dynamics between the patient and the infant's father, with an emphasis on their interactions and plans for the baby's care, but it does not suggest a lack of social support or feelings of loneliness.
# Answer:
#   For example, Response: 0 Rationale: ... (provide your justification). Do not include any unnecessary text. Here is the response to the above prompt:
#         Response: 0
#         Rationale: The text does not describe or allude to the patient suffering from ongoing social isolation or loneliness. The patient's family, including his wife, are mentioned as being involved in his care, and there is no mention of feelings of loneliness or isolation.
# Answer:
#
#
#         Response: 0
#         Rationale: There is no mention of social isolation or loneliness in the patient's documentation. The patient is described as living with her husband and has children, grandchildren, and great-grandchildren, indicating a support system. While the patient does experience confusion and disorientation, this is attributed to her medical condition and ICU-related delirium rather than feelings of loneliness or social isolation.
# Answer:
#
# Answer:
#
# Answer:
#
#
#         Response: 1
#         Rationale: The sentence "She sleeps when left alone" suggests that the patient has a habit of sleeping when she is by herself, which could be an indicator of her potential feelings of loneliness or lack of social interaction. Additionally, the patient's husband is mentioned to be involved in her care, but it is unclear if she has other visitors or social support besides him, which adds to the suspicion of social isolation.
# Answer:
#
#
#
# Response: 0
# Rationale: The note describes the patient as lethargic and withdrawn, but these symptoms are presented as related to their medical condition rather than a potential feeling of loneliness or social isolation. There is no indication of the patient expressing feelings of loneliness or isolation, and their behavior is explained by their medical state.
# Answer:
#
#         Please answer the question and provide your rationale.
# Answer:
#   Also, please do not use any other sentences or extra information other than the required fields as this can cause errors with the processing of your response.
# Answer:
#   The explanation should clearly state the presence or lack of evidence of loneliness or social isolation.
#
#         Response: 0
#         Rationale: This patient note text describes the patient's medical history, hospital course, and treatments, but does not mention or allude to feelings of loneliness, social isolation, or the patient's social interaction/support needs not being met. There is no evidence of chronic social isolation or loneliness in this chart.
# Answer:
#   I am only interested in knowing whether social isolation/loneliness is present in the patient chart. Please do not comment on the patient's medical conditions, treatment, or any other aspect of the chart. Only comment on the social isolation or loneliness aspect of the chart.
# Answer:
#   Here is the response format:
#
#         Response: [0 or 1]
#         Rationale: [Your explanation]
#
#
#         Response: 0
#         Rationale: The chart does not mention or allude to the patient's feelings of social interaction or support needs not being met. The focus is on her medical conditions and treatments.
# Answer:
#
#
# Response: 0
# Rationale: The provided chart is primarily focused on documenting a medical procedure and does not contain any language suggesting social isolation or loneliness. The tone is purely procedural, with no mention of the patient's emotional or social well-being.
# Answer:
#   Keep your explanations brief.
#
#         Response: 0
#         Rationale: There is no mention or indication of social isolation or loneliness in the patient's medical history or hospital course. The patient's primary and secondary diagnoses are focused on their medical conditions, and the documentation does not suggest any concerns related to social support or isolation.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#   The rationale should be approximately one sentence. For example: Response: 1 Rationale: The patient's social history indicates that they live alone and have no supportive partner.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 8774 tokens (8674 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#
#         Response: 0
#         Rationale: The patient's phrase "leave me alone" seems to be a reaction to chest PT rather than a reflection of ongoing feelings of loneliness or isolation. The chart also mentions the patient expressing frustration with their prolonged hospital stay and wanting to be closer to family, suggesting that they have social support and are not experiencing chronic isolation.
# Answer:
#
# Answer:
#   Do not include any irrelevant information.
#         Response: 1
#         Rationale: The patient's social history explicitly states "Lives at home alone" and "Wife passed away in [2104-9-2]" which indicates a potential feeling of loneliness and isolation, especially considering the patient lives alone with no immediate family support.
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: The chart primarily focuses on the patient's medical conditions, procedures, and treatment plans, with no mention or allusion to social isolation or loneliness. The patient's social history is briefly mentioned, but it does not provide any information related to social isolation or loneliness.
# Answer:
#
# Answer:
#
#         Response:
#         Rationale:
# Answer:
#
#
#         Response: 0
#         Rationale: There is no mention of social isolation or loneliness in this chart. The patient's medical history and current treatment plan are thoroughly discussed, but there is no information provided about their social support or feelings of isolation.
# Answer:
#   For example:
#         Response: 1
#         Rationale: The chart notes the patient's history of depression, and the patient's husband denies any prior SI, but believes the patient was not trying to hurt herself with the NyQuil overdose. This indicates a potential history of mental health issues. Additionally, the patient's Effexor medication is mentioned, which is often used to treat depression and anxiety. This suggests that the patient may still be struggling with these issues.
#
#         Please provide your
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 12718 tokens (12618 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#
# Response: 1
# Rationale: The patient lives alone, indicating potential social isolation, which may contribute to loneliness or feelings of disconnection. This is a subtle indication of social isolation, which may not necessarily be a prominent feature in this chart, but it is present nonetheless.
# Answer:
#   Always provide a short explanation for your response.
#
#
#         Response: 0
#         Rationale: This chart does not contain any text relating to the patient's feelings of loneliness or social isolation. It appears to focus on the patient's medical condition, treatment, and test results. There is no mention of social support, relationships, or emotional state beyond basic neurological assessments.
# Answer:
#
#
#         Response: 0
#         Rationale: The patient has a very complex medical history with multiple comorbidities and complications, but there is no indication or suggestion of ongoing social isolation or loneliness in the provided chart. The patient is reported to live with his mother and father, who help with his medical care, suggesting a supportive family environment. There is no mention of feelings of loneliness or social isolation in the patient's history or progress notes.
# Answer:
#   Do not include your own dialogue or quotes from the text in the response.
# Response: 0
# Rationale: There is no mention of loneliness or social isolation in the patient's history, and the patient's history suggests that he has a history of relationships and social connections, including a wife and children, as well as a business and friends.
# Answer:
#   The response should be in the following format:
#
#
#         Response: [0 or 1]
#         Rationale: [Short sentence explaining the rationale]
#
#         Example:
#
#
#         Response: 1
#         Rationale: The patient reports feeling depressed and lonely, indicating a possible state of chronic social isolation.
# Answer:
#
#
# Response: 0
# Rationale: There is no mention of social isolation or loneliness in this chart, which is primarily focused on medical observations and treatment. The patient's anxiety and requests for attention and comfort are addressed promptly, and there is no indication of chronic feelings of loneliness or social disconnection.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 9248 tokens (9148 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
# Answer:
#   Response:
#         1
#         Rationale: The phrase "Reports living alone" suggests that the patient lacks social interaction and may be experiencing loneliness, implying ongoing social isolation.
# Answer:
#
#         Please also make sure to refer to the patient by "the patient" or "he" in the rationale rather than repeating the patient's name.
#         Start with the response and rationale:
#         Response: 0
#         Rationale: There is no mention of the patient feeling socially isolated or lonely in this chart, nor is there any indication that his social interaction/support needs are not being met. The focus of the chart is on the patient's medical condition and treatment.
# Answer:
#
# Answer:
#
# Answer:
#   For example:
#         Response: 1
#         Rationale: The patient reports feeling lonely in the chart, indicating chronic social isolation.
# Answer:
#
# Answer:
#
# Answer:
#
#
#         Response: 1
#         Rationale: The patient is described as "Lives alone" in the Social History section, indicating potential feelings of loneliness or social isolation, which are hinted at through this statement.
# Answer:
#   For instance:
#         Response: 1
#         Rationale: The patient’s living situation alone and the lack of information on social history suggest potential social isolation.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 11007 tokens (10907 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#         Response: 0
#         Rationale: This note does not describe or allude to the patient suffering from ongoing social isolation or loneliness. There is no mention of the patient's emotional well-being, social support, or feelings of loneliness. The note primarily focuses on the patient's medical condition, treatment plans, and physical symptoms.
# Answer:
#   You will be able to revise or resubmit responses as necessary.
#
#         Response: 0
#         Rationale: Although the patient is homeless and an alcoholic, there is no direct mention of social isolation or loneliness in the chart. The patient's social history includes a partner and children, indicating some level of social support, and there is no mention of feelings of loneliness or isolation.
# Answer:
#
# Answer:
#
#         Response:
#         Rationale:
#
# Response: 0
# Rationale: The chart primarily focuses on the patient's medical conditions, treatment, and test results, with no mention or indication of social isolation or loneliness. The patient's mental status changes are attributed to hypotension and cerebrovascular stenosis, rather than emotional or psychological distress.
# Answer:
#   Also, remember to carefully read the entire patient note before responding.
# Answer:
#
#
# Response: 1
# Rationale: The patient lives alone in senior housing and has 2 supportive daughters, indicating potential feelings of loneliness and social isolation, which may not be fully met by their daughters' support. This suggests that the patient's social interaction and support needs may not be fully satisfied, pointing towards ongoing social isolation or loneliness.
# Answer:
#
# Answer:
#
#         Response: 0
#         Rationale: This text primarily discusses the patient's medical status and treatment, with a brief mention of a family visit, but does not contain any language suggesting ongoing social isolation or loneliness.
# Answer:
#
#
#         Response: 1
#         Rationale: The doctor is concerned that the patient can no longer live alone and properly take care of himself, which implies that the patient may be experiencing social isolation or loneliness, as the doctor thinks the patient needs more help at home. Additionally, the patient's friend is present and states that the patient eats little and is unable to completely care for himself, further supporting the notion that the patient may be experiencing social isolation or loneliness.
# Answer:
#   For example:
#         Response: 1
#         Rationale: The patient notes feeling depressed and lonely in the chart.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 8268 tokens (8168 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#
#         Response: 0
#         Rationale: There is no mention of social isolation or loneliness in the entire chart, nor is there any indication that the patient's social interaction/support needs are not being met. The patient's medical history, medications, and treatment are the primary focus of the chart.
# Answer:
#
# Answer:
#
# Response: 0
# Rationale: This chart primarily focuses on the patient's medical conditions, treatment, and physical assessment. It does not contain any direct or indirect information regarding the patient's feelings or concerns about social isolation or loneliness. The mention of "Cont emotional support to pt and family" does not imply that the patient is experiencing social isolation or loneliness. Instead, it appears to be a general recommendation for the healthcare team to provide emotional support, which is a standard aspect of care for critically
# Answer:
#
#         This helps ensure your response is accurately processed.
#
#         Response:0
#         Rationale:There is no mention or hint of the patient or family members experiencing social isolation or loneliness in the provided note. The note focuses on the infant's feeding, growth, and development, as well as the parents' involvement and interaction with the healthcare team.
# Answer:
#
#
# Response: 0
# Rationale: There is no evidence or mention of the patient expressing feelings of loneliness, social isolation, or a lack of social support in the chart. The chart focuses primarily on the patient's medical condition, treatment, and communication with the family.
# Answer:
#
# Answer:
#
#
#
# Response: 1
# Rationale: The patient's mother requires social support due to dementia and is considered unsafe to live alone, which implies the patient may have concerns or feelings of loneliness or burden due to caregiving responsibilities, indicating potential social isolation.
# Answer:
#
#         Response:
#         1
#         Rationale: The sentence "SEEMS WITHDRAWN AT TIMES" suggests that the patient may be experiencing emotional distress, possibly related to social isolation or loneliness. The context of the patient being calm when family is out of the room adds to this interpretation, implying that the patient may be feeling uncomfortable or anxious around others.
# Answer:
#
#
#         Thank you for your participation!
#         Response: 0
#         Rationale: Although the patient has a guardian, there is no mention of social isolation, loneliness, or any related indication. The chart primarily focuses on medical conditions and treatment plans.
# Answer:
#
# Answer:
#   If there is not enough evidence of loneliness or social isolation in the chart, or if you are otherwise unsure, respond with “0”.
# Answer:
#
# Answer:
#   The chart does not describe or allude to the patient suffering from ongoing social isolation or loneliness. The patient's family, including a daughter and son, are mentioned, and she has a daughter who lives locally, which suggests some social support. There is no indication that the patient's social interaction or support needs are not being met.
#         Response: 0
#         Rationale: The chart does not mention any symptoms or history of social isolation or loneliness, and it suggests the presence of some social
# Answer:
#   If you have any doubts, let me know.
#
#         Go ahead with the classification.
# Answer:
#
#
#
# Response: 1
# Rationale: The patient's social history indicates that they live alone, which could imply social isolation and loneliness.
# Answer:
#   It should look like:
#         Response: [1/0]
#         Rationale: [Your explanation goes here]
#
# Response: 0
# Rationale: There is no evidence of ongoing social isolation or loneliness in the patient's social history. The patient lives alone but has frequent visits from his son, which indicates some social support. The medical history focuses on the patient's health conditions and treatment, with no mention of feelings of isolation or loneliness.
# Answer:
#
# Answer:
#   Response and Rationale should be separated by a newline.
#         Good luck!
#
#         Response: 0
#         Rationale: There is no mention of social isolation or loneliness, nor is there any description of the patient's social interaction/support needs not being met in the provided chart.
# Answer:
#
#
# Response: 1
# Rationale: The patient lives alone in an independent living retirement community, indicating a potential for social isolation, which could lead to feelings of loneliness. Although there is no direct mention of loneliness, the fact that he has a close girlfriend and son, but still lives alone, suggests that he may not have regular social interaction.
# Answer:
#
#
# Response: 0
# Rationale: There is no mention of the patient's feelings of loneliness or social isolation, and the note primarily focuses on the patient's medical condition and treatment. The mention of family visits indicates that the patient has a support system present, which contradicts social isolation.
# Answer:
#
# Answer:
#   For example: Response: 0. Rationale: There is no mention of the patient's social interaction/support needs not being met in this chart.
# Answer:
#
#
#         Response: 0
#         Rationale: The chart is primarily focused on the patient's medical issues and treatment, with no mention of their social situation or emotional state, indicating no signs of social isolation or loneliness.
# Answer:
#   Also, be aware of potential null classes in your classification process.
#
# Response: 0
# Rationale: Although the patient requires a period of alone time to calm down, there is no clear indication that the patient is experiencing ongoing feelings of loneliness or social isolation. The patient's need for alone time appears to be related to their agitation and yelling, rather than a lack of social interaction.
# Answer:
#
# Answer:
#
#
#         Go ahead!
#
# Response: 1
# Rationale: Although the chart does not explicitly state loneliness or social isolation, the patient's withdrawn appearance, tears, and nodding yes to crying suggest emotional distress, which could be related to unmet social interaction/support needs, especially given the context of the ICU setting.
# Answer:
#
#
#         Thank you for your careful assistance.
# ```
#
# Response: 0
# Rationale: There is no mention of the patient's feelings of loneliness or social isolation in this chart. The chart focuses on the patient's medical history, treatment, and hospital course, but does not mention any social or emotional issues related to loneliness or isolation.
#                                    full_text_truncated  \
# 0    ms: withdrawn, speaking quietly, at times conf...
# 1    Bibasilar opacities likely reflect atelectasis...
# 2    Alert but lethargic, off sedation pt is mostly...
# 3    This time he was home alone and does not remem...
# 4    He lives alone No family.</s>MICU 7 RN REPORT ...
# ..                                                 ...
# 195  Action: Sedated while left alone on 200mcg/hr ...
# 196  Pt seems to do best when left alone to yell fo...
# 197  She was found by family members Pt intubated a...
# 198  Neg fld blanace 1.1L. Appears very withdrawn.<...
# 199  extrahepatic CBD normal size ERCP: Impression:...
#
#                                            label_model  gold_label
# 0     \n        Thank you for your time and expertise!         0.0
# 1     Do not include the text of the chart in your ...         0.0
# 2                                                              0.0
# 3                                                              0.0
# 4                                                              1.0
# ..                                                 ...         ...
# 195   \n\n        Response: 0 \n        Rationale: ...         0.0
# 196   Also, be aware of potential null classes in y...         0.0
# 197                                                            0.0
# 198   \n\n        Go ahead!\n\nResponse: 1\nRationa...         0.0
# 199   \n\n        Thank you for your careful assist...         0.0
#
# [200 rows x 3 columns]
# 875.8471007347107 seconds

# %%
# Parse responses
import re

# Function to extract the first number (0 or 1) after 'Response:'
def extract_response(text):
    start = text.find("Response:") + len("Response:")
    if start != -1:
        # Extract the text following "Response:"
        text_after_response = text[start:].strip()
        # Use regex to find the first occurrence of 0 or 1
        match = re.search(r'\b[01]\b', text_after_response)
        if match:
            return int(match.group())  # Return the number found (0 or 1)
    return 0  # Default to 0 if no valid response is found

# Function to extract the rationale (all text following 'Rationale:')
def extract_rationale(text):
    start = text.find("Rationale:") + len("Rationale:")
    if start != -1:
        return text[start:].strip()
    return ""  # Return empty string if "Rationale:" is not found

# Apply the functions to create new columns
result_df['response'] = result_df['label_model'].apply(extract_response)
result_df['rationale'] = result_df['label_model'].apply(extract_rationale)

# %%
result_df
result_df['response'].value_counts()
result_df['gold_label'].value_counts()
# Out:
# gold_label
# 0.0    193
# 1.0      7
# Name: count, dtype: int64

# %%
result_df.to_csv("chronic_social_isolation_llm_one_shot_labeled.csv")

# %%
chronic_social_isolation_llm_one_shot_labeled = pd.read_csv("chronic_social_isolation_llm_labeled.csv")

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import numpy as np

classificaiton_report = classification_report(result_df['gold_label'],result_df['response'])

print(classificaiton_report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.81      0.88       193
#          1.0       0.07      0.43      0.13         7
#
#     accuracy                           0.80       200
#    macro avg       0.53      0.62      0.51       200
# weighted avg       0.94      0.80      0.86       200

# %%
results = []

for _ in range(1000):
    sample_df = result_df.sample(len(result_df), replace=True)

    preds = sample_df['response'].values
    true_labels = sample_df['gold_label'].values

    accuracy = accuracy_score(true_labels, preds)
    positive_precision = precision_score(true_labels, preds, labels=[1], average='binary')
    positive_recall = recall_score(true_labels, preds, labels=[1], average='binary')
    positive_f1 = f1_score(true_labels, preds, labels=[1], average='binary')

    results.append({
        'Accuracy': accuracy,
        'Positive Precision': positive_precision,
        'Positive Recall': positive_recall,
        'Positive F1': positive_f1,
    })

results_df = pd.DataFrame(results)

# Calculate mean
mean_summary = results_df.mean()

# Calculate confidence intervals
ci_lower = results_df.apply(lambda x: np.percentile(x, 2.5))
ci_upper = results_df.apply(lambda x: np.percentile(x, 97.5))

# Combine mean and confidence intervals into a single DataFrame
summary = pd.DataFrame({
    'Mean': mean_summary,
    '2.5%': ci_lower,
    '97.5%': ci_upper
})

print(summary)
# Out:
#                         Mean  2.5%     97.5%
# Accuracy            0.795985  0.74  0.845125
# Positive Precision  0.074027  0.00  0.157925
# Positive Recall     0.432338  0.00  0.833333
# Positive F1         0.124338  0.00  0.254565
