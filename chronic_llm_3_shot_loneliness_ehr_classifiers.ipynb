# %%
# !python -m venv --copies awalk55

# %%
# %cd /mnt/beegfs/labs/bozkurtlab/drew-projects/loneliness-ehr/
# %ls
# Out:
# /mnt/beegfs/labs/bozkurtlab/drew-projects/loneliness-ehr
# acute_social_isolation_llm_labeled.csv
# acute_social_isolation_results.csv
# ajudication-reliability-files/
# annotation_Drew_sample_social_disconnection_DW.csv
# annotation_Selen_sample_social_disconnection_SB.csv
# awalk55/
# chronic_social_isolation_llm_labeled.csv
# chronic_social_isolation_results.csv
# gold_standard_social_isolation_1000.csv
# lives_alone_results.csv
# lives_alone_social_isolation_llm_labeled.csv
# lives_alone_social_isolation_results.csv
# summary_models_acute_social_isolation.csv
# summary_models_chronic_social_isolation.csv
# summary_models_lives_alone.csv
# summary_models_lives_alone_social_isolation.csv
# /opt/modules/Python/3.11.5/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import requests
import pandas as pd
import numpy as np
import sentencepiece
# %ls
# Out:
# acute_social_isolation_llm_labeled.csv
# acute_social_isolation_results.csv
# ajudication-reliability-files/
# annotation_Drew_sample_social_disconnection_DW.csv
# annotation_Selen_sample_social_disconnection_SB.csv
# awalk55/
# chronic_social_isolation_llm_labeled.csv
# chronic_social_isolation_results.csv
# gold_standard_social_isolation_1000.csv
# lives_alone_results.csv
# lives_alone_social_isolation_llm_labeled.csv
# lives_alone_social_isolation_results.csv
# summary_models_acute_social_isolation.csv
# summary_models_chronic_social_isolation.csv
# summary_models_lives_alone.csv
# summary_models_lives_alone_social_isolation.csv

# %%
# lives_alone_label, acute_social_disconnection_label
df_concat = pd.read_csv("gold_standard_social_isolation_1000.csv")
df_concat.info()
# Filter out training
exclude_ids = [18016293, 5555625, 2379689, 10433883, 9321231, 5421697] 
exclude_ids = np.array(exclude_ids, dtype=np.int64)
# Exclude the specified Sentence_ID 
df_concat_filtered = df_concat[~df_concat['Sentence ID'].isin(exclude_ids)] 



# Chronic social isolation classifier
chronic_df = df_concat_filtered[['full_text_truncated', 'chronic_social_disconnection_label']]

# Display the first few rows of chronic_df
chronic_df.info()
chronic_df.head()
unique_chronic_values = chronic_df['chronic_social_disconnection_label'].value_counts().reset_index()

# Renaming columns for clarity
unique_chronic_values.columns = ['chronic_social_disconnection_label', 'count']
unique_chronic_values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          1000 non-null   int64
#  1   Sentence ID                         1000 non-null   int64
#  2   TEXT                                1000 non-null   object
#  3   Sentence                            1000 non-null   object
#  4   matched_term                        1000 non-null   object
#  5   chronic_social_disconnection_label  1000 non-null   float64
#  6   lives_alone_label                   1000 non-null   float64
#  7   acute_social_disconnection_label    1000 non-null   float64
#  8   full_text                           1000 non-null   object
#  9   full_text_truncated                 1000 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 78.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 994 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   full_text_truncated                 994 non-null    object
#  1   chronic_social_disconnection_label  994 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 23.3+ KB
#    chronic_social_disconnection_label  count
# 0                                 0.0    965
# 1                                 1.0     29

# %%
# %pip install seaborn
# %pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/awalk55/.local/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from seaborn) (1.26.2)
# Requirement already satisfied: pandas>=1.2 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/awalk55/.local/lib/python3.11/site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/awalk55/.local/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/modules/Python/3.11.5/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/awalk55/.local/lib/python3.11/site-packages (3.9.1)
# Requirement already satisfied: click in /home/awalk55/.local/lib/python3.11/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /home/awalk55/.local/lib/python3.11/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/awalk55/.local/lib/python3.11/site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /home/awalk55/.local/lib/python3.11/site-packages (from nltk) (4.66.5)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Remove any of the one-shot examples
train_size = 0.8
train_data=chronic_df.sample(frac=train_size,random_state=0)
test_data=chronic_df.drop(train_data.index).reset_index(drop=True)
train_data = chronic_df.reset_index(drop=True)

print("Filtered Dataset: {}".format(chronic_df.shape))
print("TRAIN Dataset: {}".format(train_data.shape))
print("TEST Dataset: {}".format(test_data.shape))
# Out:
# Filtered Dataset: (994, 2)
# TRAIN Dataset: (994, 2)
# TEST Dataset: (199, 2)

# %%
import requests
import pandas as pd
from datetime import datetime
import time

start_time = time.time()

def request(query):
    # Define the headers
    headers = {
        'Content-Type': 'application/json'
    }
    
    # Define the data
    data = {
        "model": model_name,
        "prompt": query,
        "max_tokens": max_tokens,
        "temperature": 1,
        "top_p": 0.95,
    }
    
    # Make the POST request
    response = requests.post(url, headers=headers, json=data)
    
    # Check if the response is successful
    if response.status_code == 200:
        response_json = response.json()
        
        # Check if the 'choices' key exists
        if 'choices' in response_json:
            answer = response_json['choices'][0]['text']
            print('Answer:\n', answer)
            return answer
        else:
            print("Error: 'choices' key not found in the response.")
            print("Full response content:", response_json)
            return None
    else:
        print(f"Error: Received status code {response.status_code}")
        print("Response content:", response.content)
        return None

def process_dataframe(df, model_name, max_tokens, url):
    results = []
    
    for index, row in df.iterrows():
        prompt = f'''
        You are an expert in abstracting social health from medical language, focused on studying the documentation of social isolation and loneliness within an intensive care unit's electronic health record.
        Read the following sentence, appended by </s> and the full patient note text, and respond with a 1 or 0. Respond with “1” if the chart describes or alludes to a patient suffering from ongoing social isolation or loneliness. This would be any text relating to a patients' potential feelings of their social interaction/support needs not being met in general or over an extended period of time. 
        Respond with “0” if the chart does not, if there is not enough evidence of loneliness or social isolation in the chart, or if you are otherwise unsure. 
        After the response, write a short sentence describing the rationale behind the 1/0 classification.

        To assist you with classification, below are examples of  1-labeled sentences, without the full chart, where patient chronic social isolation and loneliness is present and 0-labeled sentences where it is not:
        1: Pt reports feeling depressed lately, he notes loneliness especially bothering him.
        1: He lives alone No family.
        1: TOL WELL.SOCIAL SERVICE CONSULT FOR HOMELESSNESS.PT ESTRANGED FROM FAMILY PT IN AFIB 80s TO140s,BP 90 TO100s SYSTOLIC.
        0: No attempts to get OOB alone.
        0: Response: Plan: .H/O anxiety Assessment: Lethargic/withdrawn all day.
        0: resting well when left alone, responds quickly to voice.
        
        Read the following sentence matching a related keyword, which is appended by </s> and followed by the entire chart carefully:
        {row['full_text_truncated']}
        Please strictly format each response beginning with "Response:" followed by either 0 or 1, then "Rationale:" followed by your explanation.'''
        
        answer = request(prompt)
        if answer is not None:
            results.append({'full_text_truncated': row['full_text_truncated'], 'label_model': answer, 'gold_label': row['chronic_social_disconnection_label']})
        else:
            results.append({'full_text_truncated': row['full_text_truncated'], 'label_model': 'Error', 'gold_label': row['chronic_social_disconnection_label']})
    
    return pd.DataFrame(results)

# Model parameters
model_name = 'meta-llama/Meta-Llama-3-70B-Instruct'
max_tokens = 100
url = 'http://llm1.priv.bmi.emory.edu:8000/llama3_70B/v1/completions'


# Process the DataFrame
result_df = process_dataframe(test_data, model_name, max_tokens, url)

print(result_df)
end_time = time.time()
duration = end_time - start_time
print(f"{duration} seconds")
# Out:
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 9304 tokens (9204 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#
# Response: 0
# Rationale: The chart does not describe or allude to a patient suffering from ongoing social isolation or loneliness. The text primarily focuses on the patient's medical conditions and treatment after a car accident. There is no mention of the patient's emotional or social well-being.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 10015 tokens (9915 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#         Go!
# Answer:
#   You will have a new prompt for each medical chart.
#
#
# Response: 1
# Rationale: The patient reports living alone and states that he has a woman who lives upstairs in his building who checks on him once a day, which implies limited social interaction. Additionally, he has a strained relationship with his son and does not want him involved in his care, further emphasizing his social isolation. These statements suggest that the patient lacks a strong support system and may be experiencing feelings of loneliness.
# Answer:
#
#         Response: 1
#         Rationale: The patient being described as "lethargic and withdrawn" suggests that the patient might have feelings of loneliness or isolation, potentially indicating that they are not meeting their social interaction/support needs, but this inference is quite weak. The patient is lethargic and withdrawn as a result of her medical condition and medication, not necessarily due to social isolation or loneliness.
# Answer:
#   Example:
#         Response: 1
#         Rationale: ... filler ...
#
#         Please go ahead and classify the note.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#   For example, "Response: 0 Rationale: there is no indication of chronic social isolation or loneliness."
#
#         Please respond now:
#
# Response: 0 Rationale: There is no mention of chronic social isolation or loneliness in the chart. The patient's sleeping alone in the room is a neutral observation, and the mention of a spouse visiting and being supportive implies that the patient has a social support system in place.
# Answer:
#   </s>
#
#
# Response: 0
# Rationale: The given chart does not mention any information about social isolation or loneliness of the patient. It primarily focuses on the patient's medical condition and treatment. There is no indication of the patient's social support or feelings of loneliness.
# Answer:
#
#
#         Response: 1
#         Rationale: The patient lives alone but has family living in an upstairs apartment, which suggests that while he has some social support available, he may still experience feelings of loneliness or isolation due to living alone.
# Answer:
#   Make sure to consider the entire context of the chart when making your classification.
# Answer:
#
#
# Response: 0
# Rationale: Despite the patient being single and living alone, there is no direct mention or implication of social isolation or loneliness in the chart. The patient has a sister who is his healthcare proxy, suggesting some social support network is present.
# Answer:
#
#         You will respond to approximately 100 prompts in this task.
#         Response: 0
#         Rationale: There is no evidence of loneliness or social isolation mentioned in the chart, and the patient is described as living with his son, daughter-in-law, and grandson, indicating a social support system. The focus of the chart is on the patient's medical conditions and treatment, not his emotional or social well-being.
# Answer:
#   Please do not include any unnecessary sentences or characters.
# Response: 0
# Rationale: The chart lacks any information suggesting social isolation or loneliness. The patient is described as living with a wife and children, and there is no mention of any feelings of loneliness or lack of social support.
# Answer:
#
# Answer:
#   For clarity, you can use line breaks. To ensure prompt and accurate response, please take the time to review the entire patient note carefully.
#         Response:
#         Rationale:
#
# Response: 0
# Rationale:
# The keywords "flat affect" and "withdrawn" may initially suggest social isolation or loneliness, but in this context, they are likely describing the patient's emotional state related to their medical condition (encephalopathic state, lethargic, etc.) rather than a
# Answer:
#
#         I will wait for your response.
# Answer:
#
# Answer:
#
# Answer:
#          Response:0
# Rationale: The sentence mainly focuses on the patient's medical condition, providing detailed information about their vitals, medication, and treatment plan. There is no mention of the patient's feelings of loneliness or social isolation. The phrase "Asking for wife" can be seen as a neutral statement, merely describing the patient's actions, rather than conveying any sense of emotional distress or social need. Therefore, I classified this chart as 0, indicating no presence of social isolation or
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: There is no mention of the patient's social interaction or feelings of loneliness in this chart. The focus is on her medical condition and treatment.
# Answer:
#
# Answer:
#
#
#         Response: 1
#         Rationale: The patient is described as living alone recently admitted to a facility, which suggests a lack of social interaction and support, implying social isolation.
# Answer:
#
#         The response should be in the following format:
#         Response: [0 or 1]
#         Rationale: [short sentence explaining the reasoning behind the response]
#
#         Response: 0
#         Rationale: The chart does not mention or imply the patient's feelings of loneliness or lack of social interaction, it only discusses their medical status and care.
# Answer:
#
#
# Response: 0
# Rationale: This sentence appears to be describing a medical procedure with no mention or allusion to the patient's social interaction or emotional state. The context is entirely focused on a technical aspect of care, rather than the patient's feelings or relationships.
# Answer:
#   For example:
#         Response: 1
#         Rationale: The patient's mother visited and the patient's heart rate increased, indicating social anxiety or stress from social interaction.
#
#         Response:
#         Rationale:
# Answer:
#
# Answer:
#
# Answer:
#
#         Remember to carefully read the entire chart before making your classification. Do not just rely on the sentence provided but look for other indicators within the chart that might suggest chronic social isolation or loneliness.
#         Thank you.
# Answer:
#   Example: Response: 1 Rationale: The patient explicitly mentions feeling depressed and lonely, which suggests ongoing social isolation or loneliness.
#
#         Response: 0
#         Rationale: The patient's medical conditions and hospital course are thoroughly documented, but there is no mention of social isolation or loneliness.
# Answer:
#
# Answer:
#
# Answer:
#   You are asked to provide a clear and concise response.
#
# Response: 0
# Rationale: There is no mention of patient's feelings of loneliness, social isolation, or any mental health concerns related to these issues in the chart. The statement "She is never left alone due to history of falls" is related to her physical safety rather than emotional needs or social interaction.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#   In this case, a 0 or 1 score indicates whether the patient note suggests a history of social isolation or loneliness.
# Response: 0
# Rationale: While the patient's history reveals some potential factors that may contribute to social isolation (e.g., being divorced, not working), there is no direct or indirect indication of the patient experiencing chronic loneliness or social isolation in this chart. The patient has a son and has been in contact with healthcare providers, suggesting some level of social interaction.
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: There is no mention or allusion to the patient's feelings or experiences of social isolation or loneliness, the text only describes medical observations and treatment plans.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
#         I will add the doctor's notes for this patient at a later time.
# Answer:
#   The response to the chart should be in the format:
#         Response: 0
#         Rationale: No mention of social isolation or loneliness, or any indicators that imply the patient may be experiencing these emotions. The chart is focused on the patient's medical treatment and vital signs.
# Answer:
#
# Answer:
#
#         Response: 0
#         Rationale: There is no mention of the patient's feelings of loneliness or isolation in the chart. The patient is married and lives at home with his wife, suggesting a presence of social support.
# Answer:
#
#
#         Response: 0
#         Rationale: There is no mention of loneliness, social isolation, or lack of social support in the patient's chart, and the patient is described as having a wife and children, suggesting a supportive family network.
# Answer:
#   Below is the response to the example sentence given.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#   If you have any questions, feel free to ask.
# Answer:
#
# Answer:
#
# Answer:
#
#         Please separate each response with a newline for readability.
#
# Response: 1
# Rationale: The phrase "stating leave me alone" implies the patient is craving social interaction or attention, as they are feeling uncomfortable and restless, which may suggest social isolation or loneliness.
# Answer:
#
# Answer:
#   Do not provide any additional information.
#         Response: 0
#         Rationale: Although the patient has several chronic medical conditions, lives alone, and has no close family, there is no explicit mention of social isolation or loneliness in this chart.
# Answer:
#
# Answer:
#
#         Responses must be submitted as follows:
#
#         Response:
#         Rationale:
#
# Response: 0
# Rationale: There is no mention of social isolation or loneliness in the provided chart, the patient's history and medical course are primarily focused on her diagnosis and treatment of amyloidosis and her autologous stem cell transplant. The patient's social history mentions that she works as a hairdresser and has a family history, indicating some level of social connection, but there is no indication
# Answer:
#
#         Do not include the patient note in your response.
#
# Response: 0
# Rationale: There is no mention of social isolation, loneliness, or any feelings of emotional distress that would indicate the patient is suffering from social isolation or loneliness. The patient has a husband, lives with family members, and has a social support system in place.
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: Although the patient becomes irritable with cares, they settle once left alone, which suggests that they may not be craving social interaction or feeling lonely. Instead, they may be overwhelmed or frustrated with the care they are receiving. The fact that they enjoyed being held by their mom and that mom and dad are involved in their care also suggests a supportive social environment.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 8929 tokens (8829 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#   Always respond with a 0 or 1.
#
#         Response: 0
#         Rationale: There is no indication of the patient suffering from ongoing social isolation or loneliness in the chart. The focus is on the patient's medical conditions and treatment.
# Answer:
#
# Response: 0
# Rationale: There is no indication in the chart that the patient suffers from ongoing social isolation or loneliness. The patient lives with their wife and has three adult children, indicating a social support system. The mention of "alone" in the sentence "a [7-13] pound weight loss in the last week alone" is in reference to the timeframe of the weight loss, not an indication of social isolation.
# Answer:
#   This helps in auto-reading and evaluating your responses.
#         Response: 1
#         Rationale: The patient is described as living alone in public housing and being separated from his wife, suggesting a lack of social support and potential social isolation.
# Answer:
#   Be detailed but concise and accurate.
#         Response:
#         Rationale:
#
# Response: 1
# Rationale: The patient lives in a facility and is under guardianship, indicating that they may lack social support and independence, which could contribute to feelings of loneliness and isolation. The fact that they have a guardian who needs to sign ICU consent also suggests a limited social network.
# Answer:
#
#
# Response: 1
# Rationale: The patient lives with friends and is estranged from his parents, indicating potential social isolation or lack of strong familial support, which can contribute to feelings of loneliness.
# Answer:
#
#         You are trained to recognize social isolation and loneliness to help healthcare professionals better identify and intervene early for improved patient care outcomes.
# Answer:
#
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: There is no indication of social isolation or loneliness mentioned in the patient's chart. The patient's son is listed as a healthcare proxy, and there is a mention of family being informed of the patient's condition, indicating that the patient has social support available.
# Answer:
#
# Answer:
#
# Answer:
#   For this case, I will respond:
#         Response: 0
#         Rationale: The patient's chart presents no indication or suggestion of chronic social isolation or loneliness. The focus of the chart is on the patient's medical treatment for endocarditis and related complications, with no reference to the patient's social support or interactions.
# Answer:
#
# Answer:
#
# Answer:
#
#         Response: 0
#         Rationale: The text primarily focuses on the patient's medical condition, with no mention of social isolation or loneliness. There is no language indicating the patient is experiencing emotional distress related to a lack of social support or connection.
# Answer:
#
# Answer:
#   For example: Response: 1 Rationale: This patient was described as feeling depressed and lonely.
#
#         Response: 0 Rationale: Although the patient is described as being comfortable when left alone, this does not imply feelings of loneliness or social isolation, as it is merely a description of the patient's response to pain control.
# Answer:
#   Do not include any extra spaces.
#         Response:0
#         Rationale:There is no mention of the patient's social support network, relationships, or feelings of loneliness in the chart. The patient's wife is mentioned, but only as someone he was waiting for at the beauty salon, and there is no indication that she or anyone else is involved in his care or support.
# Answer:
#
#
#         Response: 1
#         Rationale: The chart mentions the patient being estranged from his wife and children, indicating a lack of family support, and also not wanting his girlfriend to be aware of his situation, implying that he may not have close relationships or a social support network, which could contribute to feelings of loneliness or isolation.
# Answer:
#
#
# Response: 0
# Rationale: The patient's note does not contain any evidence of social isolation or loneliness. The focus of the chart is on the patient's medical conditions, treatments, and medications, with no mention of social support, living situation, or feelings of isolation.
# Answer:
#
# Answer:
#
# Answer:
#
#
# Response: 1
# Rationale: Although the patient is not explicitly stating feelings of loneliness, the chart suggests that the patient experiences anxiety when left alone, which may indicate a need for social interaction or support.
# Answer:
#   If possible, the explanation should be 1-2 sentences and address the patient's social isolation/loneliness as depicted in the chart.        Response: 1
#         Rationale: The patient lives at home alone and has no family contact except for a niece, indicating potential social isolation and limited social support.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 12654 tokens (12554 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#         response:0
#         rationale: The sentence describes the infant being irritable when disturbed, but settles easily when left alone, which indicates that the infant is responsive to social interaction, and the parents visited the infant, indicating social support. There is no evidence of chronic social isolation or loneliness in this chart.
# Answer:
#
# Answer:
#
# Answer:
#
#
#         Response: 1
#         Rationale: Although the patient lives alone, the chart mentions that they have 6 supportive adult children, indicating a potential social support system available. Thus, there is not sufficient evidence to classify this patient as experiencing chronic social isolation or loneliness.
# Answer:
#
#
#         Response: 0
#         Rationale: The patient note text does not mention anything about social isolation or loneliness. It only describes the patient's medical history and treatment. The social history only mentions that the patient works in a machine shop, drinks beer, and occasionally smokes tobacco, but there is no indication of social isolation or loneliness.
# Answer:
#   For example, "Response: 1. Rationale: The patient is experiencing symptoms that suggest chronic social isolation due to homelessness and estrangement from family."
#         Please respond accordingly to the given chart.
# Answer:
#
# Answer:
#
# Answer:
#   For example:
#         Response: 1
#         Rationale: The patient lives alone, indicating a potential lack of social interaction.
# Answer:
#
#
#         Response: 0
#         Rationale: There is no evidence of chronic social isolation or loneliness in this patient's chart, and no mention of the patient's social interaction or support needs not being met. The patient lives with her son, indicating that she has some social support at home, and there is no mention of feelings of loneliness or isolation.
# Answer:
#   For any query, feel free to ask.
# Answer:
#
#
# Response: 0
# Rationale: This chart focuses on the infant's medical information and behavior, and the phrase "quiet when left alone" only describes the infant's current behavior, not suggesting chronic feelings of loneliness or social isolation.
#
# Please answer the following chart:
# Pt enjoys spending time with her family, looking forward to going home to see them.  They brought her a plant and that made her day.  She also expressed interest in speaking with a therapist regarding coping strategies for her chronic pain
# Answer:
#
#         Response: 0
#         Rationale: This chart is primarily focused on a patient's medical history, symptoms, and treatment plans, with no mention of the patient's social isolation or loneliness. The fact that the patient lives with her daughter is mentioned, but there is no indication of the patient feeling isolated or lonely.
# Answer:
#   Here you go!
#
# Response: 0
# Rationale: There is no mention of the patient feeling lonely, isolated, or lacking social interaction/support in the chart.
# Answer:
#
#         Go ahead and respond to the given sentence.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#   For example:
#         Response: 1
#         Rationale: The chart notes the patient's daughter called to check on the patient, indicating a potential lack of family support.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 9583 tokens (9483 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: The patient's social history indicates that he lives with his son, which suggests that he has some level of social support. Additionally, there is no mention of feelings of loneliness or social isolation in the chart.
# Answer:
#   Do not include the sentence appended with </s> in your response.
#
#         Response: 0
#         Rationale: There is no indication of social isolation or loneliness in the chart, despite the patient's extensive medical history and hospital course. His social history mentions his occupation and past habits, but there is no mention of living alone, estrangement from family, or feelings of loneliness.
# Answer:
#
#         Thank you!
#         Response: 0
#         Rationale: The chart does not describe or allude to the patient experiencing social isolation or loneliness. It primarily focuses on the patient's medical conditions, procedures, and treatments, without any mention of social or emotional distress related to isolation or loneliness. The patient's social history mentions a wife and granddaughter, indicating some level of social connection.
# Answer:
#
#
# Response: 1
# Rationale: The patient lives alone, has no known family, and this social isolation could lead to feelings of loneliness, which is a key indicator of social isolation.
# Answer:
#
# Answer:
#   For example, "Response: 1 Rationale: ...". Please do not provide any additional information not requested in the prompt.
# Answer:
#   Response: 0 Rationale: The sentence does not describe the patient's feelings, nor indicate social isolation. The sentence is primarily focused on the patient's blood pressure levels when left alone, which is a medical phenomenon, not a social phenomenon.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 8475 tokens (8375 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
# Answer:
#   Use a new line to separate each part of the response.
#
#         Response: 0
#
#         Rationale: The patient's social history reveals that she lives next door to her son and daughter, which suggests that she may have social support available, and there is no mention of feelings of loneliness or social isolation in the medical history or notes.
# Answer:
#
# Answer:
#   Do not include anything else in the response. Response:0 Rationale: The chart primarily discusses the patient's medical history, symptoms, and treatment plan, without any mention of social isolation or loneliness.
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: The sentence "Irritable at times, but settles when left alone" does not suggest chronic social isolation or loneliness, rather it suggests the patient, in this case, an infant, is momentarily irritable and can be calmed down when left alone. This does not indicate unmet social interaction/support needs.
# Answer:
#
#
#         Response: 0
#         Rationale: The chart does not mention social isolation or loneliness anywhere, and the patient lives with his wife, indicating a social support system. The focus of the chart is on the patient's medical conditions and treatment.
# Answer:
#
#         Here is the response format:
#
#         Response: [0 or 1]
#         Rationale: [Explain why you chose 0 or 1 in a sentence or two]
#
#         Go ahead and respond!
#         ```
#
#         Response: 0
#         Rationale: This chart does not mention any feelings of loneliness or social isolation. It is primarily a medical chart discussing the patient's multiple health issues and treatment plans.
# Answer:
#   It should look like this:
#         Response: 0
#         Rationale: [your explanation]
#         There should be no other formatting, only the 0 or 1 and your explanation.
#
# Response: 0
# Rationale: The chart does not mention anything related to social isolation or loneliness. It only discusses the patient's medical condition, treatment, and care in the ICU.
# Answer:
#
#         Response: 0
#         Rationale: There is no mention or allusion to the patient experiencing social isolation or loneliness. The patient lives with his wife, and there is no indication that his social interaction or support needs are not being met. The focus of the note is on the patient's medical condition and treatment plan, with no evidence of social isolation or loneliness.
# Answer:
#   No other words or phrases should exist between the colon and the number/rationale.
#
# Response: 0
# Rationale: The note primarily discusses a medical procedure, the PICC line placement, and does not contain any indication of social isolation or loneliness.
# Answer:
#   The rationale must be 1-2 sentences long. The sentences should explain why the classification was made. Keep each response on a single line.
#
#
# Response: 0 Rationale: The chart describes the patient's medical history, current hospital stay, and treatments, but there is no indication of social isolation or loneliness.
# Answer:
#
#
# Response: 0
# Rationale: The phrase 'after being left alone' is indicating that the patient's respiratory rate resolves to a normal state when not being stimulated, but it does not imply chronic social isolation or loneliness. The social section of the note indicates that the patient's wife will be visiting, showing there is some social support.
# Answer:
#
# Answer:
#
#
# Response: 1
# Rationale: The patient's social history reveals that the patient "lives alone," indicating potential social isolation. Additionally, the patient has children in different locations, suggesting that they may not have frequent in-person contact or support.
# Answer:
#
#         Response: 1
#         Rationale: The patient has been living in an apartment since being separated from his wife, which implies social isolation and loneliness related to the lack of social support from a significant other.
# Answer:
#   Please use a short sentence for the rationale.
#
# Response:1
# Rationale: The patient lives alone and was found disheveled in bed, which suggests chronic social isolation and loneliness.
# Answer:
#
#         Thanks for your attention and help with this project!
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 12416 tokens (12316 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: The patient's social history mentions that he lives with his partner and has no social isolation or loneliness. There is no indication that the patient is experiencing feelings of loneliness or social isolation, or that these feelings are affecting his health. The focus of the note is on the patient's medical condition and treatment.
# Answer:
#
#         Be careful with punctuation and spacing.
#
# Response: 1
# Rationale: The patient's occupational history reveals that they live alone and have no friends or family to assist with tasks, indicating chronic social isolation and loneliness.
# Answer:
#
# Answer:
#   The response should be a single sentence only.
#         There should be no line breaks or carriage returns in the response.
#         Response: 1
#         Rationale: The patient is described as living at home alone in [**Location (un) **], indicating potential social isolation, and also receives home assistance, suggesting potential dependency on others for daily needs.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
#         Thank you.
# Answer:
#   Please only respond to the sentence provided, not the entire chart.
#
# Response: 0
# Rationale: The sentence only discusses medical treatment plans and medications for anticoagulation and does not contain any language or indication related to social isolation or loneliness.
# Answer:
#   Here is the response format:
#
# Response: [1/0]
# Rationale: [Your explanation]
#
# For this task, I will be responding based on the presence of social isolation and loneliness, which may relate to the patient's personal situation, living conditions, or expressed feelings.
#
# Response: 0
# Rationale: The chart does not provide any information that suggests the patient is suffering from ongoing social isolation or loneliness. The patient lives with his daughter, and there is no mention of feelings of
# Answer:
#
# Answer:
#
#
# Response: 0
# Rationale: This chart does not provide any information that suggests the patient is experiencing social isolation or loneliness. It primarily focuses on the patient's medical status, treatment, and physiological responses.
# Answer:
#
#
#         Response: 0
#         Rationale: The term "alone" appears in the phrase "appearing comfortable when left alone", but it is describing the patient's response to sedation rather than social isolation or loneliness. The presence of family (husband and two daughters) and daily updates for them suggests a supportive network for the patient.
# Answer:
#
#         Here is an example:
#         Response: 0
#         Rationale: There is no evidence of social isolation or loneliness in the chart.
#
# Response: 0
# Rationale: There is no mention or indication of social isolation or loneliness in the patient's chart, which primarily focuses on their physical injuries and medical treatment.
# Answer:
#
#         Response: 1
#         Rationale: The patient lives alone, which may indicate a lack of social support, and his wife's recent passing may have further exacerbated feelings of loneliness.
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: The text does not mention or imply social isolation or loneliness, it primarily focuses on the patient's medical history, hospital course, and treatment.
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: The chart focuses on medical conditions such as subarachnoid hemorrhage and diabetes mellitus and their respective treatment plans, without any mention of social isolation or loneliness. The patient's social status and support network are not discussed.
# Answer:
#
#
# Response: 1
# Rationale: The patient's social history mentions that the patient "lives alone" and "never married", which suggests that she may not have a support system, increasing the likelihood of social isolation.
# Answer:
#   And only answer with "Response: 0" "Rationale:" there is no sign of chronic social isolation or loneliness in the chart as the content primarily focuses on the infant's medical condition and no information on the parents' social life/support.
# Answer:
#   I am doing this to assist in building a machine learning model.
#
#         Response: 0
#         Rationale: There is no mention of social isolation or loneliness in the patient's history or behavior. The patient's social history mentions that she used to work as a farmer and grew up in Nova Scotia, but there is no indication that she is currently experiencing loneliness or social isolation. Additionally, there is no mention of the patient's family or friends, but there is no mention of estrangement or
# Answer:
#
#
# Response: 0
# Rationale: There is no mention of social isolation or loneliness in the patient's history, and the patient lives with children. Also, there is no indication of lack of social support or feelings of loneliness in the chart. The focus is on the patient's medical conditions and treatment.
# Error: Received status code 400
# Response content: b'{"object":"error","message":"This model\'s maximum context length is 8192 tokens. However, you requested 8574 tokens (8474 in the messages, 100 in the completion). Please reduce the length of the messages or completion.","type":"BadRequestError","param":null,"code":400}'
# Answer:
#
#
# Response: 0
# Rationale: There is no mention of the patient's emotional state, feelings of loneliness or social isolation, or any interactions with family or friends that would suggest ongoing social isolation or loneliness in this chart. The chart primarily focuses on the patient's medical condition, treatment, and care.
# Answer:
#
#         Response: 0
#         Rationale: The chart describes the patient's complex medical history and multiple surgeries, but there is no mention of social isolation or loneliness. The patient is reported to be living with her husband, indicating that she has some social support.
# Answer:
#
# Answer:
#
# Answer:
#
#
# Response: 1
# Rationale: The patient is described as divorced/estranged from family, with no contact with children, indicating a lack of social support and potential feelings of loneliness, which is reinforced by the notation "Difficult social situation" and the focus on finding affordable housing.
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: There is no mention of social isolation or loneliness in this chart, only a comprehensive description of the patient's medical conditions, treatments, and future care plans.
# Answer:
#   Here are your responses.
#
#         Response: 1
#         Rationale: The patient lives alone in subsidized housing and has a 20-year history of alcoholism, indicating a lack of social support and a history of struggling with addiction, which may contribute to feelings of loneliness and isolation. Additionally, the patient's depression and recent life tragedies (death of a close friend, separation of oldest son from his wife, and another close friend's involvement in a traumatic event) suggest that the patient may be
# Answer:
#
#         You are encouraged to provide detailed and nuanced explanations to demonstrate your thought process.
# Answer:
#
#         Response: 0
#         Rationale: There is no mention of social isolation or loneliness in the chart, and the patient lives with 2 daughters, indicating a supportive living situation.
# Answer:
#
#
# Response: 0
# Rationale: There is no language or context in this chart suggesting the patient suffers from social isolation or loneliness. The note focuses on the patient's extensive medical issues and treatment plans, with no mention of social support or relationships.
# Answer:
#
# Answer:
#
#         Thank you for your time.
#
#         Response: 1
#         Rationale: The patient lives alone and has no family involved in her life, but she has friends who are involved in her care, suggesting some social support, but limited family social interaction. This description alludes to a situation of ongoing social isolation.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#
#
#         Response: 0
#         Rationale: This chart primarily focuses on the patient's medical condition, treatment, and vital signs, with no indication or mention of social isolation, loneliness, or emotional well-being. The language is primarily medical, and there is no mention of the patient's relationships, living situation, or feelings of loneliness or isolation.
# Answer:
#
# Answer:
#
# Answer:
#
# Answer:
#   Do not include any personal opinions or unnecessary information, ensuring that the responses are objective and purely based on the provided medical chart information.
# Answer:
#
#
#         Response: 0
#         Rationale: The phrase "left alone" in the sentence does not imply chronic social isolation or loneliness but rather a temporary state of being alone in a specific situation. The sentence focuses on the patient's medical treatment and sedation rather than their emotional or social well-being.
# Answer:
#
#         (Abbreviations for clarity: Pt = patient, OOB = out of bed, AFIB = atrial fibrillation, BP = blood pressure, Nsg = nursing, IV = intravenous, abx = antibiotics, D/C = discharge)
#         Go ahead and respond with a 1 or 0, with a short explanation after.
# Answer:
#   The explanation should be no more than one sentence.
#
# Response: 0
# Rationale: The note does not describe or allude to a patient suffering from ongoing social isolation or loneliness, it solely focuses on medical treatment and observations.
# Answer:
#
# Answer:
#
#
#         Response: 1
#         Rationale: Although the chart does not directly state social isolation or loneliness, the patient's withdrawn behavior, nodding, and tears could suggest emotional distress and underlying loneliness. The presence of visitors, in this case, three children, does not necessarily imply that the patient feels socially supported or connected, especially if they are unable to express themselves.
# Answer:
#
#
#         Response: 0
#         Rationale: This chart does not contain any information about the patient's feelings of loneliness or lack of social interaction. The patient is married and has a child, which suggests that they have some social support. The focus of the chart is on the patient's medical condition and treatment, rather than their social or emotional well-being.
#                                    full_text_truncated  \
# 0    As other etiologies for bladder wall thickenin...
# 1    Additional foci of active bleeding in the left...
# 2    estranged husband.</s>Admission Date: [**2154-...
# 3    - Abx coverage limited to Vanc alone for 14 da...
# 4    He left rehab facility against medical advice ...
# ..                                                 ...
# 194  Pt seems to do best when left alone to yell fo...
# 195  To rec 2nd aliquot PRBC's this am (transfused ...
# 196  She was found by family members Pt intubated a...
# 197  Neg fld blanace 1.1L. Appears very withdrawn.<...
# 198  extrahepatic CBD normal size ERCP: Impression:...
#
#                                            label_model  gold_label
# 0                                                Error         0.0
# 1     \n\nResponse: 0\nRationale: The chart does no...         0.0
# 2                                                Error         0.0
# 3                                        \n        Go!         0.0
# 4     You will have a new prompt for each medical c...         0.0
# ..                                                 ...         ...
# 194          \n        (Abbreviations for clarity: ...         0.0
# 195   The explanation should be no more than one se...         0.0
# 196                                                            0.0
# 197   \n        \n        Response: 1\n        Rati...         0.0
# 198                 \n        \n        Response: 0...         0.0
#
# [199 rows x 3 columns]
# 929.9240500926971 seconds

# %%
# Parse responses
import re

# Function to extract the first number (0 or 1) after 'Response:'
def extract_response(text):
    start = text.find("Response:") + len("Response:")
    if start != -1:
        # Extract the text following "Response:"
        text_after_response = text[start:].strip()
        # Use regex to find the first occurrence of 0 or 1
        match = re.search(r'\b[01]\b', text_after_response)
        if match:
            return int(match.group())  # Return the number found (0 or 1)
    return 0  # Default to 0 if no valid response is found

# Function to extract the rationale (all text following 'Rationale:')
def extract_rationale(text):
    start = text.find("Rationale:") + len("Rationale:")
    if start != -1:
        return text[start:].strip()
    return ""  # Return empty string if "Rationale:" is not found

# Apply the functions to create new columns
result_df['response'] = result_df['label_model'].apply(extract_response)
result_df['rationale'] = result_df['label_model'].apply(extract_rationale)

# %%
result_df
result_df['response'].value_counts()
result_df['gold_label'].value_counts()
# Out:
# gold_label
# 0.0    194
# 1.0      5
# Name: count, dtype: int64

# %%
result_df.to_csv("chronic_social_isolation_llm_3_shot_labeled.csv")

# %%
result_df = pd.read_csv("chronic_social_isolation_llm_3_shot_labeled.csv")

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import numpy as np

classificaiton_report = classification_report(result_df['gold_label'],result_df['response'])

print(classificaiton_report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.85      0.91       194
#          1.0       0.12      0.80      0.21         5
#
#     accuracy                           0.84       199
#    macro avg       0.56      0.82      0.56       199
# weighted avg       0.97      0.84      0.90       199

# %%
results = []

for _ in range(1000):
    sample_df = result_df.sample(len(result_df), replace=True)

    preds = sample_df['response'].values
    true_labels = sample_df['gold_label'].values

    accuracy = accuracy_score(true_labels, preds)
    positive_precision = precision_score(true_labels, preds, labels=[1], average='binary')
    positive_recall = recall_score(true_labels, preds, labels=[1], average='binary')
    positive_f1 = f1_score(true_labels, preds, labels=[1], average='binary')

    results.append({
        'Accuracy': accuracy,
        'Positive Precision': positive_precision,
        'Positive Recall': positive_recall,
        'Positive F1': positive_f1,
    })

results_df = pd.DataFrame(results)

# Calculate mean
mean_summary = results_df.mean()

# Calculate confidence intervals
ci_lower = results_df.apply(lambda x: np.percentile(x, 2.5))
ci_upper = results_df.apply(lambda x: np.percentile(x, 97.5))

# Combine mean and confidence intervals into a single DataFrame
summary = pd.DataFrame({
    'Mean': mean_summary,
    '2.5%': ci_lower,
    '97.5%': ci_upper
})

print(summary)
# Out:
# /home/awalk55/.local/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/awalk55/.local/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/awalk55/.local/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/awalk55/.local/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/awalk55/.local/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#                         Mean      2.5%     97.5%
# Accuracy            0.844317  0.793970  0.889573
# Positive Precision  0.115201  0.026316  0.235294
# Positive Recall     0.794933  0.250000  1.000000
# Positive F1         0.197282  0.049970  0.370486
# /home/awalk55/.local/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
